# %%
from lxml import html
import os, json, re, nltk
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
mpl.rc('font', family='Constantia')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['text', 'f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
mypath = "../html/"
onlyfiles = [ "../html/{}".format(f) for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath,f)) ]

# %%
fulltext = ""
for f in onlyfiles:
    tree = html.parse(f)
    root = tree.getroot()
    text = root.text_content()
    fulltext += " " + text

# %%
fulltext = fulltext.replace("\xa0"," ")

# %%
fulltext = re.sub(r"([> ])ВЪ",r"\1Въ",fulltext)
fulltext = re.sub(r"([а-яіѣѳ]+)(Ѣ)",r"\1ѣ",fulltext)
fulltext = re.sub(r"(Ѣ)([а-яіѣѳ]+)",r"ѣ\2",fulltext)
fulltext = re.sub(r"([а-яіѣѳ]+)(Ъ)",r"\1ъ",fulltext)

# %%
import re,json
from lxml import html

with open("../resources/special_cases.json",'r',encoding='utf-8') as fp:
    lookup_dict = json.load(fp)

def ortho_rules(text,lookup_dict):
    """
    Takes a text string and a lookup dict as input
    Removes any lingering html tags
    Breaks the string down into component words with split
    Uses replacements to modernize orthography
    Returns re-assembled text with modern orthography
    """
    if type(text)==str:
        text = html.fromstring(text).text_content()
        textlist = text.split(' ')
        out_list = []
        for word in textlist:
            if word in [',','.',';',':']:
                out_list.append(word)
                continue
            punct = ""
            if len(re.findall(r"([,.;:])$",word))!=0:
                   punct = re.findall(r"([,.;:])$",word)[0]
            word = word.strip(',.;:')
            if word in lookup_dict:
                word = lookup_dict[word]
                out_list.append(word)
            else:
                word = re.sub("[Ъъ]$",'',word)
                word = re.sub(r"^([че]{0,2}[ч]?[вбнр]?[веоаи])з([ПФКТШСЧпфктшсч])",r"\1с\2",word,re.IGNORECASE)
                word = re.sub("аго$","ого",word,re.IGNORECASE)
                word = re.sub("яго$","его",word,re.IGNORECASE)
                word = re.sub("ыя$","ые",word,re.IGNORECASE)
                word = re.sub("iя$","ие",word,re.IGNORECASE)
                word = word.replace('i','и') #english
                word = word.replace('I','И') #english
                word = word.replace('і','и') #cyrillic
                word = word.replace('І','И') #cyrillic
                word = word.replace('Ѣ','Е')
                word = word.replace('ѣ','е')
                word = word.replace('Ѳ','Ф')
                word = word.replace('ѳ','ф')
                word += punct
                out_list.append(word)
        out_str = ' '.join(out_list)
        return out_str
    else:
        return None

# %%
fulltext = ortho_rules(fulltext,lookup_dict)

# %% [markdown]
# Fulltext is now ready to be parsed
# ==================================

# %%
tokens = nltk.tokenize.wordpunct_tokenize(fulltext)

# %%
ru_stemmer = nltk.SnowballStemmer('russian')

# %%
reverse_stem = {}
for w in set(tokens):
    if ru_stemmer.stem(w) not in reverse_stem:
        reverse_stem[ru_stemmer.stem(w)] = []
    reverse_stem[ru_stemmer.stem(w)].append(w)

# %%
tok_stems = [ru_stemmer.stem(w) for w in tokens]

# %%
text = nltk.text.Text(tokens)
stem_text = nltk.text.Text(tok_stems)

# %%
freq = nltk.FreqDist(text)

# %%
freq.plot(25,cumulative=True)

# %%
freq.most_common()
# Out:
# [(',', 4464),
#  ('.', 1806),
#  ('в', 1549),
#  ('и', 1157),
#  ('Наместничества', 716),
#  (';', 621),
#  ('бывает', 594),
#  ('на', 464),
#  ('В', 441),
#  ('с', 426),
#  ('году', 425),
#  ('уезде', 381),
#  ('из', 371),
#  ('ярмарки', 361),
#  ('товарами', 353),
#  ('ярмарка', 351),
#  ('Здесь', 314),
#  (':', 305),
#  ('день', 296),
#  ('купцы', 291),
#  ('город', 289),
#  ('оном', 233),
#  ('бывают', 230),
#  ('приезжают', 230),
#  ('по', 224),
#  ('торгуют', 207),
#  ('городов', 204),
#  ('село', 190),
#  ('первая', 184),
#  ('мелочными', 180),
#  ('разными', 169),
#  ('вторая', 167),
#  ('а', 151),
#  ('-', 148),
#  ('местечко', 144),
#  ('города', 127),
#  ('три', 122),
#  ('Июля', 121),
#  ('две', 120),
#  ('дня', 118),
#  ('третия', 114),
#  ('одна', 111),
#  ('товары', 110),
#  ('годовая', 105),
#  ('привозят', 102),
#  ('нем', 98),
#  ('оные', 97),
#  ('8', 95),
#  ('Сентября', 94),
#  ('разных', 90),
#  ('Июня', 87),
#  ('1', 85),
#  ('шелковыми', 81),
#  ('также', 77),
#  ('крестьяне', 75),
#  ('прочими', 74),
#  ('неделе', 72),
#  ('для', 71),
#  ('Августа', 71),
#  ('слобода', 70),
#  ('оной', 70),
#  ('уезду', 70),
#  ('хлебом', 68),
#  ('же', 67),
#  ('четыре', 67),
#  ('сем', 66),
#  ('вином', 65),
#  ('6', 63),
#  ('пятницу', 62),
#  ('четвертая', 59),
#  ('Маия', 59),
#  ('год', 58),
#  ('то', 57),
#  ('оных', 55),
#  ('скотом', 53),
#  ('9', 53),
#  ('Генваря', 52),
#  ('Октября', 51),
#  ('которую', 50),
#  ('бумажными', 50),
#  ('29', 49),
#  ('жители', 49),
#  ('оную', 49),
#  ('Киевского', 49),
#  ('Ноября', 48),
#  ('Губернии', 48),
#  ('припасами', 47),
#  ('Декабря', 47),
#  ('торг', 46),
#  ('десятую', 46),
#  ('того', 45),
#  ('Московской', 44),
#  ('мелочные', 44),
#  ('Пасхе', 44),
#  ('Богородицы', 43),
#  ('На', 43),
#  ('15', 42),
#  ('которые', 42),
#  ('сего', 41),
#  ('съезжаются', 41),
#  ('Харьковского', 41),
#  ('городе', 41),
#  ('хлеб', 40),
#  ('от', 40),
#  ('Купцы', 40),
#  ('здесь', 39),
#  ('дни', 39),
#  ('неделю', 39),
#  ('прочие', 39),
#  ('другая', 39),
#  ('ближних', 39),
#  ('прочимъ', 38),
#  ('съестными', 38),
#  ('близ', 37),
#  ('Могилевского', 36),
#  ('шелковые', 36),
#  ('разные', 36),
#  ('Екатеринославского', 36),
#  ('лежащих', 35),
#  ('селе', 35),
#  ('Черниговского', 35),
#  ('разным', 35),
#  ('как', 35),
#  ('числа', 35),
#  ('20', 34),
#  ('съестные', 34),
#  ('Тульского', 34),
#  ('горячим', 34),
#  ('23', 33),
#  ('продают', 33),
#  ('торжки', 32),
#  ('24', 32),
#  ('других', 32),
#  ('не', 31),
#  ('месяце', 31),
#  ('монастырь', 31),
#  ('лошадей', 31),
#  ('два', 31),
#  ('Рижского', 30),
#  ('Тамбовского', 30),
#  ('посудою', 30),
#  ('кроме', 30),
#  ('кожами', 30),
#  ('припасы', 30),
#  ('которой', 29),
#  ('Российских', 29),
#  ('Новогородского', 29),
#  ('части', 29),
#  ('Полотского', 29),
#  ('25', 28),
#  ('большей', 28),
#  ('прочее', 28),
#  ('да', 28),
#  ('торгу', 28),
#  ('после', 27),
#  ('сверх', 27),
#  ('14', 27),
#  ('приезжие', 27),
#  ('Ярославского', 27),
#  (')', 27),
#  ('десятой', 26),
#  ('лошадьми', 26),
#  ('Тверского', 26),
#  ('о', 26),
#  ('Вологодского', 26),
#  ('торги', 25),
#  ('мелочным', 25),
#  ('рыбою', 25),
#  ('товаромъ', 25),
#  ('оного', 25),
#  ('окрестных', 24),
#  ('еженедельные', 24),
#  ('всякими', 24),
#  ('пивомъ', 24),
#  ('поста', 24),
#  ('продолжается', 24),
#  ('но', 24),
#  ('уездов', 24),
#  ('2', 23),
#  ('обыватели', 23),
#  ('мест', 23),
#  ('Ярославля', 23),
#  ('месте', 23),
#  ('26', 23),
#  ('имени', 22),
#  ('или', 22),
#  ('деревянною', 22),
#  ('21', 22),
#  ('главный', 22),
#  ('во', 22),
#  ('Дворца', 22),
#  ('товаром', 22),
#  ('торгов', 21),
#  ('крестьянскими', 21),
#  ('Июне', 21),
#  ('холст', 21),
#  ('овчинами', 21),
#  ('Святого', 21),
#  ('Господня', 21),
#  ('число', 21),
#  ('масло', 20),
#  ('воск', 20),
#  ('проч', 20),
#  ('всякие', 20),
#  ('другими', 20),
#  ('Пензенского', 20),
#  ('какъ', 20),
#  ('один', 20),
#  ('Апреля', 20),
#  ('около', 19),
#  ('мед', 19),
#  ('Духа', 19),
#  ('Николая', 19),
#  ('скот', 19),
#  ('Калужского', 19),
#  ('время', 19),
#  ('медом', 19),
#  ('недели', 19),
#  ('со', 19),
#  ('годовые', 19),
#  ('великого', 19),
#  ('Сошествия', 18),
#  ('Великомученика', 18),
#  ('Курского', 18),
#  ('Марта', 18),
#  ('Костромского', 18),
#  ('Российские', 18),
#  ('Великороссийские', 18),
#  ('Орловского', 18),
#  ('обывателей', 18),
#  ('Рязанского', 18),
#  ('еженедельных', 18),
#  ('окольные', 17),
#  ('1780', 17),
#  ('сукна', 17),
#  ('всякой', 17),
#  ('Углича', 17),
#  ('съезд', 17),
#  ('Рождества', 17),
#  ('Псковского', 17),
#  ('При', 17),
#  ('продажу', 17),
#  ('при', 17),
#  ('чисел', 17),
#  ('сюда', 17),
#  ('там', 17),
#  ('Петра', 17),
#  ('тожь', 16),
#  ('только', 16),
#  ('Чудотворца', 16),
#  ('Св', 16),
#  ('Июле', 16),
#  ('Тулы', 16),
#  ('своими', 16),
#  ('Илии', 16),
#  ('Северского', 16),
#  ('называемая', 16),
#  ('уездных', 16),
#  ('мелкими', 16),
#  ('продажи', 16),
#  ('Павла', 16),
#  ('родящимися', 15),
#  ('красным', 15),
#  ('у', 15),
#  ('дней', 15),
#  ('Серпухова', 15),
#  ('дегтем', 15),
#  ('Вознесения', 15),
#  ('крестьянство', 15),
#  ('Бывает', 15),
#  ('которых', 15),
#  ('уездные', 15),
#  ('ярмарок', 15),
#  ('Пресвятые', 15),
#  ('Пророка', 15),
#  ('купечество', 14),
#  ('шерстяными', 14),
#  ('пенька', 14),
#  ('Синбирского', 14),
#  ('С', 14),
#  ('девятую', 14),
#  ('есть', 14),
#  ('понедельник', 14),
#  ('погост', 14),
#  ('окольных', 14),
#  ('лавочными', 14),
#  ('красными', 14),
#  ('соль', 14),
#  ('ярмарку', 14),
#  ('рогатой', 14),
#  ('что', 14),
#  ('селах', 13),
#  ('кожи', 13),
#  ('москотильные', 13),
#  ('Зарайска', 13),
#  ('Покрова', 13),
#  ('числу', 13),
#  ('слободы', 13),
#  ('одному', 13),
#  ('пять', 13),
#  ('1779', 13),
#  ('Нижегородского', 13),
#  ('смолу', 13),
#  ('верстах', 13),
#  ('пятнице', 13),
#  ('продолжающаяся', 13),
#  ('Сюда', 13),
#  ('Воронежского', 13),
#  ('частию', 13),
#  ('за', 13),
#  ('Февраля', 12),
#  ('изделье', 12),
#  ('понедельникам', 12),
#  ('еженедельного', 12),
#  ('более', 12),
#  ('Каширском', 12),
#  ('Российскими', 12),
#  ('Каширы', 12),
#  ('пивом', 12),
#  ('Лубенском', 12),
#  ('Пасхи', 12),
#  ('пенькою', 12),
#  ('Иоанна', 12),
#  ('к', 12),
#  ('малому', 12),
#  ('коих', 12),
#  ('москотильными', 12),
#  ('Москвы', 12),
#  ('Динабурга', 12),
#  ('Преображения', 12),
#  ('каждую', 12),
#  ('1778', 12),
#  ('съезды', 12),
#  ('до', 12),
#  ('прочия', 12),
#  ('пяток', 12),
#  ('продаже', 12),
#  ('Преполовения', 12),
#  ('Миргородском', 12),
#  ('Волоколамском', 11),
#  ('успения', 11),
#  ('товаров', 11),
#  ('купцов', 11),
#  ('пеньку', 11),
#  ('рогатым', 11),
#  ('месяца', 11),
#  ('7', 11),
#  ('большею', 11),
#  ('дню', 11),
#  ('Наместничестве', 11),
#  ('пятая', 11),
#  ('сукнами', 11),
#  ('иногда', 11),
#  ('Георгия', 11),
#  ('праздник', 11),
#  ('каждой', 11),
#  ('Владимерского', 11),
#  ('Изюма', 11),
#  ('Апостолов', 11),
#  ('прочим', 11),
#  ('пятницам', 11),
#  ('материи', 11),
#  ('Переславля', 11),
#  ('вино', 11),
#  ('б', 11),
#  ('издельями', 11),
#  ('Торгуют', 10),
#  ('Венева', 10),
#  ('тому', 10),
#  ('числах', 10),
#  ('такожь', 10),
#  ('пустыня', 10),
#  ('бумажные', 10),
#  ('Динабургском', 10),
#  ('Сентябре', 10),
#  ('делающимися', 10),
#  ('иностранные', 10),
#  ('Иркутского', 10),
#  ('которая', 10),
#  ('Воскресенье', 10),
#  ('Крымскую', 10),
#  ('холсты', 10),
#  ('рыбу', 10),
#  ('другие', 10),
#  ('салом', 10),
#  ('обыкновенных', 10),
#  ('горячее', 10),
#  ('крестьян', 9),
#  ('Богоявления', 9),
#  ('первой', 9),
#  ('монастыре', 9),
#  ('Сырной', 9),
#  ('съезжается', 9),
#  ('16', 9),
#  ('Володимерского', 9),
#  ('месяцах', 9),
#  ('холстом', 9),
#  ('Залеского', 9),
#  ('1782', 9),
#  ('5', 9),
#  ('покупают', 9),
#  ('посуду', 9),
#  ('привозятся', 9),
#  ('Донских', 9),
#  ('гарусными', 9),
#  ('солью', 9),
#  ('деревянное', 9),
#  ('несколько', 9),
#  ('Пермского', 8),
#  ('множество', 8),
#  ('28', 8),
#  ('17', 8),
#  ('жителям', 8),
#  ('железом', 8),
#  ('Малороссийских', 8),
#  ('льняные', 8),
#  ('шесть', 8),
#  ('своей', 8),
#  ('люди', 8),
#  ('произрастениями', 8),
#  ('так', 8),
#  ('Великороссийских', 8),
#  ('мелкою', 8),
#  ('сел', 8),
#  ('Казанского', 8),
#  ('шанец', 8),
#  ('деревня', 8),
#  ('чрез', 8),
#  ('субботу', 8),
#  ('Калуги', 8),
#  ('хлебомъ', 8),
#  ('колесами', 8),
#  ('Приезжают', 8),
#  ('Романова', 8),
#  ('еще', 8),
#  ('торговые', 8),
#  ('ярмарокъ', 8),
#  ('ярмарках', 8),
#  ('каждонедельно', 8),
#  ('свои', 7),
#  ('станиц', 7),
#  ('прочих', 7),
#  ('парчи', 7),
#  ('рукоделия', 7),
#  ('именно', 7),
#  ('купцам', 7),
#  ('4', 7),
#  ('Полтавском', 7),
#  ('продолжаются', 7),
#  ('Вологодские', 7),
#  ('Саратовского', 7),
#  ('соседственных', 7),
#  ('30', 7),
#  ('Маие', 7),
#  ('Переяславском', 7),
#  ('Михаила', 7),
#  ('числе', 7),
#  ('торговли', 7),
#  ('Дня', 7),
#  ('деревень', 7),
#  ('стеклянною', 7),
#  ('начинается', 7),
#  ('коей', 7),
#  ('пятницы', 7),
#  ('рухлядь', 7),
#  ('пряжу', 7),
#  ('скупают', 7),
#  ('раза', 7),
#  ('18', 7),
#  ('монастыря', 7),
#  ('праздника', 7),
#  ('скотину', 7),
#  ('крестьянства', 7),
#  ('торговых', 7),
#  ('обывателями', 7),
#  ('сей', 7),
#  ('особливо', 7),
#  ('воскресеньям', 7),
#  ('Иногда', 7),
#  ('собираются', 7),
#  ('вещи', 7),
#  ('1777', 7),
#  ('недельные', 7),
#  ('Пскова', 7),
#  ('сало', 7),
#  ('1781', 7),
#  ('Бежецком', 6),
#  ('Смоленского', 6),
#  ('годовой', 6),
#  ('братьи', 6),
#  ('середам', 6),
#  ('вещами', 6),
#  ('Пошехонском', 6),
#  ('деревянную', 6),
#  ('Уфимского', 6),
#  ('Успения', 6),
#  ('Елецкие', 6),
#  ('раз', 6),
#  ('торговля', 6),
#  ('четверток', 6),
#  ('волость', 6),
#  ('места', 6),
#  ('Предтечи', 6),
#  ('мелочью', 6),
#  ('дням', 6),
#  ('покупки', 6),
#  ('Архистратига', 6),
#  ('мягкую', 6),
#  ('второй', 6),
#  ('прочею', 6),
#  ('крепость', 6),
#  ('городка', 6),
#  ('уездными', 6),
#  ('Кашинском', 6),
#  ('еженедельной', 6),
#  ('Прилуцком', 6),
#  ('Троицы', 6),
#  ('Димитрия', 6),
#  ('парусную', 6),
#  ('их', 6),
#  ('привозимыми', 6),
#  ('честного', 6),
#  ('Выборгского', 6),
#  ('всеедной', 6),
#  ('еженедельно', 6),
#  ('Светлого', 6),
#  ('приезжает', 6),
#  ('Казанския', 6),
#  ('Сибири', 6),
#  ('Рогачева', 6),
#  ('небогатыми', 6),
#  ('Суздальском', 6),
#  ('овчины', 6),
#  ('19', 6),
#  ('Провинции', 6),
#  ('близости', 6),
#  ('купцами', 6),
#  ('Августе', 6),
#  ('Параскевы', 6),
#  ('продолжающияся', 6),
#  ('слободе', 6),
#  ('сеном', 5),
#  ('Челябинском', 5),
#  ('лавочным', 5),
#  ('2о', 5),
#  ('Воскресения', 5),
#  ('железные', 5),
#  ('сырейные', 5),
#  ('пригоняют', 5),
#  ('весною', 5),
#  ('коровье', 5),
#  ('Октябре', 5),
#  ('набойчатыми', 5),
#  ('Елецком', 5),
#  ('воскресным', 5),
#  ('Саранском', 5),
#  ('начинающаяся', 5),
#  ('Христова', 5),
#  ('Стародубовском', 5),
#  ('среду', 5),
#  ('посконной', 5),
#  ('шестая', 5),
#  ('Алексина', 5),
#  ('отчине', 5),
#  ('иностранными', 5),
#  ('токмо', 5),
#  ('первую', 5),
#  ('Валуек', 5),
#  ('крамными', 5),
#  ('Борисоглебска', 5),
#  ('Белева', 5),
#  ('Троицын', 5),
#  ('одинадцатой', 5),
#  ('вторникам', 5),
#  ('рухлядью', 5),
#  ('москотильной', 5),
#  ('сих', 5),
#  ('Тобольского', 5),
#  ('Гадяцком', 5),
#  ('лен', 5),
#  ('кои', 5),
#  ('торговъ', 5),
#  ('Графа', 5),
#  ('уточную', 5),
#  ('вина', 5),
#  ('Воздвижения', 5),
#  ('церкви', 5),
#  ('последних', 5),
#  ('27', 5),
#  ('Боровска', 5),
#  ('Богоматери', 5),
#  ('Шатском', 5),
#  ('льняной', 5),
#  ('шелковых', 5),
#  ('месяцахъ', 5),
#  ('том', 5),
#  ('всех', 5),
#  ('бумажных', 5),
#  ('Малороссийские', 5),
#  ('ежегодно', 5),
#  ('они', 5),
#  ('днем', 5),
#  ('дважды', 5),
#  ('пригород', 5),
#  ('Святых', 5),
#  ('собою', 5),
#  ('Святые', 5),
#  ('полотном', 5),
#  ('зимнее', 5),
#  ('Святителя', 5),
#  ('позументы', 5),
#  ('НИКОЛАЕВСКОЙ', 5),
#  ('3', 5),
#  ('ми', 5),
#  ('великая', 5),
#  ('Новосиля', 4),
#  ('Рогачевском', 4),
#  ('Богослова', 4),
#  ('расстоянием', 4),
#  ('привозимою', 4),
#  ('воском', 4),
#  ('той', 4),
#  ('море', 4),
#  ('знатные', 4),
#  ('те', 4),
#  ('крестьянския', 4),
#  ('ней', 4),
#  ('перед', 4),
#  ('Рыбного', 4),
#  ('Вереи', 4),
#  ('поселян', 4),
#  ('субботние', 4),
#  ('вает', 4),
#  ('Тройцын', 4),
#  ('приезжающих', 4),
#  ('Петрова', 4),
#  ('Пятидесятницы', 4),
#  ('Вологды', 4),
#  ('мелочных', 4),
#  ('некоторые', 4),
#  ('мягкою', 4),
#  ('котором', 4),
#  ('тех', 4),
#  ('материями', 4),
#  ('Можайском', 4),
#  ('Троицкая', 4),
#  ('привозит', 4),
#  ('вощину', 4),
#  ('железо', 4),
#  ('ь', 4),
#  ('шерстью', 4),
#  ('состоит', 4),
#  ('говяжьими', 4),
#  ('отправляются', 4),
#  ('двух', 4),
#  ('Олонецкого', 4),
#  ('холстов', 4),
#  ('ряды', 4),
#  ('произрастения', 4),
#  ('построены', 4),
#  ('серебро', 4),
#  ('лавок', 4),
#  ('сортов', 4),
#  ('паче', 4),
#  ('них', 4),
#  ('сию', 4),
#  ('торгует', 4),
#  ('ПОКРОВСКОЕ', 4),
#  ('субботам', 4),
#  ('Креста', 4),
#  ('1776', 4),
#  ('изделья', 4),
#  ('ИВАНОВСКОЕ', 4),
#  ('конопляное', 4),
#  ('разную', 4),
#  ('Великого', 4),
#  ('временем', 4),
#  ('одинадцатую', 4),
#  ('холстами', 4),
#  ('говяжьи', 4),
#  ('все', 4),
#  ('первых', 4),
#  ('много', 4),
#  ('Нежинском', 4),
#  ('полотна', 4),
#  ('Бывают', 4),
#  ('посуда', 4),
#  ('шерстяные', 4),
#  ('Живоначальные', 4),
#  ('рукоделья', 4),
#  ('хлебъ', 4),
#  ('Рузы', 4),
#  ('вторник', 4),
#  ('Святой', 4),
#  ('рукоделье', 4),
#  ('Харькова', 4),
#  ('Козельском', 4),
#  ('крестьянам', 4),
#  ('бываетъ', 4),
#  ('Феврале', 4),
#  ('осенью', 4),
#  ('Екатеринославском', 4),
#  ('жителями', 4),
#  ('Острова', 4),
#  ('торговой', 4),
#  ('сермяжные', 4),
#  ('под', 4),
#  ('количестве', 4),
#  ('Вятского', 4),
#  ('недорогими', 4),
#  ('Нежина', 4),
#  ('четырех', 4),
#  ('пред', 4),
#  ('Воскресеньям', 4),
#  ('мелочьми', 4),
#  ('1775', 4),
#  ('Климовицком', 4),
#  ('глиняною', 4),
#  ('Россия', 4),
#  ('Мстиславском', 4),
#  ('заячьи', 4),
#  ('привозимые', 4),
#  ('Изюмском', 4),
#  ('небольшой', 4),
#  ('Дамиана', 4),
#  ('скотиною', 4),
#  ('городок', 4),
#  ('Греки', 4),
#  ('производится', 4),
#  ('Яренска', 4),
#  ('окрестные', 3),
#  ('городовъ', 3),
#  ('всякого', 3),
#  ('подобные', 3),
#  ('отсюда', 3),
#  ('седьмой', 3),
#  ('жителей', 3),
#  ('бы', 3),
#  ('Звенигородском', 3),
#  ('тое', 3),
#  ('Алатырьском', 3),
#  ('А', 3),
#  ('главы', 3),
#  ('Сумском', 3),
#  ('Малого', 3),
#  ('Козловском', 3),
#  ('уезда', 3),
#  ('13', 3),
#  ('съежаются', 3),
#  ('льняным', 3),
#  ('каждонедельных', 3),
#  ('крестьянским', 3),
#  ('МИХАЙЛОВКА', 3),
#  ('четвергам', 3),
#  ('числом', 3),
#  ('рядах', 3),
#  ('канаты', 3),
#  ('ни', 3),
#  ('имеется', 3),
#  ('саньми', 3),
#  ('шубами', 3),
#  ('Жители', 3),
#  ('товаровъ', 3),
#  ('Шуи', 3),
#  ('Фоминой', 3),
#  ('Старой', 3),
#  ('прежде', 3),
#  ('Болхова', 3),
#  ('мехи', 3),
#  ('медочными', 3),
#  ('пятниц', 3),
#  ('средине', 3),
#  ('дов', 3),
#  ('мелочной', 3),
#  ('Троицкой', 3),
#  ('оттуда', 3),
#  ('разною', 3),
#  ('годовых', 3),
#  ('всяким', 3),
#  ('девятой', 3),
#  ('Столпника', 3),
#  ('зимою', 3),
#  ('Иркутска', 3),
#  ('печеным', 3),
#  ('ве', 3),
#  ('деревянная', 3),
#  ('крестьянами', 3),
#  ('окольными', 3),
#  ('девять', 3),
#  ('другия', 3),
#  ('торгуютъ', 3),
#  ('реки', 3),
#  ('Белицком', 3),
#  ('Яренском', 3),
#  ('Кесове', 3),
#  ('соседних', 3),
#  ('материй', 3),
#  ('Прокопия', 3),
#  ('Бежецка', 3),
#  ('между', 3),
#  ('крестьянское', 3),
#  ('1784', 3),
#  ('Залесного', 3),
#  ('первое', 3),
#  ('пушные', 3),
#  ('Ярославца', 3),
#  ('Донковском', 3),
#  ('трех', 3),
#  ('однажды', 3),
#  ('лыками', 3),
#  ('Симеона', 3),
#  ('здешние', 3),
#  ('Ваий', 3),
#  ('ме', 3),
#  ('отпускают', 3),
#  ('Рузском', 3),
#  ('Казани', 3),
#  ('Космы', 3),
#  ('Ноябре', 3),
#  ('крамщики', 3),
#  ('ТИХОНОВА', 3),
#  ('Фомину', 3),
#  ('Ростова', 3),
#  ('продажа', 3),
#  ('льняное', 3),
#  ('скота', 3),
#  ('Светлой', 3),
#  ('каждогодно', 3),
#  ('острог', 3),
#  ('серебреными', 3),
#  ('привозными', 3),
#  ('мясами', 3),
#  ('сырые', 3),
#  ('суровскими', 3),
#  ('табаком', 3),
#  ('бумагу', 3),
#  ('Великомученицы', 3),
#  ('пост', 3),
#  ('семь', 3),
#  ('иногородные', 3),
#  ('путем', 3),
#  ('11', 3),
#  ('Покровская', 3),
#  ('торгах', 3),
#  ('пятой', 3),
#  ('единожды', 3),
#  ('нет', 3),
#  ('работы', 3),
#  ('чулки', 3),
#  ('торж', 3),
#  ('каждое', 3),
#  ('местечка', 3),
#  ('Мещовска', 3),
#  ('товар', 3),
#  ('где', 3),
#  ('чай', 3),
#  ('Можайска', 3),
#  ('Евстафия', 3),
#  ('малым', 3),
#  ('торжков', 3),
#  ('отправляет', 3),
#  ('Сретения', 3),
#  ('Норской', 3),
#  ('Господ', 3),
#  ('маслом', 3),
#  ('волчьи', 3),
#  ('шелк', 3),
#  ('туда', 3),
#  ('Подле', 3),
#  ('великой', 3),
#  ('ют', 3),
#  ('Архангельского', 3),
#  ('О', 3),
#  ('22', 3),
#  ('двор', 3),
#  ('Для', 3),
#  ('округе', 3),
#  ('иные', 3),
#  ('ными', 3),
#  ('Новагорода', 3),
#  ('собирается', 3),
#  ('питейными', 3),
#  ('производят', 3),
#  ('разночинцы', 3),
#  ('крестьянскою', 3),
#  ('назад', 3),
#  ('приуготовлениями', 3),
#  ('пят', 3),
#  ('Князя', 3),
#  ('Мологи', 3),
#  ('щетиною', 3),
#  ('Московские', 3),
#  ('воскресенье', 3),
#  ('Ивановская', 3),
#  ('деревянной', 3),
#  ('КИРИЛОВ', 3),
#  ('сии', 3),
#  ('10', 3),
#  ('Р', 3),
#  ('пятокъ', 3),
#  ('больше', 3),
#  ('Генваре', 3),
#  ('виномъ', 3),
#  ('Апостол', 3),
#  ('*', 3),
#  ('находятся', 3),
#  ('каждом', 3),
#  ('лавки', 3),
#  ('купецкие', 3),
#  ('озера', 3),
#  ('вся', 3),
#  ('Петровская', 3),
#  ('торгъ', 3),
#  ('усекновения', 3),
#  ('дворе', 3),
#  ('товару', 3),
#  ('большем', 3),
#  ('гостиной', 3),
#  ('12', 3),
#  ('сахар', 3),
#  ('каждонедельные', 3),
#  ('местечке', 3),
#  ('летним', 3),
#  ('медвежьи', 3),
#  ('Дни', 2),
#  ('шубы', 2),
#  ('бараньи', 2),
#  ('Волхова', 2),
#  ('посада', 2),
#  ('Короченском', 2),
#  ('дне', 2),
#  ('продаются', 2),
#  ('мяса', 2),
#  ('хрящевым', 2),
#  ('всяких', 2),
#  ('человека', 2),
#  ('быва', 2),
#  ('1783', 2),
#  ('РУЗА', 2),
#  ('смежных', 2),
#  ('съездов', 2),
#  ('Торопецкие', 2),
#  ('приезжающие', 2),
#  ('Азиатские', 2),
#  ('половины', 2),
#  ('ПЕТРОВСК', 2),
#  ('напитки', 2),
#  ('Россиан', 2),
#  ('Белевском', 2),
#  ('про', 2),
#  ('Десне', 2),
#  ('каждый', 2),
#  ('уез', 2),
#  ('табак', 2),
#  ('Рижскому', 2),
#  ('СПАС', 2),
#  ('здешнего', 2),
#  ('Коломенском', 2),
#  ('зимовье', 2),
#  ('сряду', 2),
#  ('сено', 2),
#  ('Крестителя', 2),
#  ('Сибирскими', 2),
#  ('Доброго', 2),
#  ('которого', 2),
#  ('Области', 2),
#  ('Сверх', 2),
#  ('ва', 2),
#  ('треть', 2),
#  ('Сентябри', 2),
#  ('Декабре', 2),
#  ('ярмарке', 2),
#  ('Торг', 2),
#  ('рогожи', 2),
#  ('Воздвижение', 2),
#  ('годе', 2),
#  ('золотые', 2),
#  ('лисицы', 2),
#  ('ИВАНОВО', 2),
#  ('Кашина', 2),
#  ('Оршанском', 2),
#  ('лесом', 2),
#  ('Купечество', 2),
#  ('Марша', 2),
#  ('Калужской', 2),
#  ('Калмыки', 2),
#  ('И', 2),
#  ('КРАСНОЕ', 2),
#  ('живущие', 2),
#  ('съезжалось', 2),
#  ('Ярополче', 2),
#  ('седмицу', 2),
#  ('возвращаются', 2),
#  ('здешних', 2),
#  ('Великолуцком', 2),
#  ('когда', 2),
#  ('городом', 2),
#  ('ПОРЕЧЬЕ', 2),
#  ('небогатые', 2),
#  ('Собора', 2),
#  ...]

# %%
stopwords = ['-',',','.','а','в','и',';','на','В','с','по',':','из'] # "helper" stopwords, to find significant text generally
stopwords.extend(['быва','ярмарк','наместничеств','город','он','год','уезд','зде','ден','сел','перв','проч','втор','а','котор','местечк','годов','недел','одн','дня','три','две','привоз','трет','друг','нем','пятниц','8','слобод','числ','1','такж','август','всяк','десят','для','сем','жител','еженедельн','четыр','же','то','6','четверт','как','съезжа','мест','9','больш','ноябр','месяц','обывател','киевск','29','продаж','монастыр','декабр','губерн','московск']) # words that aren't of interest to this analysis. can be replaced/commented out

# %%
stopped_tokens = [w for w in tok_stems if w not in stopwords]

# %%
stopped_text = nltk.text.Text(stopped_tokens)

# %%
nltk.FreqDist(stopped_text).most_common()
# Out:
# [('товар', 506),
#  ('купц', 355),
#  ('торг', 355),
#  ('разн', 342),
#  ('мелочн', 259),
#  ('приезжа', 251),
#  ('июл', 137),
#  ('шелков', 124),
#  ('хлеб', 117),
#  ('июн', 108),
#  ('сентябр', 106),
#  ('вин', 85),
#  ('крестьян', 82),
#  ('припас', 77),
#  ('скот', 75),
#  ('съестн', 74),
#  ('бумажн', 67),
#  ('ма', 66),
#  ('российск', 65),
#  ('октябр', 58),
#  ('пасх', 56),
#  ('генвар', 55),
#  ('холст', 49),
#  ('посуд', 47),
#  ('горяч', 46),
#  ('деревя', 46),
#  ('тог', 45),
#  ('продолжа', 45),
#  ('част', 44),
#  ('богородиц', 44),
#  ('кож', 43),
#  ('15', 42),
#  ('дни', 41),
#  ('харьковск', 41),
#  ('крестьянск', 41),
#  ('сег', 41),
#  ('от', 40),
#  ('екатеринославск', 40),
#  ('близ', 39),
#  ('уездн', 39),
#  ('ближн', 39),
#  ('ил', 38),
#  ('велик', 38),
#  ('пеньк', 38),
#  ('мед', 38),
#  ('прочим', 38),
#  ('прода', 37),
#  ('свят', 37),
#  ('рыб', 37),
#  ('торжк', 37),
#  ('лежа', 37),
#  ('могилевск', 36),
#  ('красн', 36),
#  ('съезд', 36),
#  ('вологодск', 35),
#  ('не', 35),
#  ('черниговск', 35),
#  ('кажд', 35),
#  ('тульск', 35),
#  ('при', 35),
#  ('окольн', 34),
#  ('20', 34),
#  ('рижск', 34),
#  ('москотильн', 34),
#  ('сво', 34),
#  ('23', 33),
#  ('воскресен', 33),
#  ('пят', 33),
#  ('приезж', 32),
#  ('24', 32),
#  ('мелк', 31),
#  ('полотск', 31),
#  ('лошад', 31),
#  ('два', 31),
#  ('кром', 31),
#  ('тамбовск', 31),
#  ('сюд', 30),
#  ('сверх', 30),
#  ('ко', 30),
#  ('новогородск', 30),
#  ('понедельник', 29),
#  ('о', 29),
#  ('да', 29),
#  ('имен', 29),
#  ('сукн', 28),
#  ('ярославск', 28),
#  ('25', 28),
#  ('рогат', 28),
#  ('тверск', 27),
#  ('пост', 27),
#  ('овчин', 27),
#  ('посл', 27),
#  (')', 27),
#  ('сол', 27),
#  ('14', 27),
#  ('издел', 27),
#  ('окрестн', 27),
#  ('торгов', 26),
#  ('великороссийск', 26),
#  ('лошадьм', 26),
#  ('но', 26),
#  ('товаром', 25),
#  ('крестьянств', 24),
#  ('пивом', 24),
#  ('воск', 24),
#  ('ярмарок', 24),
#  ('ярославл', 24),
#  ('дворц', 23),
#  ('во', 23),
#  ('мал', 23),
#  ('26', 23),
#  ('2', 23),
#  ('лавочн', 23),
#  ('масл', 23),
#  ('господн', 23),
#  ('главн', 23),
#  ('праздник', 22),
#  ('21', 22),
#  ('калужск', 21),
#  ('апрел', 21),
#  ('льнян', 21),
#  ('рукодел', 20),
#  ('казанск', 20),
#  ('март', 20),
#  ('пензенск', 20),
#  ('курск', 20),
#  ('дух', 20),
#  ('один', 20),
#  ('окол', 20),
#  ('орловск', 19),
#  ('купечеств', 19),
#  ('псковск', 19),
#  ('костромск', 19),
#  ('со', 19),
#  ('никол', 19),
#  ('рождеств', 19),
#  ('сошеств', 19),
#  ('врем', 19),
#  ('шерстян', 18),
#  ('великомученик', 18),
#  ('матер', 18),
#  ('успен', 18),
#  ('вознесен', 18),
#  ('девят', 18),
#  ('чисел', 18),
#  ('иностра', 18),
#  ('зарайск', 18),
#  ('там', 18),
#  ('иногд', 18),
#  ('рязанск', 18),
#  ('углич', 18),
#  ('сал', 18),
#  ('каждонедельн', 17),
#  ('дне', 17),
#  ('погост', 17),
#  ('привозим', 17),
#  ('чудотворц', 17),
#  ('1780', 17),
#  ('петр', 17),
#  ('называ', 17),
#  ('у', 17),
#  ('св', 17),
#  ('тул', 17),
#  ('синбирск', 17),
#  ('тож', 16),
#  ('смол', 16),
#  ('родя', 16),
#  ('тольк', 16),
#  ('северск', 16),
#  ('павл', 16),
#  ('феврал', 16),
#  ('пророк', 16),
#  ('апостол', 15),
#  ('том', 15),
#  ('раз', 15),
#  ('пяток', 15),
#  ('троицк', 15),
#  ('серпухов', 15),
#  ('дегт', 15),
#  ('иркутск', 15),
#  ('пресвят', 15),
#  ('верст', 14),
#  ('воронежск', 14),
#  ('вещ', 14),
#  ('преображен', 14),
#  ('шест', 14),
#  ('ест', 14),
#  ('что', 14),
#  ('обыкновен', 14),
#  ('торговл', 14),
#  ('москв', 13),
#  ('миргородск', 13),
#  ('малороссийск', 13),
#  ('нижегородск', 13),
#  ('покров', 13),
#  ('желез', 13),
#  ('бол', 13),
#  ('динабург', 13),
#  ('пустын', 13),
#  ('1779', 13),
#  ('изюм', 13),
#  ('небольш', 13),
#  ('за', 13),
#  ('переславл', 12),
#  ('иоан', 12),
#  ('лубенск', 12),
#  ('1778', 12),
#  ('суббот', 12),
#  ('мягк', 12),
#  ('до', 12),
#  ('рухляд', 12),
#  ('начина', 12),
#  ('крымск', 12),
#  ('каширск', 12),
#  ('мелоч', 12),
#  ('волоколамск', 12),
#  ('владимерск', 12),
#  ('к', 12),
#  ('пив', 12),
#  ('кашир', 12),
#  ('преполовен', 12),
#  ('произрастен', 12),
#  ('георг', 11),
#  ('богоявлен', 11),
#  ('покупа', 11),
#  ('сырн', 11),
#  ('скотин', 11),
#  ('7', 11),
#  ('гарусн', 11),
#  ('венев', 11),
#  ('елецк', 11),
#  ('вторник', 11),
#  ('серед', 11),
#  ('дела', 11),
#  ('дню', 11),
#  ('тобольск', 11),
#  ('б', 11),
#  ('бежецк', 11),
#  ('петровск', 11),
#  ('рек', 11),
#  ('одинадцат', 10),
#  ('динабургск', 10),
#  ('недельн', 10),
#  ('светл', 10),
#  ('станиц', 10),
#  ('собира', 10),
#  ('си', 10),
#  ('деревн', 10),
#  ('особлив', 10),
#  ('також', 10),
#  ('производ', 10),
#  ('залеск', 10),
#  ('архангельск', 10),
#  ('отправля', 10),
#  ('говяж', 10),
#  ('ряд', 10),
#  ('полотн', 10),
#  ('нескольк', 9),
#  ('люд', 9),
#  ('крестья', 9),
#  ('деревенск', 9),
#  ('николаевск', 9),
#  ('борисоглебск', 9),
#  ('16', 9),
#  ('нов', 9),
#  ('честн', 9),
#  ('донск', 9),
#  ('здешн', 9),
#  ('1782', 9),
#  ('5', 9),
#  ('крест', 9),
#  ('колес', 9),
#  ('серебрен', 9),
#  ('саратовск', 9),
#  ('знатн', 9),
#  ('стекля', 9),
#  ('володимерск', 9),
#  ('28', 8),
#  ('можайск', 8),
#  ('романов', 8),
#  ('небогат', 8),
#  ('пошехонск', 8),
#  ('калуг', 8),
#  ('ещ', 8),
#  ('17', 8),
#  ('отчин', 8),
#  ('се', 8),
#  ('парч', 8),
#  ('пермск', 8),
#  ('сен', 8),
#  ('бел', 8),
#  ('троицын', 8),
#  ('множеств', 8),
#  ('волост', 8),
#  ('так', 8),
#  ('провинц', 8),
#  ('покупк', 8),
#  ('пряж', 8),
#  ('воскресн', 8),
#  ('железн', 8),
#  ('псков', 8),
#  ('чрез', 8),
#  ('шанец', 8),
#  ('зимн', 8),
#  ('хлебом', 8),
#  ('последн', 8),
#  ('уфимск', 8),
#  ('яренск', 8),
#  ('боровск', 8),
#  ('всеедн', 8),
#  ('мяс', 8),
#  ('некотор', 8),
#  ('миха', 7),
#  ('рогачев', 7),
#  ('переяславск', 7),
#  ('лен', 7),
#  ('тамошн', 7),
#  ('крепост', 7),
#  ('18', 7),
#  ('покровск', 7),
#  ('летн', 7),
#  ('устюжск', 7),
#  ('4', 7),
#  ('деревен', 7),
#  ('постро', 7),
#  ('полтавск', 7),
#  ('позумент', 7),
#  ('воздвижен', 7),
#  ('парусн', 7),
#  ('гор', 7),
#  ('челябинск', 7),
#  ('мног', 7),
#  ('богородицк', 7),
#  ('четверток', 7),
#  ('30', 7),
#  ('сибирск', 7),
#  ('1777', 7),
#  ('ивановск', 7),
#  ('стар', 7),
#  ('сибир', 7),
#  ('двор', 7),
#  ('1781', 7),
#  ('китайск', 7),
#  ('шатск', 7),
#  ('скупа', 7),
#  ('смоленск', 7),
#  ('соседствен', 7),
#  ('', 6),
#  ('приуготовлен', 6),
#  ('городок', 6),
#  ('предтеч', 6),
#  ('поскон', 6),
#  ('гостин', 6),
#  ('табак', 6),
#  ('козельск', 6),
#  ('немецк', 6),
#  ('близост', 6),
#  ('ча', 6),
#  ('дням', 6),
#  ('руз', 6),
#  ('троиц', 6),
#  ('петров', 6),
#  ('продолжающ', 6),
#  ('городк', 6),
#  ('коров', 6),
#  ('пут', 6),
#  ('фомин', 6),
#  ('алексин', 6),
#  ('суздальск', 6),
#  ('архистратиг', 6),
#  ('19', 6),
#  ('кашинск', 6),
#  ('христов', 6),
#  ('мор', 6),
#  ('шерст', 6),
#  ('их', 6),
#  ('купецк', 6),
#  ('параскев', 6),
#  ('рыбн', 6),
#  ('весн', 6),
#  ('крамн', 6),
#  ('прилуцк', 6),
#  ('брат', 6),
#  ('щетин', 6),
#  ('выборгск', 6),
#  ('димитр', 6),
#  ('саранск', 6),
#  ('соб', 5),
#  ('кесов', 5),
#  ('белозерск', 5),
#  ('остров', 5),
#  ('добр', 5),
#  ('щепетильн', 5),
#  ('набойчат', 5),
#  ('церкв', 5),
#  ('пригоня', 5),
#  ('белев', 5),
#  ('состо', 5),
#  ('никольск', 5),
#  ('все', 5),
#  ('пригород', 5),
#  ('тройцын', 5),
#  ('осен', 5),
#  ('сырейн', 5),
#  ('ва', 5),
#  ('27', 5),
#  ('стародубовск', 5),
#  ('работ', 5),
#  ('седьм', 5),
#  ('высок', 5),
#  ('грек', 5),
#  ('ми', 5),
#  ('нужн', 5),
#  ('токм', 5),
#  ('шелк', 5),
#  ('2о', 5),
#  ('всех', 5),
#  ('дважд', 5),
#  ('турецк', 5),
#  ('святител', 5),
#  ('днем', 5),
#  ('пушн', 5),
#  ('росс', 5),
#  ('гадяцк', 5),
#  ('чулк', 5),
#  ('граф', 5),
#  ('борис', 5),
#  ('валуек', 5),
#  ('лавк', 5),
#  ('сыр', 5),
#  ('выбойк', 5),
#  ('сермяжн', 5),
#  ('глинян', 5),
#  ('округ', 5),
#  ('олонецк', 5),
#  ('месяцах', 5),
#  ('новосил', 5),
#  ('сред', 5),
#  ('времен', 5),
#  ('субботн', 5),
#  ('острог', 5),
#  ('коноплян', 5),
#  ('уточн', 5),
#  ('шуб', 5),
#  ('азиатск', 5),
#  ('иногородн', 5),
#  ('богоматер', 5),
#  ('3', 5),
#  ('сахар', 5),
#  ('нежин', 5),
#  ('ежегодн', 5),
#  ('сих', 5),
#  ('четверг', 4),
#  ('суровск', 4),
#  ('1776', 4),
#  ('медн', 4),
#  ('лес', 4),
#  ('вер', 4),
#  ('климовицк', 4),
#  ('те', 4),
#  ('богослов', 4),
#  ('мелочьм', 4),
#  ('молог', 4),
#  ('количеств', 4),
#  ('вольн', 4),
#  ('подобн', 4),
#  ('лисиц', 4),
#  ('пятидесятниц', 4),
#  ('ни', 4),
#  ('керенск', 4),
#  ('ин', 4),
#  ('изюмск', 4),
#  ('пореч', 4),
#  ('недорог', 4),
#  ('мещовск', 4),
#  ('половин', 4),
#  ('сорт', 4),
#  ('собор', 4),
#  ('тутошн', 4),
#  ('осьм', 4),
#  ('благовещенск', 4),
#  ('шу', 4),
#  ('дов', 4),
#  ('городов', 4),
#  ('бывш', 4),
#  ('тихонов', 4),
#  ('вологд', 4),
#  ('сукон', 4),
#  ('великолуцк', 4),
#  ('вает', 4),
#  ('польск', 4),
#  ('заяч', 4),
#  ('иванов', 4),
#  ('ным', 4),
#  ('солен', 4),
#  ('зим', 4),
#  ('тех', 4),
#  ('спас', 4),
#  ('ют', 4),
#  ('бумаг', 4),
#  ('имеют', 4),
#  ('козловск', 4),
#  ('дамиа', 4),
#  ('вощин', 4),
#  ('под', 4),
#  ('торжок', 4),
#  ('уральск', 4),
#  ('михайловк', 4),
#  ('пач', 4),
#  ('четырех', 4),
#  ('пред', 4),
#  ('сам', 4),
#  ('ильинск', 4),
#  ('был', 4),
#  ('бывает', 4),
#  ('1775', 4),
#  ('вятск', 4),
#  ('харьков', 4),
#  ('вар', 4),
#  ('внутрен', 4),
#  ('перед', 4),
#  ('рогачевск', 4),
#  ('холм', 4),
#  ('продукт', 4),
#  ('серебр', 4),
#  ('род', 4),
#  ('сумск', 4),
#  ('посад', 4),
#  ('них', 4),
#  ('нежинск', 4),
#  ('двух', 4),
#  ('приход', 4),
#  ('живоначальн', 4),
#  ('съежа', 4),
#  ('мстиславск', 4),
#  ('поселя', 4),
#  ('им', 4),
#  ('питейн', 4),
#  ('сдела', 4),
#  ('волч', 4),
#  ('лавок', 4),
#  ('економическ', 4),
#  ('лык', 4),
#  ('богоявленск', 4),
#  ('расстоян', 4),
#  ('любимск', 3),
#  ('торгуют', 3),
#  ('евстаф', 3),
#  ('оловя', 3),
#  ('медочн', 3),
#  ('печен', 3),
#  ('новагород', 3),
#  ('дорог', 3),
#  ('армян', 3),
#  ('цвет', 3),
#  ('зимов', 3),
#  ('вод', 3),
#  ('болхов', 3),
#  ('рогож', 3),
#  ('арсамазск', 3),
#  ('славн', 3),
#  ('деньг', 3),
#  ('сторон', 3),
#  ('ген', 3),
#  ('порт', 3),
#  ('происход', 3),
#  ('11', 3),
#  ('област', 3),
#  ('ладон', 3),
#  ('ром', 3),
#  ('хлопчат', 3),
#  ('г', 3),
#  ('вознесенск', 3),
#  ('икр', 3),
#  ('нет', 3),
#  ('торж', 3),
#  ('средин', 3),
#  ('мех', 3),
#  ('отсюд', 3),
#  ('юфт', 3),
#  ('учрежд', 3),
#  ('донковск', 3),
#  ('белк', 3),
#  ('селен', 3),
#  ('водян', 3),
#  ('усекновен', 3),
#  ('где', 3),
#  ('макар', 3),
#  ('туд', 3),
#  ('бы', 3),
#  ('казан', 3),
#  ('суздал', 3),
#  ('звенигородск', 3),
#  ('петербургск', 3),
#  ('канат', 3),
#  ('алексеевск', 3),
#  ('медвеж', 3),
#  ('крамщик', 3),
#  ('торопецк', 3),
#  ('волокопинежск', 3),
#  ('завод', 3),
#  ('столпник', 3),
#  ('катайск', 3),
#  ('касимовск', 3),
#  ('нижн', 3),
#  ('рузск', 3),
#  ('выдр', 3),
#  ('привозн', 3),
#  ('коломенск', 3),
#  ('свин', 3),
#  ('уст', 3),
#  ('цен', 3),
#  ('кашин', 3),
#  ('однажд', 3),
#  ('кропивн', 3),
#  ('соседн', 3),
#  ('саньм', 3),
#  ('сретен', 3),
#  ('прежд', 3),
#  ('девич', 3),
#  ('коломн', 3),
#  ('седмиц', 3),
#  ('москательн', 3),
#  ('озер', 3),
#  ('22', 3),
#  ('хмел', 3),
#  ('полож', 3),
#  ('устюг', 3),
#  ('каждогодн', 3),
#  ('ростов', 3),
#  ('кинешм', 3),
#  ('куниц', 3),
#  ('богомол', 3),
#  ('ве', 3),
#  ('господ', 3),
#  ('норск', 3),
#  ('кирил', 3),
#  ('ярославц', 3),
#  ('великомучениц', 3),
#  ('муромск', 3),
#  ('верхн', 3),
#  ('назад', 3),
#  ('княз', 3),
#  ('товаров', 3),
#  ('подл', 3),
#  ('дмитровск', 3),
#  ('тут', 3),
#  ('р', 3),
#  ('немал', 3),
#  ('отпуска', 3),
#  ('баран', 3),
#  ('успенск', 3),
#  ('отвоз', 3),
#  ('алатырьск', 3),
#  ('сапог', 3),
#  ('единожд', 3),
#  ('глав', 3),
#  ('прокоп', 3),
#  ('краснослободск', 3),
#  ('межд', 3),
#  ('белицк', 3),
#  ('1784', 3),
#  ('петербург', 3),
#  ('10', 3),
#  ('ивановк', 3),
#  ('камк', 3),
#  ('воронеж', 3),
#  ('трех', 3),
#  ('имеет', 3),
#  ('галицк', 3),
#  ('*', 3),
#  ('13', 3),
#  ('разночинц', 3),
#  ('вином', 3),
#  ('вся', 3),
#  ('девя', 3),
#  ('наход', 3),
#  ('ме', 3),
#  ('оттуд', 3),
#  ('рыбинск', 3),
#  ('китайк', 3),
#  ('золот', 3),
#  ('12', 3),
#  ('лучш', 3),
#  ('косм', 3),
#  ('ан', 3),
#  ('залесн', 3),
#  ('симеон', 3),
#  ('кос', 3),
#  ('александровск', 2),
#  ('короченск', 2),
#  ('богородск', 2),
#  ('заморск', 2),
#  ('домашн', 2),
#  ('гвозд', 2),
#  ('подобным', 2),
#  ('свиажск', 2),
#  ('вещм', 2),
#  ('лошадин', 2),
#  ('поташ', 2),
#  ('лебедин', 2),
#  ('камен', 2),
#  ('мглин', 2),
#  ('сергиевск', 2),
#  ('тюмен', 2),
#  ('1783', 2),
#  ('кошеч', 2),
#  ('бобр', 2),
#  ('пол', 2),
#  ('важн', 2),
#  ('сторожевск', 2),
#  ('зубцов', 2),
#  ('кушак', 2),
#  ('поселян', 2),
#  ('васил', 2),
#  ('белокурин', 2),
#  ('пря', 2),
#  ('произрастан', 2),
#  ('звер', 2),
#  ('стан', 2),
#  ('городищ', 2),
#  ('дел', 2),
#  ('гремяч', 2),
#  ('ска', 2),
#  ('прост', 2),
#  ('кра', 2),
#  ('вычегодск', 2),
#  ('ворва', 2),
#  ('про', 2),
#  ('куд', 2),
#  ('опочек', 2),
#  ('сельц', 2),
#  ('приморск', 2),
#  ('цар', 2),
#  ('бык', 2),
#  ('веневск', 2),
#  ('конск', 2),
#  ('белевск', 2),
#  ('уез', 2),
#  ('енисейск', 2),
#  ('вь', 2),
#  ('промысл', 2),
#  ('купеческ', 2),
#  ('вял', 2),
#  ('домов', 2),
#  ('вышгород', 2),
#  ('краснопол', 2),
#  ('семик', 2),
#  ('глинск', 2),
#  ('деркул', 2),
#  ('костром', 2),
#  ('тотемск', 2),
#  ('кумач', 2),
#  ('вытегр', 2),
#  ('вразсужден', 2),
#  ('чег', 2),
#  ('кле', 2),
#  ('дров', 2),
#  ('град', 2),
#  ('краск', 2),
#  ('малоросс', 2),
#  ('грезет', 2),
#  ('рук', 2),
#  ('карачев', 2),
#  ('живущ', 2),
#  ('учрежден', 2),
#  ('свинск', 2),
#  ('человек', 2),
#  ('уф', 2),
#  ('михайл', 2),
#  ('рог', 2),
#  ('борзн', 2),
#  ('та', 2),
#  ('сызран', 2),
#  ('рязан', 2),
#  ('мен', 2),
#  ('иван', 2),
#  ('уклад', 2),
#  ('туринск', 2),
#  ('дал', 2),
#  ('десн', 2),
#  ('форпост', 2),
#  ('ближ', 2),
#  ('тот', 2),
#  ('крестител', 2),
#  ('волхов', 2),
#  ('отпуск', 2),
#  ('ярополч', 2),
#  ('языков', 2),
#  ('голландск', 2),
#  ('оклад', 2),
#  ('штоф', 2),
#  ('островск', 2),
#  ('возвраща', 2),
#  ('переяславл', 2),
#  ('бож', 2),
#  ('росссийск', 2),
#  ('ливенск', 2),
#  ('курмышск', 2),
#  ('дубровк', 2),
#  ('произведен', 2),
#  ('алекс', 2),
#  ('епифан', 2),
#  ('башкирц', 2),
#  ('настоя', 2),
#  ('лежнев', 2),
#  ('иноверц', 2),
#  ('тафт', 2),
#  ('починк', 2),
#  ('пупк', 2),
#  ('марш', 2),
#  ('арзамаск', 2),
#  ('хован', 2),
#  ('веревк', 2),
#  ('ток', 2),
#  ('квасц', 2),
#  ('храмов', 2),
#  ('погромц', 2),
#  ('крашен', 2),
#  ('речк', 2),
#  ('стратилатовск', 2),
#  ('брянск', 2),
#  ('киренск', 2),
#  ('упадк', 2),
#  ('иосиф', 2),
#  ('васильевск', 2),
#  ('дегот', 2),
#  ('чухлом', 2),
#  ('ординарн', 2),
#  ('мелочм', 2),
#  ('дерпт', 2),
#  ('прежн', 2),
#  ('исключ', 2),
#  ('черлянков', 2),
#  ('тюртен', 2),
#  ('привозят', 2),
#  ('когд', 2),
#  ('самар', 2),
#  ('европейск', 2),
#  ('ближайш', 2),
#  ('пятницк', 2),
#  ('сряд', 2),
#  ('сетк', 2),
#  ('замк', 2),
#  ('повсягодн', 2),
#  ('отъезжа', 2),
#  ('образ', 2),
#  ('базар', 2),
#  ('молодов', 2),
#  ('нын', 2),
#  ('след', 2),
#  ('введен', 2),
#  ('аврам', 2),
#  ('колп', 2),
#  ('го', 2),
#  ('промышленник', 2),
#  ('городн', 2),
#  ('мученик', 2),
#  ('россиа', 2),
#  ('напитк', 2),
#  ('уразов', 2),
#  ('галантерейн', 2),
#  ('впроч', 2),
#  ('корабл', 2),
#  ('ском', 2),
#  ('алексинск', 2),
#  ('оршанск', 2),
#  ('подворгальск', 2),
#  ('дворянств', 2),
#  ('колюпановк', 2),
#  ('средн', 2),
#  ('нетокм', 2),
#  ('донков', 2),
#  ('овц', 2),
#  ('рамен', 2),
#  ('л', 2),
#  ('принадлежа', 2),
#  ('рыльск', 2),
#  ('оренбург', 2),
#  ('новгородск', 2),
#  ('барышевк', 2),
#  ('намерен', 2),
#  ('кавказск', 2),
#  ('воскресенск', 2),
#  ('ком', 2),
#  ('калмык', 2),
#  ('риг', 2),
#  ('козак', 2),
#  ('границ', 2),
#  ('одиножд', 2),
#  ('аргамач', 2),
#  ('мещан', 2),
#  ('чуж', 2),
#  ('кадом', 2),
#  ('ту', 2),
#  ('построен', 2),
#  ('холстом', 2),
#  ('николин', 2),
#  ('гороховецк', 2),
#  ('михайловск', 2),
#  ('мезенск', 2),
#  ('стран', 2),
#  ('черн', 2),
#  ('звенигород', 2),
#  ('пятидесят', 2),
#  ('алексеевк', 2),
#  ('од', 2),
#  ('шапк', 2),
#  ('савин', 2),
#  ('кубенск', 2),
#  ('лет', 2),
#  ('орл', 2),
#  ('липецк', 2),
#  ('пром', 2),
#  ('ежедневн', 2),
#  ('пятничн', 2),
#  ('екатерин', 2),
#  ('яблунев', 2),
#  ('миргород', 2),
#  ('калмыцк', 2),
#  ('сийск', 2),
#  ('ярмарочн', 2),
#  ('достопамятн', 2),
#  ('оскол', 2),
#  ('симеоновск', 2),
#  ('похвальн', 2),
#  ('бронниц', 2),
#  ('хрящев', 2),
#  ('яр', 2),
#  ('ревел', 2),
#  ('состоя', 2),
#  ('ичн', 2),
#  ('ям', 2),
#  ('нич', 2),
#  ('марк', 2),
#  ('брусков', 2),
#  ('щепетин', 2),
#  ('екатеринбургск', 2),
#  ('беркунов', 2),
#  ('ста', 2),
#  ('помещик', 2),
#  ('ефремов', 2),
#  ('ямпол', 2),
#  ('платк', 2),
#  ('парск', 2),
#  ('производят', 2),
#  ('часовн', 2),
#  ('спаск', 2),
#  ('слывет', 2),
#  ('сух', 2),
#  ('хот', 2),
#  ('петропавловск', 2),
#  ('белогородск', 2),
#  ('получа', 2),
#  ('горшк', 2),
#  ('игл', 2),
#  ('шведск', 2),
#  ('алешн', 2),
#  ('ветк', 2),
#  ('руск', 2),
#  ('карпов', 2),
#  ('различн', 2),
#  ('глеб', 2),
#  ('екатеринбург', 2),
#  ('варвар', 2),
#  ('свеж', 2),
#  ('полушелков', 2),
#  ('доск', 2),
#  ('темниковск', 2),
#  ('пятницам', 2),
#  ('юрьев', 2),
#  ('конотоп', 2),
#  ('довольн', 2),
#  ('крапивн', 2),
#  ('поводнев', 2),
#  ('смежн', 2),
#  ('мясоед', 2),
#  ('санда', 2),
#  ('быв', 2),
#  ('хрящ', 2),
#  ('щепет', 2),
#  ('шипин', 2),
#  ('че', 2),
#  ('жу', 2),
#  ('обод', 2),
#  ('нагольн', 2),
#  ('ем', 2),
#  ('муриков', 2),
#  ('прилук', 2),
#  ('потребн', 2),
#  ('лужк', 2),
#  ('коф', 2),
#  ('миропол', 2),
#  ('рост', 2),
#  ('п', 2),
#  ('лебедян', 2),
#  ('ахтырк', 2),
#  ('сте', 2),
#  ('медк', 1),
#  ('балакле', 1),
#  ...]

# %%
top50 = [p[0] for p in nltk.FreqDist(stopped_text).most_common()][:50]

# %%
top50
# Out:
# ['товар',
#  'купц',
#  'торг',
#  'разн',
#  'мелочн',
#  'приезжа',
#  'июл',
#  'шелков',
#  'хлеб',
#  'июн',
#  'сентябр',
#  'вин',
#  'крестьян',
#  'припас',
#  'скот',
#  'съестн',
#  'бумажн',
#  'ма',
#  'российск',
#  'октябр',
#  'пасх',
#  'генвар',
#  'холст',
#  'посуд',
#  'горяч',
#  'деревя',
#  'тог',
#  'продолжа',
#  'част',
#  'богородиц',
#  'кож',
#  '15',
#  'дни',
#  'харьковск',
#  'крестьянск',
#  'сег',
#  'от',
#  'екатеринославск',
#  'близ',
#  'уездн',
#  'ближн',
#  'ил',
#  'велик',
#  'пеньк',
#  'мед',
#  'прочим',
#  'прода',
#  'свят',
#  'рыб',
#  'торжк']

# %%
[reverse_stem[w][0] for w in top50]
# Out:
# ['товарам',
#  'купцы',
#  'торгов',
#  'разных',
#  'мелочным',
#  'приезжающие',
#  'Июле',
#  'шелковые',
#  'хлеб',
#  'Июне',
#  'Сентябри',
#  'винной',
#  'крестьянами',
#  'припасы',
#  'скотом',
#  'съестным',
#  'бумажная',
#  'Маия',
#  'Российскими',
#  'Октябрь',
#  'Пасхи',
#  'Генваря',
#  'холст',
#  'посудою',
#  'горячого',
#  'деревянную',
#  'того',
#  'продолжающаяся',
#  'Часть',
#  'Богородице',
#  'кожи',
#  '15',
#  'Дни',
#  'Харьковского',
#  'крестьянским',
#  'сего',
#  'от',
#  'Екатеринославского',
#  'близъ',
#  'уездный',
#  'ближних',
#  'или',
#  'великое',
#  'пеньку',
#  'мед',
#  'прочимъ',
#  'продают',
#  'СВЯТОЕ',
#  'рыбою',
#  'торжков']

# %%
reverse_stem["купц"]
# Out:
# ['купцы', 'купцов', 'купцам', 'Купцы', 'купцами']

# %%
ortho_rules("Холмогорскіе",lookup_dict)
# Out:
# 'Холмогорские'

# %%
text.concordance("купцы")
# Out:
# Displaying 25 of 331 matches:
#  есть Июля 30 , на которую приезжают купцы и крестьяне с мелочными товарами . А
# арка , , на коей торгуют Вологодские купцы мелочными товарами . АВРАМИЕВ , мона
# в , в одинадцатую пятницу по Пасхе ; купцы сюда приезжают из ближних городов с
# стратига Михаила . На оные приезжают купцы из разных Российских городов с шелко
# ля покупки сего приезжают Российские купцы , и привозят с собою всякие мелочные
# т на оную из разных городов и уездов купцы , шелк , бумагу красную и писную , ,
#  которую привозят изЬ разных городов купцы мелочные и прочие това - ры ; торг п
# варами из Москвы и из других городов купцы , такожь и крестьяне . САСОВО , село
# Иоанна Богослова ; приеэжают на оные купцы из разных Российских городов с шелко
#  - ста 30 . Сюда для торгу приезжают купцы из разных Российских городов с шелко
# еславля Залеского , Углича приезжают купцы с мелочными всякими небогатыми товар
# я главы Предтечи ; приезжают на оные купцы из разных Российских городов с шелко
#  которые съезжаются из окольных мест купцы с красны - ни и другими мелочными то
# рвая в Июне , , вторая в Октябре ; ; купцы приезжают на оные из Пскова с разным
# оября 21 , шестая на Сырной неделе . Купцы приезжают на оные из окрестных город
# аются из Новагорода и из Старой Рузы купцы с разными шелковым мелочными товарам
# , , Малороссийские жители ; а Руские купцы из разных городов привозит всякие ме
# езжают и из Великороссийских городов купцы с красными товарами . Здесь бывают и
# у после Пасхи , на которую приезжают купцы из ближних городов с мелочным товаро
# есвятые Богородицы ; товары привозят купцы из Новагорода и из Торопца всякие мо
# ярмарка в Июне месяце ; ; съезжаются купцы с разными товарами из ближних городо
# ает в году ярмарка в Июне месяце ; ; купцы приезжают из близ лежащих городов с
# орая Сентября 6 , третия Декабря 4 . Купцы на оные приезжают из ближайших город
# рмарка в году , на которую приезжают купцы из ближних городовъ СТАРИНСКОЕ , сел
# атные ярмарки , на которые приезжают купцы и из Малороссии . СТАРОЙ ОСКОЛ , с 1

# %%
trade_areas = list(set(re.findall(r"([А-Яа-я]+ские)",fulltext)))
trade_areas.sort()

# %%
re.findall(r"((?:, )?[А-Яа-я]+ские)*(?: и )?([А-Яа-я]+ские) купцы",fulltext)
# Out:
# [('', 'Вологодские'),
#  ('', 'Российские'),
#  ('', 'Руские'),
#  ('', 'Российские'),
#  ('', 'Вологодские'),
#  ('Курские', 'Старооскольские'),
#  ('', 'Великороссийские'),
#  ('', 'Великороссийские'),
#  ('Устюжские', 'Тотемские'),
#  ('', 'Российские'),
#  ('', 'Великороссийские'),
#  ('', 'Великороссийские'),
#  ('', 'Великороссийские'),
#  ('', 'Великороссийские'),
#  ('', 'Российские'),
#  ('', 'Тобольские'),
#  ('', 'Великороссийские'),
#  ('', 'Великороссийские'),
#  ('Архангельские', 'Холмогорские'),
#  ('', 'Великороссийские'),
#  ('', 'Великороссийские'),
#  ('', 'Российские'),
#  ('', 'Российские'),
#  ('Романовские', 'Вологодские'),
#  ('Великороссийские', 'Малороссийские'),
#  ('', 'Псковские'),
#  ('', 'устюжские'),
#  ('', 'Российские'),
#  ('', 'Вологодские'),
#  ('', 'Вологодские'),
#  ('', 'Рыльские'),
#  ('', 'Великороссийские'),
#  ('', 'Муромские'),
#  ('Великороссийские', 'Малороссийские'),
#  ('', 'Великороссийские'),
#  ('', 'Азиатские'),
#  ('', 'Великороссийские'),
#  ('', 'Зарайские'),
#  ('', 'Московские'),
#  ('', 'Великороссийские')]

# %%
text.concordance(trade_areas[4],width=179)
# Out:
# Displaying 7 of 7 matches:
# дского Наместничества и уезду Здесь бывает два раза в год ярмарка , на коей торгуют Вологодские купцы мелочными товарами . АВРАМИЕВ монастырь Костромского Наместничества от города
# естничества и уезду При оном монастыре бывает в году три ярмарки на которых торгуют Вологодские купцы разными мелочными товарами . ТАМБОВ с 1779 году главный город Наместничества
# собливая бывает ярмарка называемая Ивановская Заозерская на которой бывают нетолько Вологодские но и Московские Устюжские и Тотемские купцы для покупки полотен холстов сукон сермя
# ряды На сих ярмарках Московские Ярославские , Костромские , Любимские Романовские и Вологодские купцы бывают из коих некоторые привозят шелковые гарусные бумажные москотильные и п
#  что на Синге в Вологодском уезде Здесь бывает в году две ярмарки ; на оных торгуют Вологодские купцы мелочными товарами . ЛИХВИН , город Калужского Наместничества В оном бывает о
# рмарка . ЛОПОТОВ монастырь в Вологодском уезде Здесь бывает однажды в год ярмарка ; Вологодские купцы торгуют на оной мелочными то варами . ЛОТСШИНО село Тверского Наместничества
# одна в году ярмарка в Июне месяце на Рождество Иоанна Предтечи Сюда приезжают купцы Вологодские Устюжские и Тотемские для покупки холстов и продажи разных мелочных товаровъ . ПЕТР

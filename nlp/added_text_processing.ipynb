# %% [markdown]
# Beginning of additional text processing
# =======================================
# This is to extract information unrelated to geocoding

# %%
import pandas as pd
import numpy as np
import time, re, json, requests, os, nltk

# %%
ru_stemmer = nltk.stem.SnowballStemmer('russian')

# %%
import os
def Ensure_dir(d):
    """Makes sure a directory 'd' exists, and if it doesn't, it creates one."""
    if not os.path.exists(d):
        os.makedirs(d)
    return 0

# %%
import re,json
from lxml import html

with open("../resources/special_cases.json",'r',encoding='utf-8') as fp:
    lookup_dict = json.load(fp)

def ortho_rules(text,lookup_dict):
    """
    Takes a text string and a lookup dict as input
    Removes any lingering html tags
    Breaks the string down into component words with split
    Uses replacements to modernize orthography
    Returns re-assembled text with modern orthography
    """
    if type(text)==str:
        text = html.fromstring(text).text_content()
        textlist = text.split(' ')
        out_list = []
        for word in textlist:
            if word in [',','.',';',':']:
                out_list.append(word)
                continue
            punct = ""
            if len(re.findall(r"([,.;:])$",word))!=0:
                   punct = re.findall(r"([,.;:])$",word)[0]
            word = word.strip(',.;:')
            if word in lookup_dict:
                word = lookup_dict[word]
                out_list.append(word)
            else:
                word = re.sub("[Ъъ]$",'',word)
                word = re.sub(r"^([че]{0,2}[ч]?[вбнр]?[веоаи])з([ПФКТШСЧпфктшсч])",r"\1с\2",word,re.IGNORECASE)
                word = re.sub("аго$","ого",word,re.IGNORECASE)
                word = re.sub("яго$","его",word,re.IGNORECASE)
                word = re.sub("ыя$","ые",word,re.IGNORECASE)
                word = re.sub("iя$","ие",word,re.IGNORECASE)
                word = word.replace('i','и') #english
                word = word.replace('I','И') #english
                word = word.replace('і','и') #cyrillic
                word = word.replace('І','И') #cyrillic
                word = word.replace('Ѣ','Е')
                word = word.replace('ѣ','е')
                word = word.replace('Ѳ','Ф')
                word = word.replace('ѳ','ф')
                word += punct
                out_list.append(word)
        out_str = ' '.join(out_list)
        return out_str
    else:
        return None

# %%
market_df = pd.DataFrame.from_csv("../output/process/no_geo.csv")
db = json.loads(market_df.to_json(orient='index'))

# %%
for i in db:
    txt = db[i]['description']
    db[i]['description_new_orth'] = ortho_rules(txt,lookup_dict)

# %%
def ru_lang_to_list(liststr):
    """
    takes a list of strings which may themselves be natural language lists in Russian
    Returns list of items in list strings, flattened
    """
    liststr = [a.split(' и ') for a in liststr]
    liststr = [item for sublist in liststr for item in sublist]
    liststr = [a.split(',') for a in liststr]
    liststr = [item for sublist in liststr for item in sublist]
    liststr = [a.strip() for a in liststr]
    liststr = [a for a in liststr if len(a)!=0]
    return liststr

# %%
def word_case_sent_finder(wordlist, case_exp, text):
    """
    Finds all words matching case_exp in sentences containing words in wordlist that appear in text
    """
    sent = nltk.tokenize.sent_tokenize(text)
    sent_tok = [nltk.tokenize.wordpunct_tokenize(text)]
    returnlist = []
    for s in sent_tok:
        if any([v in s for v in wordlist]):
            for w in s:
                match = re.match(case_exp,w)
                if match:
                    returnlist.append(match.string)
    return returnlist

# %% [markdown]
# Where are the goods and merchants coming from?
# ==============================================
# This section looks for geographic relationships between the town in the entry and named towns that serve as trade partners.

# %%
for i in db:
    txt = db[i]['description_new_orth']
    merch_adj = {}
    #merch_adj finds sequences of words ending in "ские" appearing in sentences that also contain "купцы," or some variation thereof
    #That is, it finds adjectives describing merchants, which in this text, means describing their geographic origins.
    merch_adj1 = word_case_sent_finder(['купцам','Купцы','купцы','купцами','купцов','купечество'], r"[А-Яа-я]+[цс]кие", txt)
    if len(merch_adj1)!=0:
        merch_adj[1]=merch_adj1
    #merch_adj2 just finds all of the different ways of saying "merchants from nearby towns"
    #by finding all words between "купцы из" and "городов"
    merch_adj2 = re.findall(r"из\s+((?:[а-яА-Я,]+\s+)*?(?:городов|мест|с|;|всякие|всякой|малому|привозят|еженедельно|разной) )",txt)
    merch_adj2 = [a.strip() for a in merch_adj2]
    merch_adj2 = [re.sub(r"(?:с|;|всякие|всякой|малому|привозят|еженедельно|разной)$","",a) for a in merch_adj2]
    merch_adj2 = ru_lang_to_list(merch_adj2)
    merch_adj2 = [re.sub(r"^из ","",a) for a in merch_adj2]
    if len(merch_adj2)!=0:
        merch_adj[2]=merch_adj2
    #merch_adj.extend(merch_adj2)
    #merch_adj3 finds instances of merchants from named towns
    #by finding words that come between "купцы из" and "с", and removing those phrases that end in городов or части
    #it then separates out the individual towns, similar to merch_adj
    #merch_adj3 = re.findall(r"(?:купцам|Купцы|купцы|купцами|купцов|купечество)\s+из\s+((?:[а-яА-Я,]+\s+)*?)(?:с|;) ",txt)
    #merch_adj3 = [t.strip() for t in merch_adj3]
    #merch_adj3 = [t for t in merch_adj3 if len(re.findall(r"(?:городов|части)$",t))==0]
    #merch_adj3 = ru_lang_to_list(merch_adj3)
    #merch_adj.extend(merch_adj3)
    #merch_adj4 finds lists of towns from the style "from towns... came merchants", which occurs rarely
    merch_adj4 = re.findall(r"из\s+((?:(?!из)[А-Яа-я,]+\s+)*)(?:купцам|Купцы|купцы|купцами|купцов|купечество)",txt)
    merch_adj4 = ru_lang_to_list(merch_adj4)
    merch_adj4 = [re.sub(r" приезжают$","",a) for a in merch_adj4]
    merch_adj4 = [re.sub(r"^городов ","",a) for a in merch_adj4]
    if len(merch_adj4)!=0:
        merch_adj[4]=merch_adj4
    #merch_adj.extend(merch_adj4)
    if len(merch_adj) != 0:
        db[i]['merchants_from'] = merch_adj

# %%
word_case_sent_finder(['купцам','Купцы','купцы','купцами','купцов','купечество'], r"[А-Яа-я]+[цс]кие", db['315']['description_new_orth'])
# Out:
# []

# %%
counter = 0
for i in db:
    if 'merchants_from' in db[i]:
        counter+=1
        print(db[i]['txt_id'],db[i]['merchants_from'])
# Out:
# 725 {2: ['ближних городов']}
# 393 {1: ['Курские', 'Севские', 'Рыльские']}
# 314 {2: ['здешнего', 'других уездов крестьянство']}
# 675 {2: ['разных Российских городов']}
# 53 {2: ['городов']}
# 636 {2: ['Новагорода', 'Старой Рузы купцы'], 4: ['Старой Рузы']}
# 421 {2: ['городов'], 4: ['городов']}
# 336 {2: ['разных Российских городов']}
# 724 {2: ['Болхова', 'Белева', 'других городов']}
# 660 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 196 {4: ['ближних город в']}
# 214 {2: ['Пскова']}
# 551 {2: ['уездов обыватели']}
# 682 {2: ['окрестных ближних городов']}
# 292 {2: ['ближайших городов']}
# 420 {2: ['разных городов']}
# 200 {2: ['лежащих городов']}
# 694 {2: ['ближних деревень']}
# 601 {2: ['разных городов'], 4: ['разных городов', 'уездов']}
# 29 {2: ['разных городов']}
# 380 {2: ['ближних городов'], 4: ['ближних городов']}
# 287 {2: ['уезду холсты льняные разные', 'да из городов']}
# 218 {2: ['окрестных городов']}
# 647 {2: ['ближних городов']}
# 795 {2: ['разных городов']}
# 158 {2: ['окольных городов']}
# 379 {2: ['разных Российских городов']}
# 680 {2: ['ближних городов']}
# 397 {2: ['ближних городов'], 4: ['ближних городов']}
# 254 {2: ['разных городов']}
# 7 {2: ['ближних городов']}
# 388 {2: ['Великороссийских', 'Малороссийских городов']}
# 120 {2: ['соседственных городов']}
# 591 {2: ['окрестных городов']}
# 328 {2: ['окрестных мест']}
# 257 {2: ['близ лежащих городов']}
# 142 {2: ['разных городов'], 4: ['разных городов']}
# 117 {1: ['Архангельские', 'Холмогорские']}
# 299 {2: ['других уездов', 'некоторых окрестных городов']}
# 173 {2: ['ближних городов']}
# 561 {2: ['соседних городов']}
# 454 {1: ['Муромские'], 2: ['других городов']}
# 216 {2: ['близ лежащих городов']}
# 716 {2: ['Воронежа', 'Ельца', 'Липецка']}
# 458 {2: ['Каширы', 'Тулы', 'Серпухова', 'Венева', 'Зарайска по']}
# 629 {2: ['окольных мест'], 4: ['окольных мест']}
# 81 {2: ['прочих городов']}
# 668 {2: ['окрестных городов']}
# 618 {2: ['разных Российских городов']}
# 550 {2: ['близ лежащих городов']}
# 435 {2: ['Пскова']}
# 396 {2: ['окольных мест']}
# 531 {2: ['разных городов']}
# 736 {1: ['Российские']}
# 49 {2: ['Каширы', 'а по близости из Тулы', 'Серпухова', 'Венева', 'Зарайска', 'по']}
# 68 {2: ['других городов']}
# 790 {2: ['близ лежащих городов']}
# 778 {2: ['уездов обыватели']}
# 791 {2: ['близ лежащих городов']}
# 592 {2: ['окольных мест']}
# 298 {1: ['Российские']}
# 225 {2: ['окольных городов'], 4: ['окольных городов']}
# 319 {2: ['окольных разных городов']}
# 702 {2: ['разных Российских городов']}
# 300 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 42 {2: ['Каширы', 'а по близости из Тулы', 'Серпухова', 'Венева', 'Зарайска по']}
# 416 {2: ['разных Российских городов']}
# 428 {2: ['ближних Великороссийских городов']}
# 661 {2: ['близ лежащих городов']}
# 424 {2: ['разных городов'], 4: ['разных городов']}
# 87 {2: ['разных Российских городов'], 4: ['разных Российских городов']}
# 709 {2: ['уезду съезжается крестьянство'], 4: ['Углича', 'Кашина', 'Бежецка']}
# 124 {2: ['окольных мест']}
# 604 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 719 {1: ['Вологодские', 'Московские', 'Устюжские', 'Тотемские']}
# 64 {2: ['ближних городов'], 4: ['ближних городов']}
# 505 {2: ['Пскова']}
# 685 {1: ['Курские', 'Старооскольские']}
# 692 {2: ['окрестных городов']}
# 761 {2: ['ближних городов']}
# 541 {1: ['Елецкие']}
# 372 {1: ['устюжские']}
# 779 {1: ['Великороссийские']}
# 208 {2: ['ближних городов']}
# 615 {2: ['уезду холсты льняные разные', 'да из городов'], 4: ['Ярославля', 'Переславля Залеского', 'Углича']}
# 304 {2: ['разных городов']}
# 190 {2: ['разных ближиих городов']}
# 554 {2: ['ближних городов'], 4: ['ближних городов']}
# 698 {2: ['разных Великороссийских городов'], 4: ['разных Великороссийских городов']}
# 599 {1: ['Российские']}
# 752 {2: ['Пскова']}
# 419 {2: ['разных Российских городов']}
# 74 {2: ['города Свинская', 'начинающаяся']}
# 272 {2: ['разных Российских городов']}
# 135 {2: ['городов']}
# 407 {2: ['Боровска', 'Вереи', 'Серпухова']}
# 70 {2: ['разных Российских городов']}
# 515 {1: ['Зарайские'], 2: ['уездов обыватели']}
# 797 {2: ['близ лежащих городов']}
# 800 {1: ['Великороссийские']}
# 234 {1: ['Российские']}
# 602 {2: ['разных городов'], 4: ['разных городов']}
# 771 {2: ['разных Российских городов']}
# 662 {2: ['уезду', 'холсты льняные разные', 'да из городов'], 4: ['Ярославля', 'Переславля Залеского', 'Углича']}
# 606 {2: ['разных Российских городов']}
# 673 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 793 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 17 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 285 {2: ['прочих городов']}
# 128 {1: ['Торопецкие']}
# 308 {2: ['ближних Малороссийских городов']}
# 478 {1: ['Великороссийские', 'Малороссийские']}
# 198 {2: ['Пскова']}
# 512 {2: ['разных городов']}
# 127 {2: ['разных мест']}
# 316 {1: ['Московские', 'Ярославские', 'Костромские', 'Любимские', 'Романовские', 'Вологодские'], 2: ['коих некоторые', 'Вологодского', 'Галицкого', 'Любимского', 'Костромского', 'Ярославского', 'Пошехонского уездов большее число со льняным', 'хрящевым холстом']}
# 330 {2: ['разных Российских городов']}
# 533 {2: ['близ лежащих городов']}
# 582 {1: ['Великороссийские', 'Малороссийские']}
# 769 {2: ['Москвы', 'других городов'], 4: ['других городов']}
# 65 {2: ['разных окольных городов'], 4: ['разных окольных городов']}
# 584 {2: ['Ярославля', 'Переяславля Залеского', 'Москвы', 'Вологды', 'Ярославля', 'города Кинешмы', 'слобод Макарья', 'Пуреха', 'Муромского', 'Касимовского уездов', 'Пошехонского', 'устюжского уездов']}
# 635 {2: ['разных мест']}
# 15 {2: ['разных Росссийских городов']}
# 255 {2: ['уезда холсты льняные разные', 'да из городов'], 4: ['Ярославля', 'Переславля Залесного', 'Углича']}
# 321 {2: ['уезду холсты льняные разные', 'да из городов'], 4: ['Ярославля', 'Переславля Залеского', 'Углича']}
# 653 {2: ['Новагорода', 'Торопца']}
# 241 {2: ['Нежина', 'Борзны', 'Конотопу', 'Ични']}
# 10 {2: ['близ лежащих городов']}
# 464 {2: ['близ лежащих городов']}
# 185 {2: ['близ лежащих мест'], 4: ['близ лежащих мест']}
# 107 {2: ['разных привозимых из Иркутска', 'других городов'], 4: ['Иркутска', 'других городов']}
# 188 {1: ['Российские'], 2: ['Риги', 'Ревеля', 'ближних Российских городов'], 4: ['ближних Российских городов привозят']}
# 281 {2: ['уезду холсты льняные разные', 'да из города Ярославля', 'Переславля Залеского', 'Углича купцы приезжают'], 4: ['города Ярославля', 'Переславля Залеского', 'Углича']}
# 116 {2: ['разных городов']}
# 163 {2: ['уезду холсты льняные разные', 'да из городов'], 4: ['Ярославля', 'Переславля Залеского', 'Углича']}
# 310 {4: ['приезжих']}
# 373 {2: ['кирок Чухны']}
# 131 {2: ['уезду холсты льняные разные', 'да из городов']}
# 93 {2: ['окрестных городов']}
# 39 {1: ['Тобольские']}
# 472 {2: ['Великороссийских', 'Малороссийских городов']}
# 244 {2: ['Каширы', 'Тулы', 'Серпухова', 'Веневы', 'Зарайска по']}
# 223 {2: ['окрестных городов']}
# 359 {4: ['Сибири']}
# 684 {1: ['Елецкие']}
# 35 {2: ['ближних мест']}
# 427 {1: ['Великороссийские']}
# 115 {2: ['разных мест']}
# 425 {2: ['окрестных городов']}
# 363 {2: ['разных городов']}
# 69 {2: ['Тулы', 'Калуги', 'Серпухова', 'прочих городов']}
# 18 {1: ['Елецкие']}
# 432 {2: ['близ лежащих городов']}
# 24 {1: ['Российские']}
# 707 {1: ['Великороссийские']}
# 323 {1: ['Российские']}
# 166 {1: ['Великороссийские']}
# 231 {2: ['ближних городов']}
# 151 {2: ['близ лежащих городов']}
# 345 {2: ['ближних городов']}
# 205 {2: ['разных городов']}
# 267 {2: ['ближних городов']}
# 681 {2: ['разных городов']}
# 589 {2: ['Ярославля', 'Романова', 'Углича', 'сел']}
# 524 {2: ['близ лежащих уездов крестьянство']}
# 528 {1: ['Елецкие']}
# 751 {2: ['близ лежащих городов']}
# 669 {1: ['Российские']}
# 4 {1: ['Вологодские']}
# 156 {2: ['Ярославля', 'Романова', 'Углича', 'Борисоглебска', 'Рыбного', 'изъсел']}
# 374 {2: ['близ лежащих городов']}
# 209 {2: ['которых в одном торгуют сестными припасами', 'а в другом в бывающий', 'Коломны', 'разных деревень']}
# 315 {2: ['Алексина']}
# 79 {2: ['близ лежащих городов']}
# 643 {2: ['Великороссийских городов'], 4: ['Великороссийских городов']}
# 555 {2: ['прикосновенных городов']}
# 273 {2: ['окольных мест']}
# 666 {2: ['соседственных городов']}
# 579 {2: ['окрестных городов']}
# 201 {2: ['окрестных городов']}
# 501 {1: ['Великороссийские']}
# 638 {1: ['Малороссийские', 'Руские'], 2: ['разных городов']}
# 375 {1: ['Российские'], 4: ['разных городов', 'Российские']}
# 571 {2: ['разных городов']}
# 801 {2: ['Низовых же городов']}
# 474 {2: ['соседственных городов'], 4: ['соседственных городов']}
# 520 {2: ['близ лежащих городов']}
# 718 {1: ['Великороссийские']}
# 583 {2: ['окольных мест'], 4: ['окольных мест']}
# 238 {2: ['близ лежащих городов']}
# 780 {2: ['разных мест'], 4: ['разных мест сбираются']}
# 410 {2: ['ближних городов']}
# 548 {1: ['Великороссийские', 'Малороссийские'], 4: ['всей Турецкой области']}
# 335 {2: ['близ лежащих городов']}
# 637 {2: ['уездов разных Помещиков крестьяне']}
# 378 {2: ['окрестных городов']}
# 387 {2: ['Российских', 'Малороссийских городов']}
# 757 {2: ['Старой Рузы']}
# 529 {2: ['соседственных городов']}
# 327 {2: ['разных Росссийских городов'], 4: ['разных Росссийских городов']}
# 762 {2: ['Великороссийских', 'Малороссийских городов'], 4: ['Великороссийских', 'Малороссийских городов']}
# 157 {2: ['Пскова']}
# 385 {1: ['Вологодские']}
# 465 {2: ['окрестных городов']}
# 739 {1: ['Великороссийские']}
# 507 {1: ['Российские']}
# 496 {1: ['Азиатские']}
# 598 {2: ['разных Российских городов']}
# 491 {1: ['Великороссийские']}
# 763 {2: ['других городов']}
# 78 {2: ['окрестных городов']}
# 794 {2: ['разных городов'], 4: ['разных городов наплывают  сверху Лены реки со всякими товарами']}
# 57 {2: ['разных городов'], 4: ['разных городов']}
# 527 {1: ['Вологодские', 'Устюжские', 'Тотемские']}
# 377 {2: ['разных городов'], 4: ['разных городов']}
# 595 {2: ['ближних городов']}
# 513 {2: ['близ лежащих городов']}
# 311 {2: ['Каширы', 'Тулы', 'Серпухова', 'Ренева', 'Зарайска', 'по']}
# 437 {2: ['ближних к нему городов', 'Тулы', 'Калуги', 'Боровска', 'Вереи']}
# 40 {2: ['окрестных городов'], 4: ['окрестных городов']}
# 344 {2: ['близ лежащих городов']}
# 723 {2: ['разных Российских городов']}
# 402 {2: ['блИз лежащих городов']}
# 429 {2: ['Каширы', 'Гуды', 'Серпухова', 'Венева', 'Зарайска по']}
# 745 {2: ['разных Российских городов']}
# 708 {1: ['Елецкие']}
# 159 {1: ['Великороссийские']}
# 581 {2: ['Ярославля']}
# 489 {2: ['разных городов']}
# 691 {1: ['Российские'], 2: ['Ирбитской ярмарки', 'торг содержат Марта']}
# 325 {1: ['Великороссийские', 'Малороссийские']}
# 236 {2: ['разных Российских городов']}
# 418 {2: ['соседственных мест'], 4: ['соседственных мест']}
# 758 {2: ['разных Российских городов']}
# 71 {2: ['Калуги', 'Мещовска', 'Болхова', 'Белева', 'других городов']}
# 288 {2: ['Москвы', 'Ярославля', 'Костромы', 'Нижнего Новагорода']}
# 403 {2: ['всех стран Россия', 'Сибири', 'также']}
# 481 {2: ['Каширы', 'Тулы', 'Серпухова', 'Венева', 'Зарайска по']}
# 252 {2: ['Каширы', 'Тулы', 'Серпухова', 'Венева', 'Зарайска по']}
# 633 {2: ['иных городов']}
# 246 {2: ['Каширы', 'Тулы', 'Серпухова', 'Венева из Зарайска по']}
# 511 {2: ['близ лежащих городов']}
# 631 {2: ['Пскова']}
# 179 {2: ['Каширы', 'Тулы', 'Серпухова', 'Венева', 'Зарайска по']}
# 37 {2: ['окольных мест']}
# 383 {1: ['Вологодские']}
# 549 {2: ['ближних городов'], 4: ['ближних городов']}
# 230 {1: ['Коломенские'], 2: ['Тулы', 'Венева', 'Каширы приезжают купцы'], 4: ['Тулы', 'Венева', 'Каширы']}
# 27 {2: ['раз ных городов']}

# %%
counter
# Out:
# 250

# %% [markdown]
# What goods are being traded?
# ============================
# This section uses lists of specific and generic descriptions of goods being traded and adds them to the db dict.

# %%
with open("../resources/reverse_stem.json","r") as fp:
    reverse_stem = json.load(fp)

# %%
def goods_finder(text,good):
    """
    Finds `good` in `text` using reverse_stem dict loaded from json.
    Returns `True` if good is found, else returns `False`
    """
    if " " in good:
        if good in text:
            return True
        else:
            return False
    else:
        tokens = nltk.tokenize.wordpunct_tokenize(text)
        tokens = [t.strip(',.;:') for t in tokens]
        if any([s in tokens for s in reverse_stem[good]]):
            return True
        else:
            return False

# %%
#goodslist = ['скот','небогатый','гвоздь','рогожами','льном','ярмарми','дуга','веревка','материя','ладоном','домовными','мелсчными','горшками','заморский','полотно','сахар','серебряный','тутошний','продажный','сапог','число','недорогой','овца','произрастание','еъестными','конский','воск','вино','крамными','сковорода','сеестными','ром','шелк','неводный','гумми','медкими','скотский','покроми','иностранный','семь','сено','ском','пенечными','мед','один','бумажный','железный','хлеб','пушной','платками','особливый','коими','ливом','холст','позумент','сало','чулками','парчами','коса','шелковый','лыками','суровскими','вещми','мясами','продукт','вино','овчина','обыватель','серебреный','галантерейный','знатный','роза','выбойками','красный','припас','свой','пиво','набойчатыми','рост','съестной','уездный','колеса','купецкими','котлами','гостиный','мелочьми','лес','немалый','табак','чими','нитка','прочий','рукодельный','ными','китайка','купецкими','рукоделие','хлебный','говяжий','произрастениями','знатный','лавочный','варами','мелочми','брусья','питейный','обыкновенный','который','суконный','кожа','житель','масло','бечевами','ободами','холст','привозный','лошадьми','сукно','хомут','замками','дробязком','сосуд','оловянный','шерстяной','щепетильный','приуготовлениями','саньми','крестьянский','лес','какой','привозимый','холетом','москотильными','мелочь','деревянный','нужный','меховой','сани','щепетинными','внутренний','медный','гарусный','деревенский','железо','мелочный','крестьянами','приезжий','харчевыми','уклад','мелкий','купеческий','издельями','каждый','надлежащий']
spec_goodslist = ['ободами','саньми','сукно','выбойка','китайка','роза','лыками','коса','покроми','скотский','произрастание','ладоном','дуга','скот','гвоздь','рогожами','льном','веревка','горшками','полотно','сахар','серебряный','сапог','овца','конский','воск','вино','сковорода','ром','шелк','гумми','сено','мед','хлеб','бумажный','железный','пушной','платками','холст','позумент','сало','чулками','парчами','шелковый','вино','овчина','серебреный','галантерейный','пиво','колеса','котлами','лес','табак','нитка','рукодельный','рукоделие','хлебный','говяжий','брусья','питейный','суконный','кожа','масло','бечевами','холст','лошадьми','хомут','замками','сосуд','оловянный','шерстяной','лес','меховой','сани','медный','гарусный','железо']
#adding multi-word goods separately for more convenient editing
spec_goodslist.extend(['красным товаром','Крымскую соль'])
kind_goodslist = ['нужный','надлежащими','харчевыми','приуготовлениями','суровскими','набойчатыми','припасами','москотильными','обыватель','произрастениями','мясами','тутошний','небогатый','домовными','заморский','продажный','недорогой','крамными','медкими','иностранный','особливый','ливом','знатный','съестной','уездный','купецкими','немалый','ными','купецкими','знатный','лавочный','обыкновенный','житель','привозный','щепетильный','крестьянский','мелочь','деревянный','внутренний','щепетинными','деревенский','мелочный','крестьянами','приезжий','мелкий']

# %%
#set(spec_goodslist)

# %%
#set(kind_goodslist)

# %%
equiv_dict= {'рукодельный':'рукоделие','железный':'железо','медный':'мед','серебряный':'серебреный','скотский':'скот','шелк':'шелковый'}
for i in db:
    tempgoods = []
    for good in spec_goodslist:
        try:
            if goods_finder(db[i]['description_new_orth'],ru_stemmer.stem(good)):
                if good in equiv_dict:
                    good = equiv_dict[good]
                tempgoods.append(good)
            if len(tempgoods)!=0:
                db[i]['spec_goods'] = tempgoods
        except KeyError:
            print(good)

# %%
counter = 0
for i in db:
    if 'spec_goods' in db[i]:
        counter+=1
        print(db[i]['ru_old_orth'],db[i]['spec_goods'])
# Out:
# Ухолово ['бумажный', 'холст', 'шелковый', 'колеса', 'холст']
# Краснокутскъ ['скот', 'позумент', 'шелковый', 'лошадьми']
# Льговъ ['сукно', 'шелковый']
# Мстиславль ['скот', 'хлеб']
# Коломна ['хлеб']
# Сватова Лучка ['бумажный', 'шелковый', 'шерстяной']
# Далматовъ ['скот']
# Богородицкъ ['лыками', 'колеса']
# Олишевка ['овчина', 'кожа']
# Слольца Колесная ['шелковый']
# Мена ['скот', 'хлеб', 'рукоделие', 'питейный', 'лошадьми']
# Молоково ['скот', 'хлеб', 'сало', 'кожа']
# Валки ['вино', 'мед', 'вино', 'пиво']
# Яранскъ ['воск', 'мед', 'бумажный', 'пушной', 'сало', 'шелковый', 'овчина', 'кожа']
# Утѣшевъ ['воск', 'мед', 'хлеб', 'бумажный', 'холст', 'шелковый', 'рукоделие', 'масло', 'холст']
# Малыкова ['вино', 'вино', 'пиво']
# Старцовъ Уголъ ['шелковый']
# Вольная ['сукно', 'полотно', 'бумажный', 'шелковый', 'железо']
# Порѣчье ['хлеб']
# Терешково ['шелковый']
# Медынь ['сахар', 'бумажный', 'шелковый']
# Торопецъ ['рукоделие']
# Сапожокъ ['полотно', 'шелковый', 'масло']
# Балаклеевъ ['бумажный', 'шелковый', 'гарусный']
# Седневъ ['скот', 'мед', 'хлеб', 'сало', 'лошадьми']
# Тула ['замками']
# Кимры ['холст', 'холст']
# Галяни ['вино', 'вино', 'пиво']
# Саратовъ ['сукно', 'хлеб', 'шелковый']
# Ямполь ['шелковый']
# Гоголевъ ['скот', 'хлеб']
# Богодуховъ ['скот', 'позумент', 'парчами', 'шелковый', 'лошадьми']
# Мринъ ['питейный']
# Лимань ['бумажный', 'шелковый', 'шерстяной']
# Тенгушева ['бумажный', 'шелковый']
# Холмъ У Спаса ['хлеб']
# Гадячь ['скот', 'овца', 'воск', 'вино', 'мед', 'хлеб', 'сало', 'вино', 'табак', 'лошадьми']
# Любимъ ['шелковый']
# Изюмъ ['бумажный', 'шелковый', 'шерстяной']
# Аксель ['хлеб', 'бумажный', 'шелковый']
# Лубны ['скот', 'вино', 'бумажный', 'шелковый', 'вино', 'кожа', 'лошадьми', 'шерстяной']
# Рызнъ ['воск', 'мед', 'хлеб', 'бумажный', 'шелковый', 'масло']
# Кострома ['хлеб', 'холст', 'холст']
# Красное ['шелковый']
# Клинъ ['колеса']
# Протопопова ['шелковый', 'лошадьми']
# Муромъ ['сукно', 'китайка', 'ладоном', 'воск', 'шелковый', 'хлеб', 'позумент']
# Иса ['шелковый']
# Богачка ['вино', 'хлеб', 'вино']
# Покровское ['шелковый']
# Нерехта ['выбойка', 'китайка', 'холст', 'холст']
# Моршанскъ ['хлеб']
# Рѣзыцы ['вино', 'вино', 'пиво']
# Усмань ['сукно', 'шелковый']
# Мягкое ['воск', 'мед']
# Опошное ['скот', 'хлеб']
# Бѣжецкъ ['хлеб', 'железо', 'шелковый']
# Сумская Ворожба ['вино', 'вино']
# Сенкова ['бумажный', 'шелковый', 'шерстяной']
# Дрицаны ['вино', 'вино', 'пиво']
# Стырняньі ['вино', 'вино', 'пиво']
# Мерехва ['вино', 'мед', 'вино', 'пиво']
# Любечь ['хлеб', 'колеса', 'кожа']
# Березники ['шелковый']
# Обоянь ['хлеб', 'масло']
# Печенѣги ['бумажный', 'шелковый', 'гарусный']
# Сосница ['скот', 'хлеб']
# Фридрихсгамъ ['вино', 'вино', 'табак', 'железо']
# Спасъ ['скот', 'хлеб', 'сало', 'кожа']
# Богатищебо ['воск', 'мед']
# Малино ['хлеб']
# Боровичи ['шелковый', 'шерстяной']
# Роловское ['холст', 'холст']
# Яблуновъ ['скот', 'вино', 'хлеб', 'вино']
# Сергачь ['рукоделие']
# Макарьевъ ['бумажный', 'шелковый']
# Барковъ ['вино', 'вино', 'пиво']
# Шипино ['хлеб']
# Яготинъ ['скот', 'вино', 'хлеб', 'вино']
# Бѣлополье ['скот', 'вино', 'вино', 'лошадьми']
# Жиздра ['бумажный', 'шелковый']
# Ржица ['скот', 'вино', 'хлеб', 'сало', 'вино', 'овчина', 'говяжий', 'кожа', 'лошадьми']
# Щигры ['хлеб']
# Туглинская ['рукоделие']
# Грязовецъ ['чулками']
# Ключевская ['шелковый']
# Берники ['воск', 'мед']
# Маяки ['бумажный', 'шелковый', 'шерстяной']
# Мирополье ['скот', 'лошадьми']
# Мещовскъ ['хлеб']
# Биржа ['вино', 'вино', 'пиво']
# Митякинская ['сукно', 'скот', 'холст', 'шелковый', 'холст']
# Угличъ ['хлеб', 'бумажный', 'холст', 'сало', 'шелковый', 'кожа', 'холст']
# Воронковъ ['вино', 'хлеб', 'вино']
# Уральскъ ['сукно', 'полотно', 'хлеб', 'бумажный', 'шелковый', 'шерстяной']
# Сарбаево ['шелковый']
# Устье ['холст', 'сало', 'говяжий', 'суконный', 'кожа', 'масло', 'холст']
# Островъ ['бумажный', 'шелковый']
# Тимъ ['сукно', 'шелковый']
# Лукомля ['скот', 'вино', 'хлеб', 'сало', 'вино', 'овчина', 'говяжий', 'кожа', 'лошадьми']
# Подворгальское ['холст', 'рукоделие', 'холст']
# Верея ['лыками', 'бумажный', 'холст', 'шелковый', 'колеса', 'холст']
# Лальскъ ['сукно', 'холст', 'овчина', 'холст']
# Шишаки ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Семендѣево ['холст', 'холст']
# Починки ['хлеб', 'шелковый', 'лес', 'лес']
# Троицкая Сергіева ['шелковый', 'меховой']
# Самара ['хлеб']
# Каменка ['бумажный', 'шелковый', 'шерстяной']
# Вышгородъ ['колеса']
# Малой Ярославецъ ['выбойка', 'китайка', 'сахар', 'бумажный', 'платками', 'шелковый']
# Чупаховка ['сукно', 'полотно', 'бумажный', 'шелковый', 'железо']
# Боромдя ['скот', 'бумажный', 'позумент', 'парчами', 'шелковый', 'серебреный', 'лошадьми']
# Глинскъ ['скот', 'вино', 'вино', 'овчина', 'кожа', 'лошадьми']
# Перевицкой Торжокъ ['саньми', 'хлеб', 'колеса']
# Павлово ['сукно', 'шелковый', 'хлеб', 'платками', 'шелковый']
# Ярески ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Шатскъ ['холст', 'холст']
# Шунгской ['бумажный', 'шелковый', 'гарусный']
# Чухлома ['серебреный', 'шелковый', 'овчина', 'кожа']
# Стоянцы ['холст', 'холст']
# Сватова Лучка ['бумажный', 'шелковый', 'шерстяной']
# Сарбаево ['шелковый']
# Языково ['шелковый']
# Апичерская ['шелковый']
# Лухъ ['шелковый']
# Сызрань ['хлеб']
# Петровскъ ['хлеб']
# Покровское ['шелковый']
# Кесова Гора ['хлеб']
# Юрьевецъ Поволгскій ['горшками', 'сено', 'хлеб', 'лес', 'лес']
# Юнаковка ['вино', 'вино']
# Рашевка ['хлеб']
# Лукояновъ ['хлеб']
# Ньжинъ ['ладоном', 'воск', 'вино', 'мед', 'бумажный', 'пушной', 'шелковый', 'вино', 'табак', 'шерстяной']
# Набдинъ ['мед', 'шелковый', 'кожа']
# Зинковъ ['скот', 'хлеб']
# Перекопецъ ['вино', 'мед', 'вино', 'пиво']
# Комельскъ Корниліевъ ['бумажный', 'холст', 'сало', 'чулками', 'шелковый', 'колеса', 'говяжий', 'кожа', 'холст', 'лошадьми', 'шерстяной', 'сани', 'гарусный']
# Опушка ['мед', 'холст', 'сало', 'холст']
# Котельва ['скот', 'позумент', 'парчами', 'шелковый', 'лошадьми']
# Инжавенье ['холст', 'холст']
# Писаревка ['сукно', 'полотно', 'бумажный', 'шелковый', 'железо']
# Роменъ ['ром', 'бумажный', 'шелковый', 'серебреный', 'галантерейный', 'табак', 'оловянный', 'мед', 'гарусный']
# Чугуевъ ['шелковый']
# Ростовъ ['ободами', 'роза', 'гвоздь', 'сковорода', 'железо', 'шелковый', 'серебреный', 'котлами', 'замками', 'железо']
# Карасу - Базаръ ['скот']
# Андреевка ['бумажный', 'шелковый', 'гарусный']
# Пуша ['вино', 'вино', 'пиво']
# Ильинское ['холст', 'холст']
# Константиновское ['холст', 'холст']
# Высокое ['хлеб']
# Старая Руза ['коса']
# Тресвятское ['воск', 'мед', 'хлеб', 'бумажный', 'сало', 'шелковый', 'овчина', 'кожа']
# Сребное ['скот', 'сено', 'хлеб']
# Балахна ['хлеб']
# Кривцо ['сало', 'овчина', 'кожа', 'масло']
# Ивангородъ ['сапог']
# Александровское ['скот', 'лошадьми']
# Оскино ['бумажный', 'шелковый']
# Нельянской ['железо']
# Воеводское ['шелковый']
# Ладинской ['скот', 'хлеб']
# Борисоглѣбскъ ['хлеб']
# Верхній Удинскъ ['скот', 'пушной']
# Дерптъ ['горшками', 'сено', 'хлеб', 'железо', 'шелковый', 'масло', 'лошадьми']
# Кашинъ ['холст', 'холст']
# Волоколамскъ ['коса', 'хлеб']
# Зубцовъ ['бумажный', 'шелковый']
# Волскъ ['хлеб']
# Лакновать ['мед', 'кожа']
# Чернѣевъ Николаевской ['холст', 'холст']
# Олышаная ['вино', 'мед', 'вино', 'пиво']
# Сасово ['холст', 'холст']
# Горицы ['холст', 'холст']
# Лапстрандъ ['сало', 'масло']
# Высокое ['холст', 'холст']
# Новые Млины ['хлеб']
# Иваново ['воск', 'мед']
# Гребенишки ['вино', 'вино', 'пиво']
# Тешевской ['холст', 'рукоделие', 'холст']
# Бахмачь ['вино', 'вино', 'пиво']
# Билярскъ ['рукоделие']
# Островня ['сено']
# Крижбургъ ['вино', 'вино', 'пиво']
# Миргородъ ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Артемоновка ['мед', 'пиво']
# Барышевка ['скот', 'вино', 'хлеб', 'вино']
# Сталеровчизна ['вино', 'вино', 'пиво']
# Купенка ['бумажный', 'шелковый', 'шерстяной']
# Боровскъ ['холст', 'шелковый', 'холст']
# Аргамачья ['холст', 'рукоделие', 'холст']
# Михайловка ['вино', 'вино']
# Орловъ ['сукно', 'шелковый']
# Судай ['скот', 'конский', 'овчина', 'кожа']
# Ивановка ['вино', 'мед', 'вино', 'пиво']
# Тухи ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Коренная ['лошадьми']
# Городище ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа']
# Зарубино ['скот', 'лошадьми']
# Гагарино ['холст', 'холст']
# Глемязовъ ['скот', 'вино', 'хлеб', 'вино']
# Хотень ['вино', 'вино']
# Дергачи ['вино', 'мед', 'вино', 'пиво']
# Краснослободскъ ['бумажный', 'шелковый']
# Горбатовъ ['хлеб']
# Исталена ['вино', 'вино', 'пиво']
# Рушона ['вино', 'вино', 'пиво']
# Бѣлозерскъ ['сено', 'хлеб']
# Кадомъ ['бумажный', 'шелковый']
# Троицкая ['сукно', 'полотно', 'холст', 'сало', 'говяжий', 'кожа', 'масло', 'холст']
# Чериковъ ['скот']
# Лотсшино ['хлеб', 'масло']
# Выборгъ ['вино', 'вино', 'табак', 'железо']
# Конобѣево ['холст', 'холст']
# Рыбинскъ ['произрастание', 'рукоделие']
# Яшъ ['вино', 'вино', 'пиво']
# Петровское ['холст', 'рукоделие', 'холст']
# Рязань ['выбойка', 'шелковый', 'мед', 'позумент', 'серебреный', 'кожа']
# Сумы ['сукно', 'сахар', 'вино', 'парчами', 'шелковый', 'вино']
# Хатомль ['вино', 'мед', 'вино', 'пиво']
# Лебединъ ['вино', 'вино']
# Грунь ['скот', 'хлеб']
# Дѣдиново ['хлеб']
# Сорочинцы ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа']
# Кобызча ['скот', 'вино', 'хлеб', 'вино']
# Гороховецъ ['холст', 'холст']
# Камышня ['скот', 'хлеб', 'лошадьми']
# Суджа ['бумажный', 'шелковый']
# Рожественское ['рукоделие']
# Дубровки ['хлеб', 'бумажный', 'шелковый']
# Остапье ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Смѣлое ['скот']
# Лебедянь ['сукно', 'бумажный', 'шелковый']
# Ратковка ['бумажный', 'шелковый', 'гарусный']
# Козельскъ ['бумажный', 'шелковый', 'масло']
# Ярославль ['хлеб']
# Липцы ['вино', 'мед', 'вино', 'пиво']
# Переяславль ['скот', 'вино', 'хлеб', 'вино', 'суконный']
# Устивица ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Кишенька ['хлеб']
# Золотоноша ['скот', 'хлеб']
# Атемаръ ['шелковый']
# Дубровки ['шелковый']
# Моцына ['вино', 'вино', 'пиво']
# Полтава ['скот', 'пушной', 'холст', 'масло', 'холст']
# Ична ['скот', 'хлеб']
# Флорищева ['холст', 'шелковый', 'холст']
# Крапивна ['скот', 'вино', 'хлеб', 'вино']
# Ункосова ['холст', 'холст']
# Смоленскъ ['мед', 'хлеб']
# Ливны ['шелковый']
# Глушицкой ['холст', 'холст']
# Узель ['вино', 'вино', 'пиво']
# Коприно ['масло']
# Лохвица ['кожа', 'железо', 'красным товаром']
# Кромы ['холст', 'шелковый', 'холст']
# Петрома ['шелковый']
# Корсунь ['бумажный', 'шелковый']
# Рѣпки ['хлеб']
# Старица ['бумажный', 'шелковый', 'суконный']
# Ивановка ['шелковый']
# Святое Мѣсто ['бумажный', 'железо', 'шелковый', 'лошадьми', 'мед']
# Хомутцы ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Острогожскъ ['сукно', 'парчами', 'шелковый', 'серебреный', 'галантерейный']
# Оренбургъ ['выбойка', 'бумажный']
# Дукштилагъ ['вино', 'вино', 'пиво']
# Курьяново ['вино', 'вино', 'пиво']
# Золочевъ ['вино', 'мед', 'вино', 'пиво']
# Савиницы ['бумажный', 'шелковый', 'гарусный']
# Плоское ['хлеб']
# Омельникъ ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Стародубъ ['сукно', 'рогожами', 'воск', 'вино', 'шелковый', 'вино', 'масло']
# Петровская ['холст', 'холст']
# Звенигородъ ['шелковый']
# Ряжскъ ['бумажный', 'шелковый']
# Козловка ['воск', 'мед']
# Починки ['шелковый']
# Можайскъ ['шелковый']
# Ржевъ Володимеровъ ['хлеб', 'бумажный', 'позумент', 'парчами', 'шелковый', 'серебреный']
# Волчья ['вино', 'мед', 'вино', 'пиво']
# Краснополье ['скот']
# Лада ['шелковый']
# Креславль ['вино', 'вино', 'пиво']
# Кіасовка ['хлеб']
# Лютенка ['скот', 'хлеб']
# Синявки ['хлеб']
# Макарово ['скот', 'лошадьми']
# Миротино ['воск', 'мед']
# Царевъ Борисовъ ['бумажный', 'шелковый', 'гарусный']
# Тюртень ['холст', 'рукоделие', 'холст']
# Голтва ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа', 'красным товаром']
# Плохона ['воск', 'хлеб', 'бумажный', 'холст', 'шелковый', 'рукоделие', 'масло', 'холст']
# Крылѣево ['скот', 'вино', 'хлеб', 'вино']
# Прели ['вино', 'вино', 'пиво']
# Презма ['вино', 'вино', 'пиво']
# Ольховатка ['бумажный', 'шелковый', 'шерстяной']
# Весіегонскъ ['железо', 'пушной', 'оловянный', 'мед']
# Змѣевѣ ['бумажный', 'шелковый', 'шерстяной']
# Деймановка ['скот', 'хлеб']
# Мглинъ ['вино', 'вино', 'табак', 'масло', 'красным товаром']
# Варва ['скот', 'сено', 'хлеб']
# Борисовъ ['колеса']
# Борятино ['воск', 'мед', 'хлеб', 'бумажный', 'шелковый', 'масло']
# Кинешма ['сукно', 'шелковый', 'серебреный', 'оловянный']
# Саратовъ ['сукно', 'хлеб', 'шелковый']
# Хоролъ ['скот', 'вино', 'хлеб', 'вино', 'овчина', 'кожа']
# Ляудера ['вино', 'вино']
# Игумново ['воск', 'мед']
# Алешня ['сукно', 'полотно', 'бумажный', 'шелковый', 'железо']
# Ивановское ['воск', 'мед']
# Густиново ['воск', 'мед']
# Мачуха ['питейный']
# Березинъ ['скот', 'питейный']
# Тихонова ['шелковый']
# Понорница ['произрастание', 'скот', 'нитка', 'рукоделие']
# Зарайскъ ['коса', 'хлеб', 'рукоделие', 'брусья', 'бечевами', 'лошадьми', 'хомут']
# Чернухи ['вино', 'хлеб', 'сало', 'вино', 'овчина', 'говяжий', 'кожа']
# Ахтырка ['скот', 'парчами', 'шелковый', 'лошадьми']
# Сасово ['холст', 'холст']

# %%
counter
# Out:
# 320

# %% [markdown]
# Goods export
# ============
# In this section the counts of what goods are traded where are collected and indexed by good, then by place, then exported to an Excel file.

# %%
goodscount = {}
for p in db:
    if 'spec_goods' in db[p]:
        for good in db[p]['spec_goods']:
            if good not in goodscount:
                goodscount[good]=1
            else:
                goodscount[good]+=1

# %%
spdf = pd.DataFrame.from_dict(goodscount,orient='index')
spdf.columns = ['Counts']
spdf = spdf.sort(columns='Counts',ascending=False)
#spdf.to_excel("sp_goods.xlsx",encoding='utf-8')

# %%
for i in db:
    tempgoods = []
    for good in kind_goodslist:
        try:
            if goods_finder(db[i]['description_new_orth'],ru_stemmer.stem(good)):
                if good in equiv_dict:
                    good = equiv_dict[good]
                tempgoods.append(good)
            if len(tempgoods)!=0:
                db[i]['kind_goods'] = tempgoods
        except KeyError:
            print(good)

# %%
counter = 0
for i in db:
    if 'kind_goods' in db[i]:
        counter+=1
        print(db[i]['ru_old_orth'],db[i]['kind_goods'])
# Out:
# Ухолово ['москотильными', 'деревянный', 'крестьянами']
# Льговъ ['мелкий']
# Авдулово ['мелочный', 'крестьянами']
# Кривонаволоцкая ['крестьянами']
# Мстиславль ['крестьянский']
# Коломна ['щепетильный', 'деревянный']
# Плесъ ['москотильными', 'мелочный']
# Руза ['мелочный']
# Далматовъ ['особливый']
# Богородицкъ ['мелочный', 'крестьянами']
# Олишевка ['приезжий']
# Слольца Колесная ['мелочный']
# Мена ['припасами', 'съестной', 'лавочный', 'житель', 'мелочный', 'приезжий']
# Валки ['мелочный']
# Красноборскъ ['приезжий']
# Яранскъ ['произрастениями', 'мелочный']
# Утѣшевъ ['москотильными', 'уездный', 'крестьянский', 'мелочный', 'крестьянами']
# Малыкова ['мелочный', 'крестьянами']
# Старцовъ Уголъ ['крестьянами']
# Вольная ['набойчатыми']
# Дорогобужъ ['припасами', 'съестной']
# Елимской ['мелочный']
# Порѣчье ['обыватель', 'съестной']
# Терешково ['мелочный']
# Кирсановъ ['мелочный']
# Медынь ['москотильными']
# Дубовое ['мелочный']
# Торопецъ ['крестьянский', 'мелочный', 'крестьянами']
# Сапожокъ ['обыватель', 'деревянный']
# Душатинъ ['житель', 'мелочный']
# Седневъ ['житель', 'деревянный', 'мелочный']
# Волмаръ ['иностранный']
# Раменье ['крестьянский']
# Кимры ['небогатый', 'мелочный']
# Епифань ['знатный', 'знатный']
# Спаскъ ['мелочный']
# Галяни ['мелочный', 'крестьянами']
# Саратовъ ['нужный']
# Гоголевъ ['мелочный']
# Мринъ ['припасами', 'съестной', 'мелочный']
# Кесме ['лавочный', 'мелочный']
# Старой Быховъ ['знатный', 'знатный']
# Тенгушева ['мелочный']
# Холмъ У Спаса ['обыватель', 'съестной', 'уездный']
# Гадячь ['мелочь']
# Аксель ['припасами']
# Лубны ['приуготовлениями', 'внутренний']
# Волынцы ['мелочный']
# Рызнъ ['уездный', 'крестьянами']
# Мехонской ['мелочный']
# Кострома ['крестьянский']
# Хрущово ['мелочный']
# Инсара ['недорогой']
# Коквино ['мелочный']
# Гаврилова ['купецкими', 'купецкими']
# Волокопинежская ['деревенский', 'крестьянами']
# Красное ['мелочный', 'крестьянами']
# Клинъ ['припасами', 'съестной', 'крестьянский', 'деревянный']
# Гремячевъ ['мелочный']
# Протопопова ['мелочный', 'приезжий']
# Муромъ ['обыватель', 'мясами']
# Иса ['мелочный']
# Богачка ['житель', 'мелочный', 'приезжий']
# Покровское ['мелочный']
# Нерехта ['мелочный']
# Моршанскъ ['немалый']
# Динабургъ ['обыватель', 'тутошний', 'житель', 'мелочный']
# Рѣзыцы ['мелочный', 'крестьянами']
# Пропойскъ ['обыкновенный']
# Усмань ['мелочный']
# Мягкое ['москотильными', 'обыватель', 'уездный', 'деревянный', 'мелочный']
# Симеоновка ['мелочный']
# Спирово ['крестьянский']
# Пятницкое ['мелочный']
# Опошное ['припасами', 'съестной']
# Бѣжецкъ ['москотильными', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Сумская Ворожба ['припасами', 'съестной', 'мелочный']
# Черлянково ['крестьянский']
# Гремячь ['житель', 'мелочный']
# Дрицаны ['мелочный', 'крестьянами']
# Стырняньі ['мелочный', 'крестьянами']
# Семеновъ ['припасами', 'съестной', 'мелочный']
# Михайловской ['мелочный']
# Мерехва ['мелочный']
# Любечь ['крамными', 'привозный', 'крестьянский', 'мелкий']
# Березники ['мелочный']
# Подолъ ['припасами', 'произрастениями', 'съестной']
# Парское ['купецкими', 'купецкими', 'мелочный']
# Обоянь ['житель', 'деревенский']
# Сосница ['житель', 'мелочный']
# Богатищебо ['припасами', 'москотильными', 'обыватель', 'съестной', 'уездный', 'деревенский', 'мелочный']
# Малино ['деревянный', 'деревенский']
# Роловское ['купецкими', 'немалый', 'купецкими']
# Яблуновъ ['крамными', 'житель', 'деревянный', 'мелкий']
# Сергачь ['припасами', 'крестьянами']
# Макарьевъ ['мелочный']
# Барковъ ['мелочный', 'крестьянами']
# Шипино ['обыватель', 'съестной']
# Мангазея ['мелочный']
# Яготинъ ['припасами', 'крамными', 'съестной', 'житель', 'деревянный']
# Рыльскъ ['мелкий']
# Бѣлополье ['мелочный']
# Калинкино ['мелочный']
# Кіата ['иностранный']
# Бора ['знатный', 'знатный']
# Жиздра ['москотильными']
# Ржица ['припасами', 'съестной', 'мелочный']
# Щигры ['припасами', 'обыватель', 'крестьянский', 'мелочный']
# Туглинская ['произрастениями', 'деревенский']
# Грязовецъ ['припасами', 'обыватель', 'съестной', 'мелочный']
# Ключевская ['приуготовлениями', 'крестьянами']
# Берники ['припасами', 'москотильными', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Мирополье ['внутренний', 'мелкий']
# Стешки ['мелочный']
# Мещовскъ ['крестьянами']
# Биржа ['мелочный', 'крестьянами']
# Угличъ ['москотильными', 'мясами', 'приезжий', 'мелкий']
# Воронковъ ['припасами', 'обыватель', 'съестной', 'деревянный', 'мелочный']
# Туринскъ ['знатный', 'знатный']
# Сарбаево ['крестьянами']
# Киренскъ ['житель']
# Устье ['мясами', 'особливый']
# Борисоглѣбскъ ['мелочный']
# Томаровка ['мелочный']
# Чернавскъ ['мелкий']
# Подворгальское ['припасами', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Верея ['москотильными', 'мелочный', 'крестьянами']
# Кременчугъ ['обыкновенный']
# Лальскъ ['съестной', 'мелочный']
# Шишаки ['житель', 'приезжий', 'мелкий']
# Дѣдиловъ ['мелочный']
# Махоново ['мелочный']
# Семендѣево ['небогатый', 'мелочный']
# Ковровъ ['мелочный']
# Починки ['деревянный', 'мелочный', 'крестьянами']
# Троицкая Сергіева ['мелочный', 'приезжий']
# Самара ['припасами', 'обыватель', 'уездный', 'мелочный']
# Часовня Св. Духа ['мелочный']
# Мегра ['лавочный']
# Новоникольское ['мелочный']
# Покровское ['мелочный']
# Вышгородъ ['припасами', 'съестной', 'крестьянский']
# Малой Ярославецъ ['припасами', 'москотильными', 'съестной', 'житель', 'деревенский']
# Чупаховка ['набойчатыми']
# Глинскъ ['мелочный']
# Перевицкой Торжокъ ['москотильными', 'обыватель', 'мясами', 'деревянный', 'мелочный']
# Ивановское ['крестьянский', 'мелочный']
# Павлово ['нужный', 'припасами', 'съестной', 'житель']
# Ямская ['недорогой']
# Ярески ['житель', 'мелочный', 'приезжий']
# Шатскъ ['мелочный']
# Землянскъ ['мелкий']
# Саранскъ ['мелочный']
# Чухлома ['щепетинными']
# Стоянцы ['небогатый', 'мелочный']
# Сарбаево ['крестьянами']
# Воронцовка ['мелочный']
# Языково ['крестьянами']
# Апичерская ['крестьянами']
# Бѣлая Колпь ['крестьянский']
# Сызрань ['припасами', 'съестной', 'мелочный', 'мелкий']
# Наровчатъ ['обыкновенный']
# Окуневскъ ['мелочный']
# Покровское ['мелочный', 'крестьянами']
# Кесова Гора ['обыватель', 'съестной', 'уездный', 'мелочный']
# Юрьевецъ Поволгскій ['припасами', 'съестной', 'крестьянами']
# Юнаковка ['мелочный']
# Выборъ ['мелочный']
# Рашевка ['припасами', 'съестной']
# Лукояновъ ['крестьянами']
# Козелецъ ['лавочный', 'мелочный']
# Набдинъ ['обыватель', 'мелкий']
# Пафнутьевъ ['мелочный']
# Устюгъ Великій ['приуготовлениями', 'крестьянами']
# Зинковъ ['припасами', 'съестной']
# Вревъ ['мелочный']
# Перекопецъ ['мелочный']
# Батракъ ['особливый']
# Комельскъ Корниліевъ ['москотильными', 'мелочный']
# Челябинскъ ['знатный', 'знатный']
# Лужки ['мелочный']
# Писаревка ['набойчатыми']
# Пудога ['лавочный']
# Роменъ ['иностранный', 'особливый']
# Ладога Новая ['припасами', 'заморский', 'съестной', 'крестьянский']
# Чугуевъ ['крестьянами']
# Борисоглѣбской ['суровскими', 'приезжий']
# Ростовъ ['суровскими', 'деревянный']
# Слободской ['лавочный']
# Добрая ['мелочный']
# Пуша ['мелочный']
# Ильинское ['небогатый', 'мелочный']
# Архангельское ['мелочный']
# Константиновское ['небогатый', 'мелочный']
# Высокое ['щепетильный', 'деревянный']
# Старая Руза ['москотильными']
# Тресвятское ['мелочный']
# Сребное ['припасами', 'произрастениями', 'съестной', 'житель', 'мелочный']
# Кочелаево ['крестьянами']
# Исетская ['мелочный']
# Оквадская ['приезжий']
# Балахна ['припасами', 'съестной', 'житель', 'крестьянами']
# Кривцо ['купецкими', 'купецкими', 'крестьянами']
# Ивангородъ ['крамными', 'мелочный']
# Александровское ['мелочный']
# Оскино ['крестьянами']
# Нельянской ['житель']
# Княгининъ ['припасами', 'съестной', 'крестьянами']
# Воеводское ['мелочный']
# Ладинской ['припасами', 'произрастениями', 'съестной', 'житель', 'крестьянский', 'мелочь']
# Борисоглѣбскъ ['деревянный', 'крестьянами']
# Дерптъ ['крестьянами']
# Вашка ['мелочный']
# Кашинъ ['обыватель', 'небогатый', 'уездный', 'мелочный']
# Волоколамскъ ['щепетильный', 'крестьянский', 'мелкий']
# Зубцовъ ['припасами', 'съестной', 'мелочный']
# Лакновать ['обыватель']
# Чернѣевъ Николаевской ['внутренний']
# Олышаная ['мелочный']
# Горицы ['небогатый', 'мелочный']
# Козловъ ['обыкновенный', 'крестьянский', 'приезжий']
# Задушное ['мелочный']
# Бобровское ['особливый', 'деревянный']
# Высокое ['небогатый', 'мелочный']
# Валдай ['припасами', 'съестной', 'щепетильный', 'мелкий']
# Новые Млины ['мелочный']
# Кистеръ ['житель', 'мелочный']
# Иваново ['припасами', 'москотильными', 'обыватель', 'съестной', 'уездный', 'деревянный', 'мелочный']
# Ефремовъ ['мелочный']
# Гребенишки ['мелочный', 'крестьянами']
# Кударинская ['мелочный', 'приезжий']
# Тешевской ['припасами', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Турецкая ['крестьянами']
# Еске ['лавочный', 'мелочный']
# Билярскъ ['нужный', 'житель', 'деревянный']
# Крижбургъ ['мелочный', 'крестьянами']
# Миргородъ ['медкими', 'житель', 'приезжий']
# Серпуховъ ['обыкновенный']
# Володимерецъ ['мелочный']
# Артемоновка ['мелочный']
# Барышевка ['житель', 'мелочный', 'мелкий']
# Сталеровчизна ['мелочный', 'крестьянами']
# Мижиричь ['мелочный']
# Боровскъ ['крестьянский', 'крестьянами']
# Аргамачья ['припасами', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Ховань ['крестьянский']
# Михайловка ['припасами', 'съестной', 'лавочный']
# Орловъ ['мелочный']
# Ивановка ['мелочный']
# Алексинъ ['москотильными']
# Іосифовъ ['мелочный']
# Тухи ['уездный', 'житель', 'мелочный']
# Коренная ['иностранный']
# Городище ['житель', 'мелочный', 'приезжий']
# Зарубино ['мелочный']
# Гагарино ['мелочный']
# Глемязовъ ['крамными', 'житель', 'деревянный', 'мелкий']
# Хотень ['мелочный']
# Дергачи ['лавочный', 'мелочный']
# Краснослободскъ ['припасами', 'москотильными', 'крестьянами']
# Ружное ['мелочный']
# Иваново ['мелочный']
# Горбатовъ ['крестьянами']
# Исталена ['мелочный', 'крестьянами']
# Перемышль ['обыкновенный']
# Петровки ['припасами', 'съестной', 'житель']
# Дунилово ['мелочный']
# Елатма ['припасами', 'обыватель', 'съестной', 'мелочный']
# Гдовъ ['лавочный', 'мелочный']
# Рушона ['мелочный', 'крестьянами']
# Бѣлозерскъ ['домовными']
# Беркунова ['крестьянский']
# Кадомъ ['мелочный']
# Лотсшино ['мелочь', 'крестьянами']
# Кошира ['мелочный']
# Кодинское ['мелочный']
# Теплогорская Богородицкая ['мелочный']
# Рыбинскъ ['особливый', 'купецкими', 'купецкими', 'деревянный', 'крестьянами']
# Петровскъ ['припасами', 'съестной']
# Яшъ ['мелочный', 'крестьянами']
# Петровское ['припасами', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Даймино ['знатный', 'знатный']
# Часовня Апостола Ѳомы ['недорогой']
# Рязань ['припасами', 'москотильными', 'съестной']
# Авженская ['мелочный']
# Хатомль ['мелочный']
# Глѣбово ['купецкими', 'купецкими', 'крестьянами', 'мелкий']
# Лебединъ ['лавочный']
# Соль-Галицкая ['обыкновенный']
# Грунь ['припасами', 'съестной']
# Дѣдиново ['припасами', 'обыватель', 'щепетильный']
# Колюпановка ['мелкий']
# Бушнрво ['мелочный']
# Сорочинцы ['житель', 'мелочный', 'приезжий']
# Поводнево ['лавочный', 'мелочный']
# Ирбитъ ['припасами', 'съестной', 'мелочь']
# Кобызча ['лавочный', 'мелкий']
# Гороховецъ ['мелочный']
# Камышня ['припасами', 'съестной', 'приезжий']
# Рожественское ['мелочный', 'крестьянами']
# Дубровки ['припасами']
# Остапье ['житель', 'мелочный', 'приезжий']
# Пятницкое ['мелочь']
# Смѣлое ['житель', 'мелочный']
# Лебедянь ['припасами', 'обыватель', 'съестной', 'деревянный', 'мелочный']
# Киструса ['крестьянами']
# Козельскъ ['крестьянами']
# Ярославль ['крестьянами']
# Новосиль ['москотильными', 'мелочный']
# Китайской ['особливый']
# Липцы ['мелочный']
# Переяславль ['крамными', 'житель']
# Устивица ['житель', 'мелочный', 'приезжий']
# Кишенька ['деревянный']
# Ропскъ ['мелочный']
# Золотоноша ['крамными', 'житель', 'деревянный', 'мелкий']
# Атемаръ ['мелочный']
# Дубровки ['мелочный']
# Цывильскъ ['мелочный']
# Моцына ['мелочный', 'крестьянами']
# Маркушевская ['москотильными', 'мелочный']
# Полтава ['иностранный', 'знатный', 'уездный', 'знатный', 'житель', 'мелочный']
# Ична ['припасами', 'произрастениями', 'съестной', 'житель', 'деревянный']
# Мостовское ['мелочный']
# Флорищева ['мелочный']
# Крапивна ['крамными', 'обыкновенный', 'житель', 'деревянный', 'мелкий']
# Смоленскъ ['крестьянами']
# Ливны ['мелочный', 'крестьянами']
# Глушицкой ['мелочный']
# Узель ['мелочный', 'крестьянами']
# Богородицкъ ['нужный']
# Коприно ['крестьянами']
# Макалово ['припасами', 'крестьянами']
# Шуя ['иностранный']
# Кромы ['произрастениями', 'тутошний', 'уездный', 'житель', 'мелкий']
# Черенчицкой ['мелочный']
# Петрома ['мелочный']
# Верховажской ['приуготовлениями']
# Корсунь ['обыватель', 'знатный', 'знатный', 'привозный', 'крестьянский', 'деревенский', 'крестьянами']
# Рѣпки ['житель', 'крестьянский']
# Крапивна ['обыкновенный']
# Черниговъ ['приезжий']
# Ивановка ['мелочный']
# Гнильской ['мелочный']
# Лопотовъ ['мелочный']
# Олонецъ ['уездный']
# Недригайловъ ['мелочный']
# Хомутцы ['житель', 'мелочный', 'приезжий']
# Острогожскъ ['иностранный']
# Оренбургъ ['иностранный']
# Дукштилагъ ['мелочный', 'крестьянами']
# Курьяново ['мелочный', 'крестьянами']
# Золочевъ ['мелочный']
# Плоское ['мелочный']
# Омельникъ ['житель', 'мелочный', 'приезжий']
# Стародубъ ['обыкновенный', 'деревянный', 'мелкий']
# Чериоострожской Николаевской ['припасами', 'обыватель', 'знатный', 'съестной', 'уездный', 'знатный', 'мелочный']
# Петровская ['мелочный']
# Звенигородъ ['привозный', 'мелкий']
# Юрьевъ Польскій ['житель', 'мелочный']
# Шартолинской Николаевской ['иностранный', 'лавочный']
# Рига ['приезжий']
# Пена ['лавочный', 'мелочный']
# Козловка ['москотильными', 'обыватель', 'уездный', 'деревянный', 'мелочный']
# Починки ['мелочный']
# Можайскъ ['мелочный']
# Ржевъ Володимеровъ ['москотильными', 'крестьянский', 'мелочный']
# Березовца ['лавочный']
# Волчья ['мелочный']
# Краснополье ['мелочный']
# Лада ['мелочный']
# Креславль ['мелочный', 'крестьянами']
# Утвымская ['лавочный']
# Кіасовка ['деревянный']
# Лютенка ['припасами', 'съестной', 'житель']
# Троицкъ ['обыкновенный']
# Муриково ['крестьянский']
# Кароча ['мелкий']
# Змѣтневъ ['обыватель']
# Донковъ ['мелочный']
# Синявки ['житель', 'мелочный']
# Макарово ['мелочный']
# Миротино ['припасами', 'москотильными', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Тюртень ['припасами', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Голтва ['житель', 'мелочный', 'приезжий']
# Плохона ['москотильными', 'уездный', 'крестьянский', 'мелочный']
# Романовъ ['мелочный']
# Крылѣево ['житель', 'деревянный', 'мелочный', 'мелкий']
# Одоевъ ['москотильными', 'деревянный', 'мелочный']
# Прели ['мелочный', 'крестьянами']
# Презма ['мелочный', 'крестьянами']
# Ядринъ ['заморский', 'крестьянский']
# Коропъ ['мелочный']
# Весіегонскъ ['москотильными', 'съестной']
# Деймановка ['припасами', 'произрастениями', 'съестной', 'житель', 'крестьянский', 'мелочь', 'деревянный', 'деревенский']
# Мглинъ ['произрастениями', 'мелочный']
# Варва ['припасами', 'произрастениями', 'съестной', 'житель', 'мелочный']
# Кумзерская ['мелочный']
# Богородскъ ['припасами', 'съестной', 'мелочный', 'крестьянами']
# Лѣвые Ламки ['мелочный']
# Свіажскъ ['припасами', 'съестной', 'мелочный']
# Борисовъ ['припасами', 'съестной', 'крестьянский']
# Наспищи ['надлежащими']
# Борятино ['москотильными', 'уездный', 'крестьянами']
# Кинешма ['мелочный']
# Саратовъ ['нужный']
# Хоролъ ['житель', 'мелочный', 'приезжий']
# Путятино ['мелочный']
# Ляудера ['ливом', 'мелочный', 'крестьянами']
# Одинцово ['обыватель', 'уездный', 'мелочный']
# Игумново ['припасами', 'москотильными', 'обыватель', 'съестной', 'уездный', 'мелочный']
# Алешня ['набойчатыми']
# Синбирскъ ['особливый']
# Скопинъ ['съестной', 'крестьянский']
# Ивановское ['припасами', 'москотильными', 'обыватель', 'съестной', 'уездный', 'деревянный', 'мелочный']
# Парѳеньева ['мелочный']
# Синской ['мелочный']
# Густиново ['москотильными', 'обыватель', 'уездный', 'деревянный']
# Карповка ['мелочный', 'крестьянами']
# Мачуха ['припасами', 'съестной', 'житель']
# Березинъ ['припасами', 'съестной', 'деревянный']
# Лиской ['мелочный']
# Понорница ['припасами', 'тутошний', 'съестной', 'житель', 'деревянный', 'мелочный', 'приезжий']
# Зарайскъ ['обыватель', 'продажный', 'уездный', 'деревенский']
# Чернухи ['припасами', 'съестной', 'мелочный']
# Арзамасъ ['обыкновенный']

# %%
counter
# Out:
# 426

# %%
kind_goodscount = {}
for p in db:
    if 'kind_goods' in db[p]:
        for good in db[p]['kind_goods']:
            if good not in kind_goodscount:
                kind_goodscount[good]=1
            else:
                kind_goodscount[good]+=1

# %%
kdf = pd.DataFrame.from_dict(kind_goodscount,orient='index')
kdf.columns = ['Counts']
kdf = kdf.sort(columns='Counts',ascending=False)
#kdf.to_excel("k_goods.xlsx",encoding='utf-8')

# %%
with open("../resources/partof_prov_bounds.json","r",encoding='utf-8') as fp:
    partof_lookup = json.load(fp)

# %%
prov_sp_goods = {}
for i in db:
    if 'spec_goods' in db[i]:
        if not pd.isnull(db[i]['admin1_partofID']) and db[i]['admin1_partofID'] != 'нот_ин_теxт':
            partof_name = partof_lookup[str(float(db[i]['admin1_partofID']))]['name']
        else:
            partof_name = 'None'
        if partof_name not in prov_sp_goods:
            prov_sp_goods[partof_name] = {}
        for good in db[i]['spec_goods']:
            if good not in prov_sp_goods[partof_name]:
                prov_sp_goods[partof_name][good] = 1
            else:
                prov_sp_goods[partof_name][good]+=1

# %%
#pd.DataFrame.from_dict(prov_sp_goods).to_excel('sp_byprov.xlsx',encoding='utf-8')

# %%
with open('test.json','w',encoding='utf-8') as fp:
    json.dump(db,fp)

# %%
prov_k_goods = {}
for i in db:
    if 'kind_goods' in db[i]:
        if not pd.isnull(db[i]['admin1_partofID']) and db[i]['admin1_partofID'] != 'нот_ин_теxт':
            partof_name = partof_lookup[str(float(db[i]['admin1_partofID']))]['name']
        else:
            partof_name = 'None'
        if partof_name not in prov_k_goods:
            prov_k_goods[partof_name] = {}
        for good in db[i]['kind_goods']:
            if good not in prov_k_goods[partof_name]:
                prov_k_goods[partof_name][good] = 1
            else:
                prov_k_goods[partof_name][good]+=1

# %%
#pd.DataFrame.from_dict(prov_k_goods).to_excel('k_byprov.xlsx',encoding='utf-8')

# %% [markdown]
# When are the markets?
# =====================
# Here we are looking for dates of markets, mostly explicit, calendar dates, but also dates that are implicit in religious holidays.

# %%
def date_range_finder(text):
    """
    Takes a text entry and uses a series of regexes to find start and end dates in given text
    """
    monthlist = ["Генваря","Февраля","Марта","Апреля","Мая","Июня","Июля","Августа","Сентября","Октября","Ноября","Декабря"]
    remonth = "|".join(monthlist)
    ranges = []
    range1 = re.findall(r"с\s+([0-9]+)\s+({})\s+по\s+([0-9]+)\s+({})".format(remonth,remonth),text)
    if len(range1)!=0:
        for r in range1:
            temp = {'beg_mon':r[1],'beg_day':r[0],'end_mon':r[3],'end_day':r[2]}
            ranges.append(temp)
    range2 = re.findall(r"({})\s+с\s+([0-9]+)\s+({})\s+по\s+([0-9]+)".format(remonth,remonth),text)
    if len(range2)!=0:
        for r in range2:
            temp = {'beg_mon':r[0],'beg_day':r[1],'end_mon':r[2],'end_day':r[3]}
            ranges.append(temp)
    range3 = re.findall(r"({})\s+от\s+([0-9]+)\s+по\s+([0-9]+)".format(remonth,remonth),text)
    if len(range3)!=0:
        for r in range3:
            temp = {'beg_mon':r[0],'beg_day':r[1],'end_mon':r[0],'end_day':r[2]}
            ranges.append(temp)
    return ranges

# %%
def single_date_finder(text):
    """
    Finds single dates using various regexes and returns them as a list of date ranges
    """
    monthlist = ["Генваря","Февраля","Марта","Апреля","Мая","Июня","Июля","Августа","Сентября","Октября","Ноября","Декабря"]
    remonth = "|".join(monthlist)
    ranges = []
    dates1 = re.findall(r"([а-яА-Я0-9:,]+)\s+([а-яА-Я0-9:,]+)\s+([0-9]+)\s+({})".format(remonth),text)
    if len(dates1)!=0:
        for r in dates1:
            if r[0] in monthlist and r[1] == 'с':
                pass
            else:
                temp = {'beg_mon':r[3],'beg_day':r[2],'end_mon':r[3],'end_day':r[2]}
                ranges.append(temp)
    dates2 = re.findall(r"({})\s+(?:по|от|на|с|в)?(?:\s+)?([0-9]+)".format(remonth),text)
    if len(dates2)!=0:
        for r in dates2:
            temp = {'beg_mon':r[0],'beg_day':r[1],'end_mon':r[0],'end_day':r[1]}
            ranges.append(temp)
    return(ranges)

# %%
for i in db:
    ranges = date_range_finder(db[i]['description_new_orth'])
    ranges1 = single_date_finder(db[i]['description_new_orth'])
    if len(ranges)!=0 and len(ranges1)!=0:
        to_rm = []
        for ind1 in range(0,len(ranges1)):
            for ind in range(0,len(ranges)):
                if ranges[ind]['beg_mon'] == ranges1[ind1]['beg_mon'] and ranges[ind]['beg_day'] == ranges1[ind1]['beg_day']:
                    to_rm.append(ranges1[ind1])
                elif ranges[ind]['end_mon'] == ranges1[ind1]['end_mon'] and ranges[ind]['end_day'] == ranges1[ind1]['end_day']:
                    to_rm.append(ranges1[ind1])
        for p in to_rm:
            ranges1.remove(p)
    ranges.extend(ranges1)
    if len(ranges)!=0:
        db[i]['fair_dates']=ranges
        print(db[i]['description_new_orth'])
        for r in ranges:
            print("{beg_mon} {beg_day} - {end_mon} {end_day}".format(**r))
        print()
# Out:
# КРАСНОКУТСК, город Харьковского Наместничества. Здесь бывает в году четыре ярмарки: первая в пост о Крестопоклонной неделе , вторая Апреля 23, третия Июня 29, четвертая Ноября 21; приезжают на оные купцы из разных Российских городов; привозят шелковые и прочие товары , позументы, серебро в посуде и прочее; торгуют тут же скотом и лошадьми.
# Апреля 23 - Апреля 23
# Июня 29 - Июня 29
# Ноября 21 - Ноября 21
#
# ФЛОРОВО , село того же Наместничества и уезду. В сем селе бывают торговые съезды Июня 23 и Августа 18 числа.
# Июня 23 - Июня 23
# Августа 18 - Августа 18
#
# ЛЬГОВ, город Курского Наместничества. В немЬ, кроме еженедельного торгу, бывают в году две ярмарки: первая в Иванов день 24 Июня , вторая Сентября 1 числа, продолжающияся по два и по три дни, на которые Курские, Севские и Рыльские купцы привозят сукна , шелковые разные материи и мелкия вещи ; также довольно пригоняют туда с заводов лошадей.
# Июня 24 - Июня 24
# Сентября 1 - Сентября 1
#
# 657: СТАРОДУБ, с 1782 году город Новогородскаго-Северского Наместничества. В оном бывают в году ярмарки , одна на второй неделе великого поста, а другая после Светлого Воскресения на десятой ; торгуют на оных и в обыкновенные недельные торжхи мелкими красными товарами , сукнами , шелковыми материями, привозимыми из других соседственных мест. Купечество сего города отправляет к портам Рижскому и Санктпетербургскому пеньку и канаты, а в окольные места воск , лен , щетину , масло конопляное , смолу , рогожи , разную деревянную, стеклянную , хрустальную посуду и горячее вино.
#
# 794: ЯКУТСК, с 1783 году город Иркутского Наместничества. Здесь бывают ярмарки в Декабре, в Июне, в Июле и Августе месяцах, когда из разных городов наплывают  сверху Лены реки со всякими товарами купцы.
#
# 122: ВОРОНЕЖ, главный город Наместничества сего имени. В нем, кроме еженедельных по понедельникам , середам и пятницам торгов , бывают в году две ярмарки: первая в городе о десятой пятнице , а последняя при слободе Чижовке в 29 день Августа.
#
# 788: ЮРЬЕВ ПОЛЬСКИЙ, с 1778 году город Володимерского Наместничества. Жители оного промышляют юфтью , также мелочными товарами и огородными работами.
#
# 651: СТАВРОПОЛЬ, с 1780 году город Синбирского Наместничества. В оном бывает один базарной день во вторник.
#
# 100: ВЕЛИЖ, город Полотского Наместничества. В сем городе бывает в году две ярмарки : первая 2о Июля , вторая на первой неделе великого поста.
#
# 792: ЯДРИН, с 1781 году город Казанского Наместничества. В оном городе и в уезде ярмарок нет, а бывают торжки малые в каждой неделе по одному дню; товар бывает крестьянской , а заморских товаров в приводе не бывает.
#
# 610: СВИАЖСК, с 1781 году город Казанского Наместничества. Здесь бывает ярмарка, и торгуют на оной мелочными товарами и съестными припасами.
#
# 633: СКОПИН, с 1778 году город Рязанского Наместничества. Здесь бывает ярмарка после Светлой недели в девятую , в десятую и во вторуюнадесять пятницы; товары привозят из иных городов и из уездов крестьянские, съестные и прочие, что до обывательских крестьянских нужд принадлежит.

# %%
db['213']

# %%
date_range_finder('ЕЛЕЦ, город Орловского Наместничества. Здесь бывают торжки в Аргамачей слободе Сентября в 8 день, а в уезде его в селе Подворгальском Мая 21, при Тешевском')

# %% [markdown]
# for e in db:
#     temp_goodslist = word_case_sent_finder(['приезжают','привозят','торгуют','съежаются','скупают','покупают'],r"[а-яА-Я]+(?:ми|ом)$",db[e]['description_new_orth'])
#     goodsfrom = [g for g in temp_goodslist if re.match(r"^[А-Я]",g)]
#     goodskinds = [g for g in temp_goodslist if re.match(r"^[а-я]",g)]
#     removelist = ['купеческими','издельями','каждом','какими','привозимыми','котором','чими','своими','продуктами','коими','пенечными','семи','оном','товарами','товаром','вещами','всякими','другими','другом','ими','различными','разными','торгом','том','числом','неводными']
#     for i in removelist:
#         if i in goodskinds:
#             goodskinds.remove(i)
#     if len(goodsfrom)!=0:
#         db[e]['goodsfrom']=goodsfrom
#     if len(goodskinds)!=0:
#         db[e]['goodskinds'] = goodskinds

# %% [markdown]
# counter=0
# for e in db:
#     if 'goodskinds' in db[e]:
#         print(db[e]['goodskinds'])
#         counter += 1

# %%
#counter

# %%
with open("enhanced_dataset.json","w",encoding='utf-8') as fp:
    json.dump(db,fp,indent=2)

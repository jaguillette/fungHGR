# %%
from lxml import html
import os, json, re, nltk
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
mpl.rc('font', family='Constantia')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test', 'text', 'f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
mypath = "../html/"
onlyfiles = [ "../html/{}".format(f) for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath,f)) ]

# %%
fulltext = ""
for f in onlyfiles:
    tree = html.parse(f)
    root = tree.getroot()
    text = root.text_content()
    fulltext += " " + text

# %%
fulltext = fulltext.replace("\xa0"," ")

# %%
fulltext = re.sub(r"([> ])ВЪ",r"\1Въ",fulltext)
fulltext = re.sub(r"([а-яіѣѳ]+)(Ѣ)",r"\1ѣ",fulltext)
fulltext = re.sub(r"(Ѣ)([а-яіѣѳ]+)",r"ѣ\2",fulltext)
fulltext = re.sub(r"([а-яіѣѳ]+)(Ъ)",r"\1ъ",fulltext)

# %%
import re,json
from lxml import html

with open("../resources/special_cases.json",'r',encoding='utf-8') as fp:
    lookup_dict = json.load(fp)

def ortho_rules(text,lookup_dict):
    """
    Takes a text string and a lookup dict as input
    Removes any lingering html tags
    Breaks the string down into component words with split
    Uses replacements to modernize orthography
    Returns re-assembled text with modern orthography
    """
    if type(text)==str:
        text = html.fromstring(text).text_content()
        textlist = text.split(' ')
        out_list = []
        for word in textlist:
            if word in [',','.',';',':']:
                out_list.append(word)
                continue
            punct = ""
            if len(re.findall(r"([,.;:])$",word))!=0:
                   punct = re.findall(r"([,.;:])$",word)[0]
            word = word.strip(',.;:')
            if word in lookup_dict:
                word = lookup_dict[word]
                out_list.append(word)
            else:
                word = re.sub("[Ъъ]$",'',word)
                word = re.sub(r"^([че]{0,2}[ч]?[вбнр]?[веоаи])з([ПФКТШСЧпфктшсч])",r"\1с\2",word,re.IGNORECASE)
                word = re.sub("аго$","ого",word,re.IGNORECASE)
                word = re.sub("яго$","его",word,re.IGNORECASE)
                word = re.sub("ыя$","ые",word,re.IGNORECASE)
                word = re.sub("iя$","ие",word,re.IGNORECASE)
                word = word.replace('i','и') #english
                word = word.replace('I','И') #english
                word = word.replace('і','и') #cyrillic
                word = word.replace('І','И') #cyrillic
                word = word.replace('Ѣ','Е')
                word = word.replace('ѣ','е')
                word = word.replace('Ѳ','Ф')
                word = word.replace('ѳ','ф')
                word += punct
                out_list.append(word)
        out_str = ' '.join(out_list)
        return out_str
    else:
        return None

# %%
fulltext = ortho_rules(fulltext,lookup_dict)

# %% [markdown]
# Fulltext is now ready to be parsed
# ==================================

# %%
tokens = nltk.tokenize.wordpunct_tokenize(fulltext)

# %%
ru_stemmer = nltk.SnowballStemmer('russian')

# %%
reverse_stem = {}
for w in set(tokens):
    if ru_stemmer.stem(w) not in reverse_stem:
        reverse_stem[ru_stemmer.stem(w)] = []
    reverse_stem[ru_stemmer.stem(w)].append(w)

# %%
tok_stems = [ru_stemmer.stem(w) for w in tokens]

# %%
text = nltk.text.Text(tokens)
stem_text = nltk.text.Text(tok_stems)

# %%
freq = nltk.FreqDist(text)

# %%
freq.plot(25,cumulative=True)

# %%
freq.most_common()
# Out:
# [(',', 3402),
#  ('.', 1801),
#  ('в', 1546),
#  ('и', 1155),
#  ('Наместничества', 716),
#  ('бывает', 594),
#  (';', 475),
#  ('на', 462),
#  ('В', 441),
#  ('с', 425),
#  ('году', 425),
#  ('уезде', 382),
#  ('из', 371),
#  ('ярмарки', 360),
#  ('товарами', 352),
#  ('ярмарка', 351),
#  ('Здесь', 313),
#  ('день', 294),
#  ('купцы', 291),
#  ('город', 289),
#  ('оном', 233),
#  ('бывают', 231),
#  ('приезжают', 231),
#  ('по', 224),
#  (':', 220),
#  ('торгуют', 207),
#  ('городов', 206),
#  ('село', 190),
#  ('первая', 183),
#  ('мелочными', 181),
#  ('разными', 168),
#  ('вторая', 166),
#  ('а', 150),
#  ('местечко', 144),
#  ('города', 127),
#  ('три', 122),
#  ('Июля', 121),
#  ('две', 120),
#  ('дня', 117),
#  ('третия', 113),
#  ('одна', 111),
#  ('товары', 111),
#  ('годовая', 106),
#  ('привозят', 102),
#  ('нем', 98),
#  ('оные', 97),
#  ('8', 95),
#  ('Сентября', 95),
#  ('разных', 90),
#  ('Июня', 87),
#  ('-', 84),
#  ('1', 84),
#  ('шелковыми', 81),
#  ('также', 77),
#  ('крестьяне', 75),
#  ('прочими', 74),
#  ('Августа', 72),
#  ('для', 71),
#  ('неделе', 71),
#  ('уезду', 70),
#  ('оной', 70),
#  ('слобода', 69),
#  ('хлебом', 68),
#  ('же', 66),
#  ('четыре', 66),
#  ('сем', 66),
#  ('вином', 65),
#  ('6', 63),
#  ('пятницу', 62),
#  ('Маия', 59),
#  ('четвертая', 58),
#  ('то', 57),
#  ('год', 57),
#  ('оных', 55),
#  ('Генваря', 53),
#  ('скотом', 53),
#  ('9', 53),
#  ('Октября', 51),
#  ('которую', 50),
#  ('бумажными', 50),
#  ('29', 49),
#  ('жители', 49),
#  ('оную', 49),
#  ('Киевского', 49),
#  ('Губернии', 48),
#  ('припасами', 47),
#  ('Декабря', 47),
#  ('Ноября', 47),
#  ('торг', 46),
#  ('десятую', 46),
#  ('того', 45),
#  ('Московской', 44),
#  ('мелочные', 44),
#  ('Пасхе', 44),
#  ('На', 43),
#  ('Богородицы', 43),
#  ('которые', 42),
#  ('съезжаются', 42),
#  ('15', 42),
#  ('сего', 41),
#  ('Харьковского', 41),
#  ('городе', 41),
#  ('ближних', 40),
#  ('хлеб', 40),
#  ('от', 40),
#  ('Купцы', 40),
#  ('съестными', 39),
#  ('прочие', 39),
#  ('неделю', 39),
#  ('здесь', 39),
#  ('дни', 39),
#  ('другая', 39),
#  ('прочимъ', 38),
#  ('близ', 37),
#  ('разные', 36),
#  ('разным', 36),
#  ('шелковые', 36),
#  ('Могилевского', 36),
#  ('Екатеринославского', 36),
#  ('Черниговского', 35),
#  ('съестные', 35),
#  ('селе', 35),
#  ('лежащих', 35),
#  ('числа', 35),
#  ('как', 35),
#  ('Тульского', 34),
#  ('20', 34),
#  ('торжки', 34),
#  ('горячим', 34),
#  ('23', 33),
#  ('продают', 33),
#  ('других', 32),
#  ('24', 32),
#  ('два', 31),
#  ('монастырь', 31),
#  ('лошадей', 31),
#  ('месяце', 31),
#  ('Рижского', 31),
#  ('кроме', 30),
#  ('припасы', 30),
#  ('посудою', 30),
#  ('не', 30),
#  ('Тамбовского', 30),
#  ('кожами', 30),
#  ('Российских', 29),
#  ('которой', 29),
#  ('части', 29),
#  ('Полотского', 29),
#  ('большей', 29),
#  ('25', 28),
#  ('да', 28),
#  ('прочее', 28),
#  ('Ярославского', 27),
#  (')', 27),
#  ('14', 27),
#  ('Новогородского', 27),
#  ('торгу', 27),
#  ('приезжие', 27),
#  ('сверх', 27),
#  ('после', 27),
#  ('Тверского', 26),
#  ('Вологодского', 26),
#  ('лошадьми', 26),
#  ('десятой', 26),
#  ('мелочным', 25),
#  ('о', 25),
#  ('оного', 25),
#  ('рыбою', 25),
#  ('торги', 25),
#  ('товаромъ', 25),
#  ('еженедельные', 24),
#  ('уездов', 24),
#  ('поста', 24),
#  ('но', 24),
#  ('всякими', 24),
#  ('продолжается', 24),
#  ('окрестных', 24),
#  ('пивомъ', 24),
#  ('обыватели', 23),
#  ('2', 23),
#  ('мест', 23),
#  ('Ярославля', 23),
#  ('месте', 23),
#  ('26', 23),
#  ('или', 22),
#  ('главный', 22),
#  ('товаром', 22),
#  ('имени', 22),
#  ('во', 22),
#  ('21', 22),
#  ('деревянною', 22),
#  ('число', 22),
#  ('Дворца', 22),
#  ('Святого', 21),
#  ('Господня', 21),
#  ('торгов', 21),
#  ('овчинами', 21),
#  ('холст', 21),
#  ('крестьянскими', 21),
#  ('Июне', 21),
#  ('проч', 20),
#  ('какъ', 20),
#  ('Пензенского', 20),
#  ('воск', 20),
#  ('другими', 20),
#  ('всякие', 20),
#  ('один', 20),
#  ('Апреля', 20),
#  ('масло', 20),
#  ('Калужского', 19),
#  ('Духа', 19),
#  ('Николая', 19),
#  ('время', 19),
#  ('великого', 19),
#  ('со', 19),
#  ('мед', 19),
#  ('скот', 19),
#  ('медом', 19),
#  ('недели', 19),
#  ('годовые', 19),
#  ('Костромского', 18),
#  ('Великороссийские', 18),
#  ('Сошествия', 18),
#  ('Орловского', 18),
#  ('Марта', 18),
#  ('Великомученика', 18),
#  ('Рязанского', 18),
#  ('еженедельных', 18),
#  ('около', 18),
#  ('Курского', 18),
#  ('обывателей', 18),
#  ('При', 17),
#  ('всякой', 17),
#  ('сюда', 17),
#  ('Углича', 17),
#  ('1780', 17),
#  ('съезд', 17),
#  ('там', 17),
#  ('Петра', 17),
#  ('продажу', 17),
#  ('Псковского', 17),
#  ('чисел', 17),
#  ('окольные', 17),
#  ('при', 17),
#  ('сукна', 17),
#  ('Российские', 17),
#  ('Рождества', 17),
#  ('мелкими', 16),
#  ('только', 16),
#  ('уездных', 16),
#  ('называемая', 16),
#  ('своими', 16),
#  ('Павла', 16),
#  ('ярмарок', 16),
#  ('Июле', 16),
#  ('Тулы', 16),
#  ('Северского', 16),
#  ('Илии', 16),
#  ('Чудотворца', 16),
#  ('Св', 16),
#  ('тожь', 16),
#  ('продажи', 16),
#  ('дней', 15),
#  ('крестьянство', 15),
#  ('красным', 15),
#  ('Пресвятые', 15),
#  ('которых', 15),
#  ('Серпухова', 15),
#  ('уездные', 15),
#  ('родящимися', 15),
#  ('у', 15),
#  ('Вознесения', 15),
#  ('дегтем', 15),
#  ('Пророка', 15),
#  ('Бывает', 15),
#  ('красными', 14),
#  ('окольных', 14),
#  ('что', 14),
#  ('С', 14),
#  ('москотильные', 14),
#  ('есть', 14),
#  ('соль', 14),
#  ('купечество', 14),
#  ('девятую', 14),
#  ('понедельник', 14),
#  ('пенька', 14),
#  ('рогатой', 14),
#  ('шерстяными', 14),
#  ('лавочными', 14),
#  ('ярмарку', 14),
#  ('погост', 14),
#  ('одному', 13),
#  ('продаже', 13),
#  ('Нижегородского', 13),
#  ('пятнице', 13),
#  ('пяток', 13),
#  ('Покрова', 13),
#  ('продолжающаяся', 13),
#  ('за', 13),
#  ('Сюда', 13),
#  ('Зарайска', 13),
#  ('пять', 13),
#  ('частию', 13),
#  ('кожи', 13),
#  ('селах', 13),
#  ('числу', 13),
#  ('Воронежского', 13),
#  ('смолу', 13),
#  ('верстах', 13),
#  ('Синбирского', 13),
#  ('1779', 13),
#  ('более', 12),
#  ('Динабурга', 12),
#  ('москотильными', 12),
#  ('Иоанна', 12),
#  ('еженедельного', 12),
#  ('Российскими', 12),
#  ('изделье', 12),
#  ('пенькою', 12),
#  ('Каширском', 12),
#  ('Миргородском', 12),
#  ('Преображения', 12),
#  ('Преполовения', 12),
#  ('слободы', 12),
#  ('малому', 12),
#  ('Пасхи', 12),
#  ('материи', 12),
#  ('пивом', 12),
#  ('понедельникам', 12),
#  ('1778', 12),
#  ('каждую', 12),
#  ('коих', 12),
#  ('Февраля', 12),
#  ('съезды', 12),
#  ('Каширы', 12),
#  ('Лубенском', 12),
#  ('Москвы', 12),
#  ('прочия', 12),
#  ('до', 12),
#  ('пятницам', 11),
#  ('горячее', 11),
#  ('к', 11),
#  ('большею', 11),
#  ('б', 11),
#  ('пеньку', 11),
#  ('Георгия', 11),
#  ('иногда', 11),
#  ('рогатым', 11),
#  ('Владимерского', 11),
#  ('каждой', 11),
#  ('Апостолов', 11),
#  ('месяца', 11),
#  ('пятая', 11),
#  ('прочим', 11),
#  ('Изюма', 11),
#  ('успения', 11),
#  ('Переславля', 11),
#  ('7', 11),
#  ('вино', 11),
#  ('сукнами', 11),
#  ('товаров', 11),
#  ('издельями', 11),
#  ('Волоколамском', 11),
#  ('праздник', 11),
#  ('дню', 11),
#  ('Сентябре', 10),
#  ('салом', 10),
#  ('Наместничестве', 10),
#  ('такожь', 10),
#  ('холсты', 10),
#  ('делающимися', 10),
#  ('пустыня', 10),
#  ('купцов', 10),
#  ('тому', 10),
#  ('Динабургском', 10),
#  ('Иркутского', 10),
#  ('Венева', 10),
#  ('рыбу', 10),
#  ('иностранные', 10),
#  ('которая', 10),
#  ('Крымскую', 10),
#  ('обыкновенных', 10),
#  ('Воскресенье', 10),
#  ('другие', 10),
#  ('бумажные', 10),
#  ('Торгуют', 10),
#  ('числах', 10),
#  ('холстом', 9),
#  ('Донских', 9),
#  ('Володимерского', 9),
#  ('посуду', 9),
#  ('привозятся', 9),
#  ('16', 9),
#  ('покупают', 9),
#  ('Богоявления', 9),
#  ('первой', 9),
#  ('съезжается', 9),
#  ('Великороссийских', 9),
#  ('месяцах', 9),
#  ('Залеского', 9),
#  ('монастыре', 9),
#  ('Сырной', 9),
#  ('каждонедельно', 9),
#  ('несколько', 9),
#  ('1782', 9),
#  ('гарусными', 9),
#  ('крестьян', 9),
#  ('солью', 9),
#  ('5', 9),
#  ('деревянное', 9),
#  ('льняные', 8),
#  ('произрастениями', 8),
#  ('субботу', 8),
#  ('колесами', 8),
#  ('17', 8),
#  ('люди', 8),
#  ('хлебомъ', 8),
#  ('железом', 8),
#  ('так', 8),
#  ('Приезжают', 8),
#  ('сел', 8),
#  ('ярмарокъ', 8),
#  ('ярмарках', 8),
#  ('множество', 8),
#  ('еще', 8),
#  ('чрез', 8),
#  ('Казанского', 8),
#  ('пряжу', 8),
#  ('своей', 8),
#  ('Калуги', 8),
#  ('торговые', 8),
#  ('деревня', 8),
#  ('шесть', 8),
#  ('Пермского', 8),
#  ('Романова', 8),
#  ('мелкою', 8),
#  ('Малороссийских', 8),
#  ('жителям', 8),
#  ('28', 8),
#  ('шанец', 8),
#  ('начинается', 7),
#  ('коей', 7),
#  ('соседственных', 7),
#  ('сей', 7),
#  ('крестьянства', 7),
#  ('сало', 7),
#  ('Дня', 7),
#  ('именно', 7),
#  ('скупают', 7),
#  ('Пскова', 7),
#  ('1781', 7),
#  ('торговли', 7),
#  ('Переяславском', 7),
#  ('воскресеньям', 7),
#  ('монастыря', 7),
#  ('18', 7),
#  ('особливо', 7),
#  ('Михаила', 7),
#  ('вещи', 7),
#  ('раза', 7),
#  ('свои', 7),
#  ('скотину', 7),
#  ('числе', 7),
#  ('Вологодские', 7),
#  ('праздника', 7),
#  ('недельные', 7),
#  ('деревень', 7),
#  ('собираются', 7),
#  ('прочих', 7),
#  ('пятницы', 7),
#  ('4', 7),
#  ('Саратовского', 7),
#  ('стеклянною', 7),
#  ('рукоделия', 7),
#  ('1777', 7),
#  ('купцам', 7),
#  ('обывателями', 7),
#  ('Иногда', 7),
#  ('продолжаются', 7),
#  ('Маие', 7),
#  ('Полтавском', 7),
#  ('рухлядь', 7),
#  ('30', 7),
#  ('торговых', 7),
#  ('парчи', 7),
#  ('станиц', 7),
#  ('Суздальском', 6),
#  ('Смоленского', 6),
#  ('Прилуцком', 6),
#  ('Казанския', 6),
#  ('вещами', 6),
#  ('еженедельной', 6),
#  ('одинадцатой', 6),
#  ('Уфимского', 6),
#  ('середам', 6),
#  ('Рогачева', 6),
#  ('Троицы', 6),
#  ('Успения', 6),
#  ('братьи', 6),
#  ('парусную', 6),
#  ('Елецкие', 6),
#  ('Борисоглебска', 6),
#  ('Пошехонском', 6),
#  ('продолжающияся', 6),
#  ('прочею', 6),
#  ('приезжает', 6),
#  ('слободе', 6),
#  ('мелочью', 6),
#  ('деревянную', 6),
#  ('покупки', 6),
#  ('годовой', 6),
#  ('Параскевы', 6),
#  ('волость', 6),
#  ('Архистратига', 6),
#  ('крепость', 6),
#  ('второй', 6),
#  ('привозимыми', 6),
#  ('их', 6),
#  ('Провинции', 6),
#  ('близости', 6),
#  ('дням', 6),
#  ('уездными', 6),
#  ('Димитрия', 6),
#  ('Выборгского', 6),
#  ('мягкую', 6),
#  ('четверток', 6),
#  ('19', 6),
#  ('Предтечи', 6),
#  ('торговля', 6),
#  ('небогатыми', 6),
#  ('Светлого', 6),
#  ('места', 6),
#  ('овчины', 6),
#  ('Бежецком', 6),
#  ('Августе', 6),
#  ('еженедельно', 6),
#  ('Сибири', 6),
#  ('всеедной', 6),
#  ('Кашинском', 6),
#  ('купцами', 6),
#  ('городка', 6),
#  ('котором', 5),
#  ('весною', 5),
#  ('Богоматери', 5),
#  ('Воскресения', 5),
#  ('2о', 5),
#  ('Троицын', 5),
#  ('льняной', 5),
#  ('вторникам', 5),
#  ('шелковых', 5),
#  ('рухлядью', 5),
#  ('Белева', 5),
#  ('полотном', 5),
#  ('сих', 5),
#  ('27', 5),
#  ('Саранском', 5),
#  ('бумажных', 5),
#  ('Гадяцком', 5),
#  ('последних', 5),
#  ('торговъ', 5),
#  ('шестая', 5),
#  ('кои', 5),
#  ('позументы', 5),
#  ('посконной', 5),
#  ('москотильной', 5),
#  ('3', 5),
#  ('Октябре', 5),
#  ('железные', 5),
#  ('отчине', 5),
#  ('пригород', 5),
#  ('токмо', 5),
#  ('том', 5),
#  ('Боровска', 5),
#  ('Валуек', 5),
#  ('Челябинском', 5),
#  ('Тобольского', 5),
#  ('великая', 5),
#  ('Христова', 5),
#  ('месяцахъ', 5),
#  ('Стародубовском', 5),
#  ('лен', 5),
#  ('Воздвижения', 5),
#  ('сырейные', 5),
#  ('НИКОЛАЕВСКОЙ', 5),
#  ('набойчатыми', 5),
#  ('лавочным', 5),
#  ('среду', 5),
#  ('пригоняют', 5),
#  ('коровье', 5),
#  ('Святителя', 5),
#  ('ежегодно', 5),
#  ('раз', 5),
#  ('Шатском', 5),
#  ('дважды', 5),
#  ('Святых', 5),
#  ('честного', 5),
#  ('церкви', 5),
#  ('собою', 5),
#  ('зимнее', 5),
#  ('сеном', 5),
#  ('крамными', 5),
#  ('всех', 5),
#  ('днем', 5),
#  ('Малороссийские', 5),
#  ('воскресным', 5),
#  ('начинающаяся', 5),
#  ('Алексина', 5),
#  ('уточную', 5),
#  ('Святые', 5),
#  ('иностранными', 5),
#  ('вина', 5),
#  ('Елецком', 5),
#  ('они', 5),
#  ('первую', 5),
#  ('Богослова', 4),
#  ('шерстью', 4),
#  ('четырех', 4),
#  ('некоторые', 4),
#  ('воском', 4),
#  ('мелочной', 4),
#  ('торговой', 4),
#  ('сортов', 4),
#  ('сию', 4),
#  ('хлебъ', 4),
#  ('перед', 4),
#  ('осенью', 4),
#  ('те', 4),
#  ('говяжьи', 4),
#  ('временем', 4),
#  ('привозит', 4),
#  ('произрастения', 4),
#  ('мягкою', 4),
#  ('Тройцын', 4),
#  ('построены', 4),
#  ('все', 4),
#  ('Россия', 4),
#  ('ь', 4),
#  ('скотиною', 4),
#  ('Рогачевском', 4),
#  ('между', 4),
#  ('полотна', 4),
#  ('первых', 4),
#  ('Яренска', 4),
#  ('Острова', 4),
#  ('Живоначальные', 4),
#  ('Мстиславском', 4),
#  ('шерстяные', 4),
#  ('Рузы', 4),
#  ('Новосиля', 4),
#  ('жителями', 4),
#  ('Воскресеньям', 4),
#  ('говяжьими', 4),
#  ('расстоянием', 4),
#  ('поселян', 4),
#  ('вторник', 4),
#  ('торгует', 4),
#  ('Климовицком', 4),
#  ('Бывают', 4),
#  ('паче', 4),
#  ('ряды', 4),
#  ('знатные', 4),
#  ('ми', 4),
#  ('прежде', 4),
#  ('Козельском', 4),
#  ('крестьянския', 4),
#  ('небольшой', 4),
#  ('двух', 4),
#  ('состоит', 4),
#  ('Графа', 4),
#  ('Генваре', 4),
#  ('Рыбного', 4),
#  ('одинадцатую', 4),
#  ('привозимые', 4),
#  ('1775', 4),
#  ('Мещовска', 4),
#  ('холстами', 4),
#  ('пред', 4),
#  ('рукоделье', 4),
#  ('Харькова', 4),
#  ('Нежина', 4),
#  ('лавок', 4),
#  ('крестьянам', 4),
#  ('материями', 4),
#  ('Изюмском', 4),
#  ('недорогими', 4),
#  ('ПОКРОВСКОЕ', 4),
#  ('Екатеринославском', 4),
#  ('Феврале', 4),
#  ('вощину', 4),
#  ('бываетъ', 4),
#  ('мелочных', 4),
#  ('железо', 4),
#  ('отправляются', 4),
#  ('ней', 4),
#  ('Святой', 4),
#  ('привозимою', 4),
#  ('много', 4),
#  ('городок', 4),
#  ('посуда', 4),
#  ('Вятского', 4),
#  ('производится', 4),
#  ('рукоделья', 4),
#  ('Олонецкого', 4),
#  ('изделья', 4),
#  ('под', 4),
#  ('субботние', 4),
#  ('заячьи', 4),
#  ('субботам', 4),
#  ('количестве', 4),
#  ('серебро', 4),
#  ('Можайском', 4),
#  ('Пятидесятницы', 4),
#  ('Петрова', 4),
#  ('разную', 4),
#  ('глиняною', 4),
#  ('ИВАНОВСКОЕ', 4),
#  ('сермяжные', 4),
#  ('Покровская', 4),
#  ('холстов', 4),
#  ('мелочьми', 4),
#  ('1776', 4),
#  ('Нежинском', 4),
#  ('торжков', 4),
#  ('тех', 4),
#  ('Вереи', 4),
#  ('море', 4),
#  ('Греки', 4),
#  ('конопляное', 4),
#  ('Вологды', 4),
#  ('Троицкая', 4),
#  ('приезжающих', 4),
#  ('той', 4),
#  ('Великого', 4),
#  ('товар', 3),
#  ('Донковском', 3),
#  ('всяким', 3),
#  ('Дамиана', 3),
#  ('деревянная', 3),
#  ('производят', 3),
#  ('уезда', 3),
#  ('отпускают', 3),
#  ('жителей', 3),
#  ('окрестные', 3),
#  ('собирается', 3),
#  ('пятокъ', 3),
#  ('Кесове', 3),
#  ('товаровъ', 3),
#  ('Ивановская', 3),
#  ('ТИХОНОВА', 3),
#  ('питейными', 3),
#  ('нет', 3),
#  ('Московские', 3),
#  ('медочными', 3),
#  ('торгах', 3),
#  ('великой', 3),
#  ('Козловском', 3),
#  ('съежаются', 3),
#  ('пушные', 3),
#  ('шубами', 3),
#  ('лыками', 3),
#  ('Рузском', 3),
#  ('Р', 3),
#  ('оттуда', 3),
#  ('канаты', 3),
#  ('деревянной', 3),
#  ('Симеона', 3),
#  ('Яренском', 3),
#  ('шелк', 3),
#  ('волчьи', 3),
#  ('Болхова', 3),
#  ('О', 3),
#  ('Великомученицы', 3),
#  ('находятся', 3),
#  ('округе', 3),
#  ('печеным', 3),
#  ('вся', 3),
#  ('годовых', 3),
#  ('местечке', 3),
#  ('материй', 3),
#  ('Жители', 3),
#  ('мехи', 3),
#  ('торгъ', 3),
#  ('седьмой', 3),
#  ('каждогодно', 3),
#  ('*', 3),
#  ('девятой', 3),
#  ('каждое', 3),
#  ('крестьянами', 3),
#  ('Сумском', 3),
#  ('Апостол', 3),
#  ('воскресенье', 3),
#  ('12', 3),
#  ('Можайска', 3),
#  ('МИХАЙЛОВКА', 3),
#  ('Алатырьском', 3),
#  ('Подле', 3),
#  ('ными', 3),
#  ('Казани', 3),
#  ('подобные', 3),
#  ('главы', 3),
#  ('пятниц', 3),
#  ('зимою', 3),
#  ('маслом', 3),
#  ('крамщики', 3),
#  ('сахар', 3),
#  ('Бежецка', 3),
#  ('Ростова', 3),
#  ('рядах', 3),
#  ('иные', 3),
#  ('виномъ', 3),
#  ('серебреными', 3),
#  ('крестьянскою', 3),
#  ('КИРИЛОВ', 3),
#  ('Евстафия', 3),
#  ('городовъ', 3),
#  ('тое', 3),
#  ('скота', 3),
#  ('иногородные', 3),
#  ('однажды', 3),
#  ('отправляет', 3),
#  ('Новагорода', 3),
#  ('льняное', 3),
#  ('Сретения', 3),
#  ('Малого', 3),
#  ('товару', 3),
#  ('Господ', 3),
#  ('назад', 3),
#  ('где', 3),
#  ('малым', 3),
#  ('медвежьи', 3),
#  ('А', 3),
#  ('10', 3),
#  ('двор', 3),
#  ('продажа', 3),
#  ('приуготовлениями', 3),
#  ('суровскими', 3),
#  ('ве', 3),
#  ('усекновения', 3),
#  ('табаком', 3),
#  ('бумагу', 3),
#  ('озера', 3),
#  ('гостиной', 3),
#  ('Фомину', 3),
#  ('саньми', 3),
#  ('всякого', 3),
#  ('Петровская', 3),
#  ('каждонедельные', 3),
#  ('лавки', 3),
#  ('привозными', 3),
#  ('окольными', 3),
#  ('пятой', 3),
#  ('щетиною', 3),
#  ('Мологи', 3),
#  ('коем', 3),
#  ('путем', 3),
#  ('туда', 3),
#  ('разною', 3),
#  ('трех', 3),
#  ('местечка', 3),
#  ('Старой', 3),
#  ('Фоминой', 3),
#  ('острог', 3),
#  ('Иркутска', 3),
#  ('купецкие', 3),
#  ('единожды', 3),
#  ('каждонедельных', 3),
#  ('Шуи', 3),
#  ('соседних', 3),
#  ('Ваий', 3),
#  ('большем', 3),
#  ('четвергам', 3),
#  ('Для', 3),
#  ('сырые', 3),
#  ('здешние', 3),
#  ('1784', 3),
#  ('отсюда', 3),
#  ('Креста', 3),
#  ('льняным', 3),
#  ('каждом', 3),
#  ('дворе', 3),
#  ('Прокопия', 3),
#  ('другия', 3),
#  ('пост', 3),
#  ('Норской', 3),
#  ('11', 3),
#  ('числом', 3),
#  ('первое', 3),
#  ('них', 3),
#  ('имеется', 3),
#  ('Белицком', 3),
#  ('работы', 3),
#  ('Звенигородском', 3),
#  ('семь', 3),
#  ('Ноябре', 3),
#  ('разночинцы', 3),
#  ('Ярославца', 3),
#  ('чай', 3),
#  ('мясами', 3),
#  ('крестьянское', 3),
#  ('больше', 3),
#  ('Столпника', 3),
#  ('крестьянским', 3),
#  ('реки', 3),
#  ('Залесного', 3),
#  ('девять', 3),
#  ('чулки', 3),
#  ('Архангельского', 3),
#  ('13', 3),
#  ('сии', 3),
#  ('22', 3),
#  ('летним', 3),
#  ('торгуютъ', 3),
#  ('Князя', 3),
#  ('Светлой', 3),
#  ('средине', 3),
#  ('ГЛИНСК', 2),
#  ('мелочми', 2),
#  ('сено', 2),
#  ('ТРОИЦКАЯ', 2),
#  ('ВЫСОКОЕ', 2),
#  ('КРАПИВНА', 2),
#  ('пути', 2),
#  ('ПЕТРОВСКАЯ', 2),
#  ('водою', 2),
#  ('ГОРОДИЩЕ', 2),
#  ('приезжающие', 2),
#  ('посад', 2),
#  ('сте', 2),
#  ('Немецкими', 2),
#  ('табак', 2),
#  ('рода', 2),
#  ('ИВАНОВО', 2),
#  ('говяжье', 2),
#  ('БОРИСОГЛЕБСК', 2),
#  ('ОСКОЛ', 2),
#  ('уезд', 2),
#  ('Глеба', 2),
#  ('смежных', 2),
#  ('Троицком', 2),
#  ('пустыне', 2),
#  ('когда', 2),
#  ('Кашина', 2),
#  ('приуготовления', 2),
#  ('Тотемские', 2),
#  ('летнее', 2),
#  ('года', 2),
#  ('саломъ', 2),
#  ('Крестителя', 2),
#  ('родов', 2),
#  ('гарусные', 2),
#  ('Поречье', 2),
#  ('Варвары', 2),
#  ('Купечество', 2),
#  ('осьмь', 2),
#  ('селений', 2),
#  ('Немецких', 2),
#  ('Дни', 2),
#  ('Крымскою', 2),
#  ('устюжского', 2),
#  ('девичий', 2),
#  ('Богоявление', 2),
#  ('медными', 2),
#  ('исключая', 2),
#  ('которого', 2),
#  ('варами', 2),
#  ('разного', 2),
#  ('лето', 2),
#  ('яр', 2),
#  ('рыбы', 2),
#  ('кумачи', 2),
#  ('Воскресение', 2),
#  ('производятъ', 2),
#  ('золотые', 2),
#  ('Козаков', 2),
#  ('тот', 2),
#  ('повсягодно', 2),
#  ('съезда', 2),
#  ('Десне', 2),
#  ('креста', 2),
#  ('Васильевская', 2),
#  ('села', 2),
#  ('Помещиков', 2),
#  ('СПАС', 2),
#  ('большая', 2),
#  ('тамошних', 2),
#  ('реке', 2),
#  ('мяса', 2),
#  ('купецкими', 2),
#  ('Петровым', 2),
#  ('стран', 2),
#  ('Доброй', 2),
#  ('подобнымъ', 2),
#  ('Кадома', 2),
#  ('Г', 2),
#  ('ВЕТКА', 2),
#  ('какими', 2),
#  ('Иванов', 2),
#  ('крестьянские', 2),
#  ('Волхова', 2),
#  ('Николаевского', 2),
#  ...]

# %%
stopwords = ['-',',','.','а','в','и',';','на','В','с','по',':','из'] # "helper" stopwords, to find significant text generally
stopwords.extend(['быва','ярмарк','наместничеств','город','он','год','уезд','зде','ден','сел','перв','проч','втор','а','котор','местечк','годов','недел','одн','дня','три','две','привоз','трет','друг','нем','пятниц','8','слобод','числ','1','такж','август','всяк','десят','для','сем','жител','еженедельн','четыр','же','то','6','четверт','как','съезжа','мест','9','больш','ноябр','месяц','обывател','киевск','29','продаж','монастыр','декабр','губерн','московск']) # words that aren't of interest to this analysis. can be replaced/commented out

# %%
stopped_tokens = [w for w in tok_stems if w not in stopwords]

# %%
stopped_text = nltk.text.Text(stopped_tokens)

# %%
nltk.FreqDist(stopped_text).most_common()
# Out:
# [('товар', 506),
#  ('купц', 354),
#  ('торг', 354),
#  ('разн', 342),
#  ('мелочн', 261),
#  ('приезжа', 252),
#  ('июл', 137),
#  ('шелков', 124),
#  ('хлеб', 117),
#  ('июн', 108),
#  ('сентябр', 107),
#  ('вин', 85),
#  ('крестьян', 82),
#  ('припас', 77),
#  ('скот', 75),
#  ('съестн', 75),
#  ('бумажн', 67),
#  ('ма', 66),
#  ('российск', 64),
#  ('октябр', 58),
#  ('генвар', 57),
#  ('пасх', 56),
#  ('холст', 49),
#  ('горяч', 47),
#  ('посуд', 47),
#  ('деревя', 46),
#  ('продолжа', 45),
#  ('тог', 45),
#  ('богородиц', 44),
#  ('част', 44),
#  ('кож', 43),
#  ('15', 42),
#  ('дни', 41),
#  ('крестьянск', 41),
#  ('сег', 41),
#  ('харьковск', 41),
#  ('от', 40),
#  ('торжк', 40),
#  ('ближн', 40),
#  ('екатеринославск', 40),
#  ('близ', 39),
#  ('уездн', 39),
#  ('велик', 38),
#  ('прочим', 38),
#  ('мед', 38),
#  ('пеньк', 38),
#  ('ил', 38),
#  ('прода', 37),
#  ('рыб', 37),
#  ('лежа', 37),
#  ('свят', 36),
#  ('могилевск', 36),
#  ('съезд', 36),
#  ('окольн', 35),
#  ('черниговск', 35),
#  ('вологодск', 35),
#  ('москотильн', 35),
#  ('красн', 35),
#  ('рижск', 35),
#  ('тульск', 35),
#  ('не', 34),
#  ('20', 34),
#  ('сво', 34),
#  ('кажд', 34),
#  ('при', 34),
#  ('23', 33),
#  ('воскресен', 33),
#  ('24', 32),
#  ('пят', 32),
#  ('кром', 31),
#  ('мелк', 31),
#  ('приезж', 31),
#  ('два', 31),
#  ('лошад', 31),
#  ('тамбовск', 31),
#  ('полотск', 31),
#  ('ко', 30),
#  ('сюд', 30),
#  ('сверх', 30),
#  ('имен', 29),
#  ('понедельник', 29),
#  ('да', 29),
#  ('25', 28),
#  ('о', 28),
#  ('новогородск', 28),
#  ('сукн', 28),
#  ('ярославск', 28),
#  ('рогат', 28),
#  ('великороссийск', 28),
#  ('сол', 27),
#  (')', 27),
#  ('14', 27),
#  ('посл', 27),
#  ('пост', 27),
#  ('овчин', 27),
#  ('окрестн', 27),
#  ('тверск', 27),
#  ('издел', 27),
#  ('торгов', 26),
#  ('лошадьм', 26),
#  ('ярмарок', 25),
#  ('но', 25),
#  ('товаром', 25),
#  ('крестьянств', 24),
#  ('пивом', 24),
#  ('ярославл', 24),
#  ('воск', 24),
#  ('масл', 23),
#  ('во', 23),
#  ('мал', 23),
#  ('2', 23),
#  ('26', 23),
#  ('главн', 23),
#  ('господн', 23),
#  ('дворц', 23),
#  ('лавочн', 23),
#  ('21', 22),
#  ('праздник', 22),
#  ('калужск', 21),
#  ('льнян', 21),
#  ('апрел', 21),
#  ('курск', 20),
#  ('март', 20),
#  ('один', 20),
#  ('казанск', 20),
#  ('рукодел', 20),
#  ('пензенск', 20),
#  ('дух', 20),
#  ('никол', 19),
#  ('рождеств', 19),
#  ('псковск', 19),
#  ('матер', 19),
#  ('сошеств', 19),
#  ('костромск', 19),
#  ('орловск', 19),
#  ('купечеств', 19),
#  ('со', 19),
#  ('врем', 19),
#  ('рязанск', 18),
#  ('там', 18),
#  ('успен', 18),
#  ('углич', 18),
#  ('каждонедельн', 18),
#  ('великомученик', 18),
#  ('девят', 18),
#  ('вознесен', 18),
#  ('окол', 18),
#  ('иногд', 18),
#  ('сал', 18),
#  ('шерстян', 18),
#  ('чисел', 18),
#  ('зарайск', 18),
#  ('тул', 17),
#  ('называ', 17),
#  ('дне', 17),
#  ('иностра', 17),
#  ('привозим', 17),
#  ('1780', 17),
#  ('чудотворц', 17),
#  ('петр', 17),
#  ('св', 17),
#  ('погост', 17),
#  ('у', 17),
#  ('смол', 16),
#  ('павл', 16),
#  ('пяток', 16),
#  ('синбирск', 16),
#  ('тольк', 16),
#  ('феврал', 16),
#  ('тож', 16),
#  ('родя', 16),
#  ('северск', 16),
#  ('пророк', 16),
#  ('пресвят', 15),
#  ('апостол', 15),
#  ('серпухов', 15),
#  ('том', 15),
#  ('дегт', 15),
#  ('иркутск', 15),
#  ('вещ', 14),
#  ('ест', 14),
#  ('что', 14),
#  ('раз', 14),
#  ('торговл', 14),
#  ('преображен', 14),
#  ('верст', 14),
#  ('шест', 14),
#  ('троицк', 14),
#  ('обыкновен', 14),
#  ('миргородск', 13),
#  ('малороссийск', 13),
#  ('динабург', 13),
#  ('нижегородск', 13),
#  ('воронежск', 13),
#  ('изюм', 13),
#  ('покров', 13),
#  ('желез', 13),
#  ('москв', 13),
#  ('небольш', 13),
#  ('за', 13),
#  ('пустын', 13),
#  ('1779', 13),
#  ('начина', 12),
#  ('переславл', 12),
#  ('произрастен', 12),
#  ('каширск', 12),
#  ('1778', 12),
#  ('крымск', 12),
#  ('владимерск', 12),
#  ('иоан', 12),
#  ('волоколамск', 12),
#  ('пив', 12),
#  ('кашир', 12),
#  ('рухляд', 12),
#  ('преполовен', 12),
#  ('суббот', 12),
#  ('мягк', 12),
#  ('бол', 12),
#  ('лубенск', 12),
#  ('до', 12),
#  ('гарусн', 11),
#  ('елецк', 11),
#  ('дела', 11),
#  ('рек', 11),
#  ('петровск', 11),
#  ('богоявлен', 11),
#  ('серед', 11),
#  ('одинадцат', 11),
#  ('к', 11),
#  ('дню', 11),
#  ('бежецк', 11),
#  ('сырн', 11),
#  ('7', 11),
#  ('б', 11),
#  ('скотин', 11),
#  ('вторник', 11),
#  ('покупа', 11),
#  ('георг', 11),
#  ('тобольск', 11),
#  ('венев', 11),
#  ('залеск', 10),
#  ('светл', 10),
#  ('ряд', 10),
#  ('архангельск', 10),
#  ('також', 10),
#  ('особлив', 10),
#  ('деревн', 10),
#  ('полотн', 10),
#  ('мелоч', 10),
#  ('собира', 10),
#  ('си', 10),
#  ('отправля', 10),
#  ('борисоглебск', 10),
#  ('говяж', 10),
#  ('производ', 10),
#  ('станиц', 10),
#  ('динабургск', 10),
#  ('колес', 9),
#  ('недельн', 9),
#  ('донск', 9),
#  ('стекля', 9),
#  ('здешн', 9),
#  ('николаевск', 9),
#  ('пряж', 9),
#  ('16', 9),
#  ('крестья', 9),
#  ('люд', 9),
#  ('5', 9),
#  ('1782', 9),
#  ('нов', 9),
#  ('саратовск', 9),
#  ('володимерск', 9),
#  ('серебрен', 9),
#  ('нескольк', 9),
#  ('знатн', 9),
#  ('деревенск', 9),
#  ('волост', 8),
#  ('небогат', 8),
#  ('се', 8),
#  ('пошехонск', 8),
#  ('всеедн', 8),
#  ('боровск', 8),
#  ('воскресн', 8),
#  ('честн', 8),
#  ('парч', 8),
#  ('можайск', 8),
#  ('покровск', 8),
#  ('железн', 8),
#  ('17', 8),
#  ('множеств', 8),
#  ('последн', 8),
#  ('отчин', 8),
#  ('уфимск', 8),
#  ('так', 8),
#  ('троицын', 8),
#  ('калуг', 8),
#  ('бел', 8),
#  ('крест', 8),
#  ('шанец', 8),
#  ('ещ', 8),
#  ('провинц', 8),
#  ('чрез', 8),
#  ('зимн', 8),
#  ('покупк', 8),
#  ('некотор', 8),
#  ('хлебом', 8),
#  ('псков', 8),
#  ('пермск', 8),
#  ('яренск', 8),
#  ('сен', 8),
#  ('романов', 8),
#  ('28', 8),
#  ('мяс', 8),
#  ('летн', 7),
#  ('позумент', 7),
#  ('полтавск', 7),
#  ('челябинск', 7),
#  ('крепост', 7),
#  ('четверток', 7),
#  ('1781', 7),
#  ('4', 7),
#  ('стар', 7),
#  ('мног', 7),
#  ('китайск', 7),
#  ('рогачев', 7),
#  ('смоленск', 7),
#  ('устюжск', 7),
#  ('1777', 7),
#  ('постро', 7),
#  ('18', 7),
#  ('ивановск', 7),
#  ('сибирск', 7),
#  ('тамошн', 7),
#  ('богородицк', 7),
#  ('соседствен', 7),
#  ('парусн', 7),
#  ('шатск', 7),
#  ('30', 7),
#  ('сибир', 7),
#  ('деревен', 7),
#  ('лен', 7),
#  ('переяславск', 7),
#  ('скупа', 7),
#  ('миха', 7),
#  ('двор', 7),
#  ('', 6),
#  ('предтеч', 6),
#  ('мор', 6),
#  ('параскев', 6),
#  ('табак', 6),
#  ('19', 6),
#  ('поскон', 6),
#  ('немецк', 6),
#  ('купецк', 6),
#  ('руз', 6),
#  ('крамн', 6),
#  ('ча', 6),
#  ('их', 6),
#  ('весн', 6),
#  ('гостин', 6),
#  ('щетин', 6),
#  ('воздвижен', 6),
#  ('козельск', 6),
#  ('продолжающ', 6),
#  ('суздальск', 6),
#  ('пут', 6),
#  ('приуготовлен', 6),
#  ('выборгск', 6),
#  ('дням', 6),
#  ('шерст', 6),
#  ('городок', 6),
#  ('христов', 6),
#  ('троиц', 6),
#  ('коров', 6),
#  ('саранск', 6),
#  ('кашинск', 6),
#  ('близост', 6),
#  ('городк', 6),
#  ('брат', 6),
#  ('петров', 6),
#  ('димитр', 6),
#  ('фомин', 6),
#  ('архистратиг', 6),
#  ('рыбн', 6),
#  ('прилуцк', 6),
#  ('лавк', 5),
#  ('осен', 5),
#  ('ва', 5),
#  ('состо', 5),
#  ('2о', 5),
#  ('щепетильн', 5),
#  ('пригоня', 5),
#  ('никольск', 5),
#  ('сыр', 5),
#  ('пригород', 5),
#  ('грек', 5),
#  ('выбойк', 5),
#  ('месяцах', 5),
#  ('святител', 5),
#  ('ежегодн', 5),
#  ('белозерск', 5),
#  ('гадяцк', 5),
#  ('шелк', 5),
#  ('набойчат', 5),
#  ('сих', 5),
#  ('27', 5),
#  ('нежин', 5),
#  ('высок', 5),
#  ('добр', 5),
#  ('шуб', 5),
#  ('олонецк', 5),
#  ('все', 5),
#  ('седьм', 5),
#  ('3', 5),
#  ('работ', 5),
#  ('сермяжн', 5),
#  ('белев', 5),
#  ('соб', 5),
#  ('стародубовск', 5),
#  ('коноплян', 5),
#  ('всех', 5),
#  ('токм', 5),
#  ('остров', 5),
#  ('днем', 5),
#  ('округ', 5),
#  ('сред', 5),
#  ('мещовск', 5),
#  ('богоматер', 5),
#  ('кесов', 5),
#  ('турецк', 5),
#  ('азиатск', 5),
#  ('сахар', 5),
#  ('валуек', 5),
#  ('алексин', 5),
#  ('уточн', 5),
#  ('гор', 5),
#  ('нужн', 5),
#  ('тройцын', 5),
#  ('церкв', 5),
#  ('чулк', 5),
#  ('острог', 5),
#  ('глинян', 5),
#  ('иногородн', 5),
#  ('росс', 5),
#  ('времен', 5),
#  ('сырейн', 5),
#  ('субботн', 5),
#  ('новосил', 5),
#  ('дважд', 5),
#  ('пушн', 5),
#  ('благовещенск', 4),
#  ('зим', 4),
#  ('посад', 4),
#  ('сумск', 4),
#  ('четырех', 4),
#  ('нежинск', 4),
#  ('сам', 4),
#  ('козловск', 4),
#  ('вологд', 4),
#  ('суровск', 4),
#  ('1775', 4),
#  ('бывш', 4),
#  ('медн', 4),
#  ('лык', 4),
#  ('михайловк', 4),
#  ('харьков', 4),
#  ('молог', 4),
#  ('пред', 4),
#  ('осьм', 4),
#  ('иванов', 4),
#  ('пятидесятниц', 4),
#  ('был', 4),
#  ('економическ', 4),
#  ('заяч', 4),
#  ('мелочьм', 4),
#  ('серебр', 4),
#  ('шу', 4),
#  ('питейн', 4),
#  ('подобн', 4),
#  ('городов', 4),
#  ('перед', 4),
#  ('торгуют', 4),
#  ('те', 4),
#  ('лавок', 4),
#  ('ильинск', 4),
#  ('расстоян', 4),
#  ('пореч', 4),
#  ('лисиц', 4),
#  ('четверг', 4),
#  ('вятск', 4),
#  ('мстиславск', 4),
#  ('холм', 4),
#  ('им', 4),
#  ('польск', 4),
#  ('бывает', 4),
#  ('вощин', 4),
#  ('прежд', 4),
#  ('богоявленск', 4),
#  ('спас', 4),
#  ('богослов', 4),
#  ('приход', 4),
#  ('солен', 4),
#  ('вер', 4),
#  ('волч', 4),
#  ('живоначальн', 4),
#  ('великолуцк', 4),
#  ('лес', 4),
#  ('под', 4),
#  ('бумаг', 4),
#  ('продукт', 4),
#  ('тех', 4),
#  ('вольн', 4),
#  ('ин', 4),
#  ('климовицк', 4),
#  ('уральск', 4),
#  ('поселя', 4),
#  ('межд', 4),
#  ('половин', 4),
#  ('ми', 4),
#  ('съежа', 4),
#  ('граф', 4),
#  ('изюмск', 4),
#  ('керенск', 4),
#  ('борис', 4),
#  ('количеств', 4),
#  ('имеют', 4),
#  ('1776', 4),
#  ('рогачевск', 4),
#  ('недорог', 4),
#  ('собор', 4),
#  ('внутрен', 4),
#  ('род', 4),
#  ('пач', 4),
#  ('сорт', 4),
#  ('тутошн', 4),
#  ('сдела', 4),
#  ('двух', 4),
#  ('торжок', 4),
#  ('тихонов', 4),
#  ('сукон', 4),
#  ('новагород', 3),
#  ('макар', 3),
#  ('вознесенск', 3),
#  ('катайск', 3),
#  ('тут', 3),
#  ('успенск', 3),
#  ('любимск', 3),
#  ('петербург', 3),
#  ('медвеж', 3),
#  ('г', 3),
#  ('порт', 3),
#  ('оттуд', 3),
#  ('озер', 3),
#  ('вод', 3),
#  ('москательн', 3),
#  ('селен', 3),
#  ('нет', 3),
#  ('однажд', 3),
#  ('туд', 3),
#  ('выдр', 3),
#  ('галицк', 3),
#  ('средин', 3),
#  ('богомол', 3),
#  ('подл', 3),
#  ('ным', 3),
#  ('сапог', 3),
#  ('алатырьск', 3),
#  ('крамщик', 3),
#  ('верхн', 3),
#  ('немал', 3),
#  ('завод', 3),
#  ('воронеж', 3),
#  ('рогож', 3),
#  ('залесн', 3),
#  ('саньм', 3),
#  ('свин', 3),
#  ('рузск', 3),
#  ('золот', 3),
#  ('армян', 3),
#  ('каждогодн', 3),
#  ('трех', 3),
#  ('икр', 3),
#  ('уст', 3),
#  ('22', 3),
#  ('ростов', 3),
#  ('волокопинежск', 3),
#  ('водян', 3),
#  ('суздал', 3),
#  ('евстаф', 3),
#  ('канат', 3),
#  ('лучш', 3),
#  ('муромск', 3),
#  ('ярославц', 3),
#  ('кос', 3),
#  ('глав', 3),
#  ('вся', 3),
#  ('славн', 3),
#  ('зимов', 3),
#  ('куниц', 3),
#  ('китайк', 3),
#  ('привозн', 3),
#  ('деньг', 3),
#  ('дорог', 3),
#  ('рыбинск', 3),
#  ('цен', 3),
#  ('краснослободск', 3),
#  ('цвет', 3),
#  ('вином', 3),
#  ('кашин', 3),
#  ('кропивн', 3),
#  ('печен', 3),
#  ('област', 3),
#  ('ивановк', 3),
#  ('казан', 3),
#  ('мелочм', 3),
#  ('где', 3),
#  ('донковск', 3),
#  ('устюг', 3),
#  ('*', 3),
#  ('ве', 3),
#  ('1784', 3),
#  ('усекновен', 3),
#  ('единожд', 3),
#  ('торопецк', 3),
#  ('12', 3),
#  ('медочн', 3),
#  ('11', 3),
#  ('происход', 3),
#  ('учрежд', 3),
#  ('белк', 3),
#  ('сретен', 3),
#  ('имеет', 3),
#  ('наход', 3),
#  ('мех', 3),
#  ('отсюд', 3),
#  ('дамиа', 3),
#  ('них', 3),
#  ('нижн', 3),
#  ('столпник', 3),
#  ('отпуска', 3),
#  ('дмитровск', 3),
#  ('хмел', 3),
#  ('великомучениц', 3),
#  ('звенигородск', 3),
#  ('касимовск', 3),
#  ('разночинц', 3),
#  ('баран', 3),
#  ('девич', 3),
#  ('соседн', 3),
#  ('норск', 3),
#  ('господ', 3),
#  ('арсамазск', 3),
#  ('симеон', 3),
#  ('камк', 3),
#  ('юфт', 3),
#  ('коломн', 3),
#  ('кирил', 3),
#  ('алексеевск', 3),
#  ('р', 3),
#  ('товаров', 3),
#  ('сторон', 3),
#  ('полож', 3),
#  ('отвоз', 3),
#  ('девя', 3),
#  ('прокоп', 3),
#  ('петербургск', 3),
#  ('промышленник', 3),
#  ('хлопчат', 3),
#  ('седмиц', 3),
#  ('белицк', 3),
#  ('коломенск', 3),
#  ('назад', 3),
#  ('княз', 3),
#  ('ни', 3),
#  ('болхов', 3),
#  ('кинешм', 3),
#  ('ладон', 3),
#  ('ан', 3),
#  ('оловя', 3),
#  ('10', 3),
#  ('13', 3),
#  ('ближайш', 2),
#  ('холстом', 2),
#  ('опочек', 2),
#  ('симеоновск', 2),
#  ('туринск', 2),
#  ('оренбург', 2),
#  ('екатеринбург', 2),
#  ('сте', 2),
#  ('смежн', 2),
#  ('грезет', 2),
#  ('семик', 2),
#  ('ярополч', 2),
#  ('нагольн', 2),
#  ('сух', 2),
#  ('дубровк', 2),
#  ('построен', 2),
#  ('ям', 2),
#  ('курмышск', 2),
#  ('сетк', 2),
#  ('цар', 2),
#  ('миргород', 2),
#  ('ром', 2),
#  ('свиажск', 2),
#  ('домов', 2),
#  ('звер', 2),
#  ('ординарн', 2),
#  ('нич', 2),
#  ('брусков', 2),
#  ('борзн', 2),
#  ('епифан', 2),
#  ('рязан', 2),
#  ('колп', 2),
#  ('состоя', 2),
#  ('ливенск', 2),
#  ('лебедян', 2),
#  ('городн', 2),
#  ('гремяч', 2),
#  ('щепет', 2),
#  ('беркунов', 2),
#  ('прост', 2),
#  ('лошадин', 2),
#  ('краснопол', 2),
#  ('европейск', 2),
#  ('брянск', 2),
#  ('поташ', 2),
#  ('обод', 2),
#  ('ском', 2),
#  ('образ', 2),
#  ('алешн', 2),
#  ('рук', 2),
#  ('дал', 2),
#  ('платк', 2),
#  ('камен', 2),
#  ('екатеринбургск', 2),
#  ('намерен', 2),
#  ('чег', 2),
#  ('липецк', 2),
#  ('парск', 2),
#  ('оклад', 2),
#  ('град', 2),
#  ('языков', 2),
#  ('яблунев', 2),
#  ('нетокм', 2),
#  ('салом', 2),
#  ('шведск', 2),
#  ('стран', 2),
#  ('коф', 2),
#  ('чуж', 2),
#  ('уразов', 2),
#  ('россиа', 2),
#  ('замк', 2),
#  ('важн', 2),
#  ('мезенск', 2),
#  ('тот', 2),
#  ('впроч', 2),
#  ('напитк', 2),
#  ('михайловск', 2),
#  ('марш', 2),
#  ('белевск', 2),
#  ('произведен', 2),
#  ('веревк', 2),
#  ('ворва', 2),
#  ('юрьев', 2),
#  ('полушелков', 2),
#  ('довольн', 2),
#  ('пупк', 2),
#  ('волхов', 2),
#  ('достопамятн', 2),
#  ('лебедин', 2),
#  ('настоя', 2),
#  ('ярмарочн', 2),
#  ('васильевск', 2),
#  ('рамен', 2),
#  ('карачев', 2),
#  ('помещик', 2),
#  ('форпост', 2),
#  ('ямпол', 2),
#  ('гвозд', 2),
#  ('ежедневн', 2),
#  ('щепетин', 2),
#  ('сряд', 2),
#  ('ахтырк', 2),
#  ('веневск', 2),
#  ('арзамаск', 2),
#  ('кушак', 2),
#  ('кошеч', 2),
#  ('овц', 2),
#  ('исключ', 2),
#  ('кавказск', 2),
#  ('молодов', 2),
#  ('краск', 2),
#  ('десн', 2),
#  ('вял', 2),
#  ('рыльск', 2),
#  ('муриков', 2),
#  ('пятницам', 2),
#  ('миропол', 2),
#  ('ветк', 2),
#  ('новогородскаг', 2),
#  ('кубенск', 2),
#  ('переяславл', 2),
#  ('отъезжа', 2),
#  ('след', 2),
#  ('свеж', 2),
#  ('часовн', 2),
#  ('черлянков', 2),
#  ('варвар', 2),
#  ('производят', 2),
#  ('орл', 2),
#  ('богородск', 2),
#  ('вразсужден', 2),
#  ('лет', 2),
#  ('алексинск', 2),
#  ('аврам', 2),
#  ('границ', 2),
#  ('упадк', 2),
#  ('хрящ', 2),
#  ('уклад', 2),
#  ('отпуск', 2),
#  ('риг', 2),
#  ('стратилатовск', 2),
#  ('зубцов', 2),
#  ('николин', 2),
#  ('введен', 2),
#  ('козак', 2),
#  ('купеческ', 2),
#  ('дворянств', 2),
#  ('росссийск', 2),
#  ('карпов', 2),
#  ('штоф', 2),
#  ('пятничн', 2),
#  ('болееж', 2),
#  ('белокурин', 2),
#  ('пол', 2),
#  ('иван', 2),
#  ('бронниц', 2),
#  ('пятницк', 2),
#  ('спаск', 2),
#  ('крапивн', 2),
#  ('бы', 2),
#  ('вещм', 2),
#  ('слывет', 2),
#  ('шипин', 2),
#  ('косм', 2),
#  ('рог', 2),
#  ('тюртен', 2),
#  ('подобным', 2),
#  ('шапк', 2),
#  ('принадлежа', 2),
#  ('хован', 2),
#  ('аргамач', 2),
#  ('вытегр', 2),
#  ('сторожевск', 2),
#  ('мещан', 2),
#  ('мен', 2),
#  ('вычегодск', 2),
#  ('галантерейн', 2),
#  ('кле', 2),
#  ('островск', 2),
#  ('колюпановк', 2),
#  ('бык', 2),
#  ('руск', 2),
#  ('иноверц', 2),
#  ('игл', 2),
#  ('когд', 2),
#  ('самар', 2),
#  ('звенигород', 2),
#  ('оскол', 2),
#  ('хот', 2),
#  ('стан', 2),
#  ('оршанск', 2),
#  ('горшк', 2),
#  ('доск', 2),
#  ('вар', 2),
#  ('храмов', 2),
#  ('погромц', 2),
#  ('получа', 2),
#  ('савин', 2),
#  ('крестител', 2),
#  ('хрящев', 2),
#  ('починк', 2),
#  ('яр', 2),
#  ('петропавловск', 2),
#  ('деркул', 2),
#  ('л', 2),
#  ('подворгальск', 2),
#  ('свинск', 2),
#  ('вает', 2),
#  ('корабл', 2),
#  ('александровск', 2),
#  ('поселян', 2),
#  ('прилук', 2),
#  ('сельц', 2),
#  ('сызран', 2),
#  ('дров', 2),
#  ('ком', 2),
#  ('гороховецк', 2),
#  ('донков', 2),
#  ('калмыцк', 2),
#  ('прежн', 2),
#  ('различн', 2),
#  ('дегот', 2),
#  ('кумач', 2),
#  ('башкирц', 2),
#  ('черн', 2),
#  ('голландск', 2),
#  ('мясоед', 2),
#  ('темниковск', 2),
#  ('квасц', 2),
#  ('глеб', 2),
#  ('возвраща', 2),
#  ('первоверховн', 2),
#  ('ревел', 2),
#  ('санда', 2),
#  ('промысл', 2),
#  ('средн', 2),
#  ('произрастан', 2),
#  ('костром', 2),
#  ('конотоп', 2),
#  ('мглин', 2),
#  ('калмык', 2),
#  ('васил', 2),
#  ('куд', 2),
#  ('заморск', 2),
#  ('приморск', 2),
#  ('повсягодн', 2),
#  ('п', 2),
#  ('поводнев', 2),
#  ('ту', 2),
#  ('дерпт', 2),
#  ('короченск', 2),
#  ('конск', 2),
#  ('потребн', 2),
#  ('кадом', 2),
#  ('барышевк', 2),
#  ('живущ', 2),
#  ('ичн', 2),
#  ('сергиевск', 2),
#  ('кра', 2),
#  ('базар', 2),
#  ('тафт', 2),
#  ('воскресенск', 2),
#  ('михайл', 2),
#  ('белогородск', 2),
#  ('пятидесят', 2),
#  ('учрежден', 2),
#  ('иосиф', 2),
#  ('новгородск', 2),
#  ('бобр', 2),
#  ('уф', 2),
#  ('глинск', 2),
#  ('тюмен', 2),
#  ('лежнев', 2),
#  ('похвальн', 2),
#  ('енисейск', 2),
#  ('одиножд', 2),
#  ('домашн', 2),
#  ('малоросс', 2),
#  ('вышгород', 2),
#  ('екатерин', 2),
#  ('привозят', 2),
#  ('городищ', 2),
#  ('1783', 2),
#  ('вь', 2),
#  ('чухлом', 2),
#  ('речк', 2),
#  ('тотемск', 2),
#  ('киренск', 2),
#  ('севск', 2),
#  ('дел', 2),
#  ('марк', 2),
#  ('рост', 2),
#  ('лужк', 2),
#  ('ефремов', 2),
#  ('крашен', 2),
#  ('нын', 2),
#  ('козловк', 1),
#  ('отдален', 1),
#  ('жиганск', 1),
#  ('вере', 1),
#  ('почт', 1),
#  ('уез', 1),
#  ('маккав', 1),
#  ('способн', 1),
#  ('кемар', 1),
#  ('приеэжа', 1),
#  ('шартольск', 1),
#  ('рожественск', 1),
#  ('стешк', 1),
#  ('меньшиков', 1),
#  ('евстафиевск', 1),
#  ('зел', 1),
#  ('сапожк', 1),
#  ('палатк', 1),
#  ('барж', 1),
#  ('одинцов', 1),
#  ('царевосанчурск', 1),
#  ('мелочны', 1),
#  ('кунц', 1),
#  ...]

# %%
top50 = [p[0] for p in nltk.FreqDist(stopped_text).most_common()][:50]

# %%
top50
# Out:
# ['товар',
#  'купц',
#  'торг',
#  'разн',
#  'мелочн',
#  'приезжа',
#  'июл',
#  'шелков',
#  'хлеб',
#  'июн',
#  'сентябр',
#  'вин',
#  'крестьян',
#  'припас',
#  'скот',
#  'съестн',
#  'бумажн',
#  'ма',
#  'российск',
#  'октябр',
#  'генвар',
#  'пасх',
#  'холст',
#  'горяч',
#  'посуд',
#  'деревя',
#  'продолжа',
#  'тог',
#  'богородиц',
#  'част',
#  'кож',
#  '15',
#  'дни',
#  'крестьянск',
#  'сег',
#  'харьковск',
#  'от',
#  'торжк',
#  'ближн',
#  'екатеринославск',
#  'близ',
#  'уездн',
#  'велик',
#  'прочим',
#  'мед',
#  'пеньк',
#  'ил',
#  'прода',
#  'рыб',
#  'лежа']

# %%
[reverse_stem[w][0] for w in top50]
# Out:
# ['товар',
#  'купцов',
#  'торгах',
#  'разные',
#  'мелочной',
#  'приезжающие',
#  'Июля',
#  'шелковых',
#  'хлебъ',
#  'Июня',
#  'Сентябре',
#  'вином',
#  'крестьяне',
#  'припасами',
#  'скотом',
#  'съестным',
#  'бумажных',
#  'Маие',
#  'Российской',
#  'Октябре',
#  'Генваря',
#  'Пасхи',
#  'холстом',
#  'горячее',
#  'посудою',
#  'деревянная',
#  'продолжав',
#  'того',
#  'Богородице',
#  'часть',
#  'кожи',
#  '15',
#  'Дни',
#  'крестьянской',
#  'сего',
#  'Харьковского',
#  'от',
#  'торжки',
#  'ближних',
#  'Екатеринославском',
#  'близъ',
#  'уездных',
#  'великое',
#  'прочимъ',
#  'медом',
#  'пенька',
#  'или',
#  'проданные',
#  'рыбы',
#  'лежащем']

# %%
reverse_stem["купц"]
# Out:
# ['купцов', 'купцы', 'купцам', 'Купцы', 'купцами']

# %%
ortho_rules("Холмогорскіе",lookup_dict)
# Out:
# 'Холмогорские'

# %%
text.concordance("купцы",lines=50)
# Out:
# Displaying 50 of 331 matches:
#  есть Июля 30 , на которую приезжают купцы и крестьяне с мелочными товарами . А
# рмарка , на коей торгуют Вологодские купцы мелочными товарами . АВРАМИЕВ , мона
# в , в одинадцатую пятницу по Пасхе ; купцы сюда приезжают из ближних городов с
# стратига Михаила . На оные приезжают купцы из разных Российских городов с шелко
# ля покупки сего приезжают Российские купцы , и привозят с собою всякие мелочные
# т на оную из разных городов и уездов купцы , шелк , бумагу красную и писную , к
#  которую привозят изЬ разных городов купцы мелочные и прочие товары ; торг прод
# варами из Москвы и из других городов купцы , такожь и крестьяне . САСОВО , село
# Иоанна Богослова ; приеэжают на оные купцы из разных Российских городов с шелко
# вгуста 30 . Сюда для торгу приезжают купцы из разных Российских городов с шелко
# еславля Залеского , Углича приезжают купцы с мелочными всякими небогатыми товар
# я главы Предтечи ; приезжают на оные купцы из разных Российских городов с шелко
#  которые съезжаются из окольных мест купцы с красныни и другими мелочными товар
# : первая в Июне , вторая в Октябре ; купцы приезжают на оные из Пскова с разным
# оября 21 , шестая на Сырной неделе . Купцы приезжают на оные из окрестных город
# аются из Новагорода и из Старой Рузы купцы с разными шелковым мелочными товарам
# е , Малороссийские жители ; а Руские купцы из разных городов привозит всякие ме
# езжают и из Великороссийских городов купцы с красными товарами . Здесь бывают и
# у после Пасхи , на которую приезжают купцы из ближних городов с мелочным товаро
# есвятые Богородицы ; товары привозят купцы из Новагорода и из Торопца всякие мо
# я ярмарка в Июне месяце ; съезжаются купцы с разными товарами из ближних городо
# ывает в году ярмарка в Июне месяце ; купцы приезжают из близ лежащих городов с
# орая Сентября 6 , третия Декабря 4 . Купцы на оные приезжают из ближайших город
# рмарка в году , на которую приезжают купцы из ближних городовъ СТАРИНСКОЕ , сел
# атные ярмарки , на которые приезжают купцы и из Малороссии . СТАРОЙ ОСКОЛ , с 1
# ень успения , по два дни ; приезжают купцы с разными товарами из близ лежащих г
# варами из Москвы и из других городов купцы , такожь и крестьяне . СТЕШКИ , село
# ень Пророка Илии ; на оную приезжают купцы из близ лежащих городов с разными ме
# еславля Залеского , Углича приезжают купцы с мелочными всякими небогатыми товар
# еделе по два дни ; приезжают на оные купцы из соседственных городов ; привозят
#  7 ) в Лежневе на семик ; съезжаются купцы из Москвы , Ярославля , Суздаля , Шу
#  оном бывает в году четыре ярмарки ; купцы приезжают из окрестных городов с мел
# съезжаются разных городов Российские купцы и Греки ; привозят хорошия сукна , ш
# рки , на которых торгуют Вологодские купцы разными мелочными товарами . ТАМБОВ
# олжающаяся до 7 дня того же месяца . Купцы приезжают на оные из ближних городов
# ол Петра и Павла ; приезжают на оную купцы с мелкими товарами и съестными из бл
# году ярмарка , на которую съевжаются купцы из ближних городов с шелковыми , бум
#  одна ярмарка , на которую приезжают купцы из разных городов по большей части с
# ксея Митрополита ; на оную приезжают купцы из окрестных ближних городов с мелоч
# ной торгуют Елецкие и дру их городов купцы с уездными обывателями разными мелоч
# ются более Курские и Старооскольские купцы с сукнами и шелковыми материями . ТИ
# а Июня 18 дня , на которую съежаются купцы из Калуги и Малого Ярославца . ТИХОН
# ый город Наместничества сего имени . Купцы Российские , в Сибири и на Китайскую
# енью Сибирским и Китайским товарам . Купцы приезд еще имеют с товарами из Ирбит
#  и продолжаются оные по одному дню . Купцы приезжают из окрестных городов с мел
# 31 , Февраля 1 , Декабря 6 и 7 чисел купцы со всякими мелочными шелковыми и бум
# ых в оной у соседних поселян здешние купцы покупают масло коровье , сало , кожи
# е из разных Великороссийских городов купцы разными шелковыми , меховыми и мелоч
# пения Богородицы . На оные приезжают купцы из Тамбова и Зарайска с шелковыми и
#  23 Октября по 1 . На оные приезжают купцы из разных Российских городов с товар

# %%
trade_areas = list(set(re.findall(r"([А-Яа-я]+ские)",fulltext)))
trade_areas.sort()

# %%
re.findall(r"((?:[А-Яа-я]+[цс]кие\s*,\s*)*(?:[А-Яа-я]+[цс]кие)*(?:\s*и\s*)?(?:[А-Яа-я]+[цс]кие)) купцы",fulltext)\
# Out:
# ['Вологодские',
#  'Российские',
#  'Руские',
#  'Российские',
#  'Вологодские',
#  'Курские и Старооскольские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Московские, Устюжские и Тотемские',
#  'Российские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Российские',
#  'Тобольские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Архангельские и Холмогорские',
#  'Торопецкие',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Российские',
#  'Российские',
#  'Московские, Ярославские , Костромские , Любимские, Романовские и Вологодские',
#  'Великороссийские и Малороссийские',
#  'Великолуцкие, Торопецкие и Псковские',
#  'устюжские',
#  'Российские',
#  'Вологодские',
#  'Вологодские',
#  'Курские, Севские и Рыльские',
#  ' и Великороссийские',
#  'Муромские',
#  'Великороссийские и Малороссийские',
#  ' и Великороссийские',
#  'Азиатские',
#  ' и Великороссийские',
#  'Зарайские',
#  'Московские',
#  'Елецкие',
#  ' и Великороссийские']

# %%
re.findall(r"[А-Яа-я]+ские\s*,\s*",fulltext)
# Out:
# ['крестьянские, ',
#  'Российские, ',
#  'Вологодские, ',
#  'Московские, ',
#  'Российские, ',
#  'Китайские, ',
#  'Персидские, ',
#  'Кадомонские , ',
#  'Московские, ',
#  'Ярославские , ',
#  'Костромские , ',
#  'Любимские, ',
#  'Российские, ',
#  'Курские, ',
#  'Вологодские, ',
#  'Великороссийские , ',
#  'Великороссийские , ']

# %%
text.concordance("Алексина")
# Out:
# Displaying 5 of 5 matches:
# ыми из ближних городов Серпухова и Алексина , а уездные люди с крестьянскими п
# кого Наместничества в уезде города Алексина . В оном бывают яр марки Июля 8 ,
# кого Наместничества в 7 верстах от Алексина . Здесь бывает ярмарка Июля 8 числ
# ла , на которую приезжают купцы из Алексина с мелкими для крестьян товарами .
# кого Наместничества в уезде города Алексина . Здесь бывает ярмарка Маия 2 и Ию

# %%
re.findall(r"купцы из\s+(?:[а-яА-Я]+\s+)*городов\s+[а-яА-Я]+",fulltext)
# Out:
# ['купцы из разных Российских городов с',
#  'купцы из разных Российских городов с',
#  'купцы из разных Российских городов с',
#  'купцы из разных Российских городов с',
#  'купцы из разных городов привозит',
#  'купцы из ближних городов с',
#  'купцы из близ лежащих городов с',
#  'купцы из ближних городов с',
#  'купцы из разных городов по',
#  'купцы из окрестных ближних городов с',
#  'купцы из разных Российских городов с',
#  'купцы из разных Российских городов с',
#  'купцы из разных Российских городов с',
#  'купцы из ближних городов с',
#  'купцы из близ лежащих городов с',
#  'купцы из разных городов с',
#  'купцы из разных Российских городов с',
#  'купцы из близ лежащих городов с',
#  'купцы из окрестных городов с',
#  'купцы из городов Вереи',
#  'купцы из ближних городов с',
#  'купцы из окрестных городов с',
#  'купцы из разных городов с',
#  'купцы из близ лежащих городов с',
#  'купцы из некоторых окрестных городов \r\n\r\n \r\n\r\n\r\n\r\nс',
#  'купцы из разных городов с',
#  'купцы из разных Российских городов с',
#  'купцы из близ лежащих городов с',
#  'купцы из окрестных городов с',
#  'купцы из Российских и Малороссийских городов с',
#  'купцы из разных городов с',
#  'купцы из ближних городов торгуют',
#  'купцы из Великороссийских и Малороссийских городов с',
#  'купцы из окрестных ближних городов с',
#  'купцы из близ лежащих городов с',
#  'купцы из разных городов с',
#  'купцы из соседственных городов с',
#  'купцы из соседних городов торгуют',
#  'купцы из окрестных городов с']

# %%
test = re.findall(r"купцы (из\s+(?:[а-яА-Я,]+\s+)*?)с ",fulltext)

# %%
test = [t.strip() for t in test]

# %%
test = [t for t in test if len(re.findall(r"городов|части$",t))==0]

# %%
test
# Out:
# ['из Тамбова и Зарайска',
#  'из Воронежа, Ельца и Липецка',
#  'из Ярославля , Юрьева и из Переславля Залеского',
#  'из Алексина',
#  'из Боровска, Вереи и Серпухова',
#  'из прикосновенных горед в , Ярославля , Романова , Углича и Вологды']

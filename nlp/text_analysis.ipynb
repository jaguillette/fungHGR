# %%
from lxml import html
import os, json, re, nltk
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
mpl.rc('font', family='Constantia')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test', 'f', 'text']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
mypath = "../html/"
onlyfiles = [ "../html/{}".format(f) for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath,f)) ]

# %%
fulltext = ""
for f in onlyfiles:
    tree = html.parse(f)
    root = tree.getroot()
    text = root.text_content()
    fulltext += " " + text

# %%
fulltext = fulltext.replace("\xa0"," ")

# %%
fulltext = re.sub(r"([> ])ВЪ",r"\1Въ",fulltext)
fulltext = re.sub(r"([а-яіѣѳ]+)(Ѣ)",r"\1ѣ",fulltext)
fulltext = re.sub(r"(Ѣ)([а-яіѣѳ]+)",r"ѣ\2",fulltext)
fulltext = re.sub(r"([а-яіѣѳ]+)(Ъ)",r"\1ъ",fulltext)

# %%
import re,json
from lxml import html

with open("../resources/special_cases.json",'r',encoding='utf-8') as fp:
    lookup_dict = json.load(fp)

def ortho_rules(text,lookup_dict):
    """
    Takes a text string and a lookup dict as input
    Removes any lingering html tags
    Breaks the string down into component words with split
    Uses replacements to modernize orthography
    Returns re-assembled text with modern orthography
    """
    if type(text)==str:
        text = html.fromstring(text).text_content()
        textlist = text.split(' ')
        out_list = []
        for word in textlist:
            if word in [',','.',';',':']:
                out_list.append(word)
                continue
            punct = ""
            if len(re.findall(r"([,.;:])$",word))!=0:
                   punct = re.findall(r"([,.;:])$",word)[0]
            word = word.strip(',.;:')
            if word in lookup_dict:
                word = lookup_dict[word]
                out_list.append(word)
            else:
                word = re.sub("[Ъъ]$",'',word)
                word = re.sub(r"^([че]{0,2}[ч]?[вбнр]?[веоаи])з([ПФКТШСЧпфктшсч])",r"\1с\2",word,re.IGNORECASE)
                word = re.sub("аго$","ого",word,re.IGNORECASE)
                word = re.sub("яго$","его",word,re.IGNORECASE)
                word = re.sub("ыя$","ые",word,re.IGNORECASE)
                word = re.sub("iя$","ие",word,re.IGNORECASE)
                word = word.replace('i','и') #english
                word = word.replace('I','И') #english
                word = word.replace('і','и') #cyrillic
                word = word.replace('І','И') #cyrillic
                word = word.replace('Ѣ','Е')
                word = word.replace('ѣ','е')
                word = word.replace('Ѳ','Ф')
                word = word.replace('ѳ','ф')
                word += punct
                out_list.append(word)
        out_str = ' '.join(out_list)
        return out_str
    else:
        return None

# %%
fulltext = ortho_rules(fulltext,lookup_dict)

# %% [markdown]
# Fulltext is now ready to be parsed
# ==================================

# %%
tokens = nltk.tokenize.wordpunct_tokenize(fulltext)

# %%
ru_stemmer = nltk.SnowballStemmer('russian')

# %%
reverse_stem = {}
for w in set(tokens):
    if ru_stemmer.stem(w) not in reverse_stem:
        reverse_stem[ru_stemmer.stem(w)] = []
    reverse_stem[ru_stemmer.stem(w)].append(w)

# %%
tok_stems = [ru_stemmer.stem(w) for w in tokens]

# %%
text = nltk.text.Text(tokens)
stem_text = nltk.text.Text(tok_stems)

# %%
freq = nltk.FreqDist(text)

# %%
freq.plot(25,cumulative=True)

# %%
freq.most_common()
# Out:
# [(',', 3405),
#  ('.', 1802),
#  ('в', 1546),
#  ('и', 1155),
#  ('Наместничества', 714),
#  ('бывает', 597),
#  (';', 478),
#  ('на', 462),
#  ('В', 440),
#  ('году', 420),
#  ('с', 418),
#  ('уезде', 384),
#  ('из', 376),
#  ('ярмарки', 360),
#  ('ярмарка', 353),
#  ('товарами', 351),
#  ('Здесь', 315),
#  ('день', 299),
#  ('купцы', 292),
#  ('город', 286),
#  ('приезжают', 231),
#  ('бывают', 230),
#  ('оном', 230),
#  ('по', 222),
#  (':', 220),
#  ('городов', 207),
#  ('торгуют', 207),
#  ('село', 192),
#  ('первая', 184),
#  ('мелочными', 179),
#  ('разными', 167),
#  ('вторая', 167),
#  ('а', 149),
#  ('местечко', 144),
#  ('города', 129),
#  ('три', 121),
#  ('две', 121),
#  ('Июля', 121),
#  ('дня', 116),
#  ('третия', 113),
#  ('товары', 111),
#  ('одна', 109),
#  ('годовая', 105),
#  ('привозят', 101),
#  ('нем', 99),
#  ('оные', 97),
#  ('Сентября', 96),
#  ('8', 96),
#  ('разных', 92),
#  ('Июня', 89),
#  ('шелковыми', 85),
#  ('1', 84),
#  ('-', 82),
#  ('также', 77),
#  ('прочими', 76),
#  ('крестьяне', 76),
#  ('Августа', 74),
#  ('для', 73),
#  ('оной', 71),
#  ('слобода', 70),
#  ('неделе', 70),
#  ('уезду', 69),
#  ('хлебом', 68),
#  ('же', 66),
#  ('четыре', 66),
#  ('сем', 66),
#  ('вином', 65),
#  ('6', 63),
#  ('пятницу', 62),
#  ('Маия', 59),
#  ('четвертая', 58),
#  ('то', 57),
#  ('год', 57),
#  ('оных', 55),
#  ('скотом', 53),
#  ('9', 53),
#  ('Генваря', 52),
#  ('Октября', 51),
#  ('бумажными', 51),
#  ('которую', 50),
#  ('29', 50),
#  ('Киевского', 49),
#  ('жители', 49),
#  ('оную', 49),
#  ('Губернии', 48),
#  ('Декабря', 47),
#  ('Ноября', 47),
#  ('десятую', 46),
#  ('торг', 46),
#  ('припасами', 46),
#  ('Пасхе', 44),
#  ('мелочные', 44),
#  ('Московской', 44),
#  ('того', 44),
#  ('Богородицы', 44),
#  ('которые', 43),
#  ('съезжаются', 43),
#  ('15', 43),
#  ('На', 43),
#  ('Харьковского', 42),
#  ('от', 42),
#  ('хлеб', 41),
#  ('городе', 41),
#  ('сего', 40),
#  ('Купцы', 39),
#  ('неделю', 39),
#  ('другая', 39),
#  ('ближних', 39),
#  ('прочие', 39),
#  ('съестными', 38),
#  ('здесь', 38),
#  ('дни', 38),
#  ('прочимъ', 38),
#  ('близ', 37),
#  ('шелковые', 37),
#  ('разным', 36),
#  ('разные', 36),
#  ('Могилевского', 36),
#  ('Екатеринославского', 36),
#  ('лежащих', 36),
#  ('числа', 36),
#  ('как', 35),
#  ('съестные', 35),
#  ('Черниговского', 35),
#  ('селе', 34),
#  ('Тульского', 34),
#  ('торжки', 34),
#  ('20', 34),
#  ('горячим', 34),
#  ('продают', 34),
#  ('других', 33),
#  ('23', 33),
#  ('монастырь', 32),
#  ('24', 32),
#  ('лошадей', 32),
#  ('месяце', 31),
#  ('Тамбовского', 31),
#  ('Рижского', 31),
#  ('посудою', 30),
#  ('припасы', 30),
#  ('Российских', 30),
#  ('не', 30),
#  ('кожами', 30),
#  ('кроме', 30),
#  ('два', 29),
#  ('большей', 29),
#  ('которой', 29),
#  ('Полотского', 29),
#  ('части', 29),
#  ('25', 28),
#  ('прочее', 28),
#  ('14', 27),
#  ('да', 27),
#  ('Ярославского', 27),
#  ('Новогородского', 27),
#  ('торгу', 27),
#  ('после', 27),
#  (')', 27),
#  ('приезжие', 27),
#  ('лошадьми', 26),
#  ('сверх', 26),
#  ('Тверского', 26),
#  ('всякими', 25),
#  ('товаромъ', 25),
#  ('продолжается', 25),
#  ('оного', 25),
#  ('рыбою', 25),
#  ('мелочным', 25),
#  ('десятой', 25),
#  ('Вологодского', 25),
#  ('окрестных', 24),
#  ('26', 24),
#  ('поста', 24),
#  ('уездов', 24),
#  ('о', 24),
#  ('еженедельные', 24),
#  ('пивомъ', 24),
#  ('но', 24),
#  ('торги', 23),
#  ('месте', 23),
#  ('обыватели', 23),
#  ('мест', 23),
#  ('2', 23),
#  ('Ярославля', 23),
#  ('Дворца', 22),
#  ('товаром', 22),
#  ('число', 22),
#  ('Святого', 22),
#  ('21', 22),
#  ('или', 22),
#  ('деревянною', 22),
#  ('Господня', 21),
#  ('главный', 21),
#  ('овчинами', 21),
#  ('имени', 21),
#  ('холст', 21),
#  ('во', 21),
#  ('какъ', 20),
#  ('крестьянскими', 20),
#  ('проч', 20),
#  ('масло', 20),
#  ('Духа', 20),
#  ('всякие', 20),
#  ('один', 20),
#  ('Апреля', 20),
#  ('торгов', 20),
#  ('со', 20),
#  ('другими', 20),
#  ('воск', 20),
#  ('Пензенского', 20),
#  ('Июне', 20),
#  ('годовые', 19),
#  ('мед', 19),
#  ('скот', 19),
#  ('Николая', 19),
#  ('великого', 19),
#  ('недели', 19),
#  ('время', 19),
#  ('Сошествия', 19),
#  ('медом', 19),
#  ('Великороссийские', 18),
#  ('Великомученика', 18),
#  ('Курского', 18),
#  ('Костромского', 18),
#  ('еженедельных', 18),
#  ('сукна', 18),
#  ('около', 18),
#  ('продажи', 18),
#  ('обывателей', 18),
#  ('Рязанского', 18),
#  ('Марта', 18),
#  ('Калужского', 18),
#  ('При', 17),
#  ('Петра', 17),
#  ('съезд', 17),
#  ('Российские', 17),
#  ('при', 17),
#  ('всякой', 17),
#  ('Рождества', 17),
#  ('Углича', 17),
#  ('там', 17),
#  ('сюда', 17),
#  ('окольные', 17),
#  ('продажу', 17),
#  ('Орловского', 17),
#  ('1780', 17),
#  ('Псковского', 17),
#  ('чисел', 17),
#  ('только', 16),
#  ('уездных', 16),
#  ('Северского', 16),
#  ('Св', 16),
#  ('Чудотворца', 16),
#  ('своими', 16),
#  ('ярмарок', 16),
#  ('Июле', 16),
#  ('Павла', 16),
#  ('тожь', 16),
#  ('называемая', 16),
#  ('Илии', 16),
#  ('Вознесения', 16),
#  ('Тулы', 16),
#  ('красным', 15),
#  ('дегтем', 15),
#  ('родящимися', 15),
#  ('Пресвятые', 15),
#  ('шерстяными', 15),
#  ('мелкими', 15),
#  ('у', 15),
#  ('Пророка', 15),
#  ('ярмарку', 15),
#  ('дней', 15),
#  ('крестьянство', 15),
#  ('окольных', 14),
#  ('красными', 14),
#  ('Бывает', 14),
#  ('есть', 14),
#  ('Серпухова', 14),
#  ('Сюда', 14),
#  ('купечество', 14),
#  ('соль', 14),
#  ('лавочными', 14),
#  ('которых', 14),
#  ('девятую', 14),
#  ('что', 14),
#  ('москотильные', 14),
#  ('С', 14),
#  ('уездные', 14),
#  ('рогатой', 14),
#  ('погост', 14),
#  ('понедельник', 14),
#  ('пенька', 14),
#  ('Синбирского', 14),
#  ('верстах', 14),
#  ('числу', 13),
#  ('Москвы', 13),
#  ('пенькою', 13),
#  ('Покрова', 13),
#  ('продаже', 13),
#  ('материи', 13),
#  ('более', 13),
#  ('за', 13),
#  ('смолу', 13),
#  ('кожи', 13),
#  ('Нижегородского', 13),
#  ('одному', 13),
#  ('селах', 13),
#  ('Иоанна', 13),
#  ('Зарайска', 13),
#  ('пяток', 13),
#  ('частию', 13),
#  ('пять', 13),
#  ('Воронежского', 13),
#  ('Каширы', 12),
#  ('съезды', 12),
#  ('Изюма', 12),
#  ('Преображения', 12),
#  ('прочия', 12),
#  ('Февраля', 12),
#  ('пятнице', 12),
#  ('Преполовения', 12),
#  ('продолжающаяся', 12),
#  ('слободы', 12),
#  ('Российскими', 12),
#  ('Миргородском', 12),
#  ('коих', 12),
#  ('пивом', 12),
#  ('прочим', 12),
#  ('еженедельного', 12),
#  ('малому', 12),
#  ('Пасхи', 12),
#  ('каждой', 12),
#  ('изделье', 12),
#  ('Лубенском', 12),
#  ('Каширском', 12),
#  ('1779', 12),
#  ('Динабурга', 12),
#  ('каждую', 12),
#  ('понедельникам', 12),
#  ('успения', 11),
#  ('москотильными', 11),
#  ('рогатым', 11),
#  ('сукнами', 11),
#  ('вино', 11),
#  ('иногда', 11),
#  ('пятая', 11),
#  ('Переславля', 11),
#  ('Владимерского', 11),
#  ('такожь', 11),
#  ('до', 11),
#  ('которая', 11),
#  ('товаров', 11),
#  ('пеньку', 11),
#  ('б', 11),
#  ('к', 11),
#  ('большею', 11),
#  ('издельями', 11),
#  ('1778', 11),
#  ('горячее', 11),
#  ('Апостолов', 11),
#  ('пятницам', 11),
#  ('дню', 11),
#  ('Волоколамском', 11),
#  ('Георгия', 11),
#  ('праздник', 11),
#  ('купцов', 11),
#  ('Сентябре', 10),
#  ('тому', 10),
#  ('Торгуют', 10),
#  ('7', 10),
#  ('Наместничестве', 10),
#  ('съезжается', 10),
#  ('бумажные', 10),
#  ('холсты', 10),
#  ('покупают', 10),
#  ('Иркутского', 10),
#  ('салом', 10),
#  ('Крымскую', 10),
#  ('16', 10),
#  ('рыбу', 10),
#  ('другие', 10),
#  ('иностранные', 10),
#  ('крестьян', 10),
#  ('числах', 10),
#  ('Динабургском', 10),
#  ('Венева', 10),
#  ('делающимися', 10),
#  ('Воскресенье', 10),
#  ('месяца', 10),
#  ('пустыня', 10),
#  ('солью', 9),
#  ('Сырной', 9),
#  ('Залеского', 9),
#  ('Володимерского', 9),
#  ('посуду', 9),
#  ('несколько', 9),
#  ('5', 9),
#  ('каждонедельно', 9),
#  ('месяцах', 9),
#  ('множество', 9),
#  ('Великороссийских', 9),
#  ('гарусными', 9),
#  ('холстом', 9),
#  ('1782', 9),
#  ('Богоявления', 9),
#  ('привозятся', 9),
#  ('Донских', 9),
#  ('деревянное', 9),
#  ('28', 8),
#  ('Приезжают', 8),
#  ('монастыре', 8),
#  ('произрастениями', 8),
#  ('железом', 8),
#  ('Казанского', 8),
#  ('своей', 8),
#  ('пряжу', 8),
#  ('так', 8),
#  ('17', 8),
#  ('Романова', 8),
#  ('Пермского', 8),
#  ('жителям', 8),
#  ('колесами', 8),
#  ('сел', 8),
#  ('льняные', 8),
#  ('первой', 8),
#  ('шесть', 8),
#  ('ярмарокъ', 8),
#  ('мелкою', 8),
#  ('хлебомъ', 8),
#  ('торговые', 8),
#  ('еще', 8),
#  ('Малороссийских', 8),
#  ('деревня', 8),
#  ('обыкновенных', 8),
#  ('Калуги', 8),
#  ('ярмарках', 8),
#  ('чрез', 8),
#  ('субботу', 8),
#  ('шанец', 8),
#  ('прочих', 7),
#  ('крестьянства', 7),
#  ('18', 7),
#  ('рухлядь', 7),
#  ('монастыря', 7),
#  ('Михаила', 7),
#  ('свои', 7),
#  ('Дня', 7),
#  ('купцам', 7),
#  ('Переяславском', 7),
#  ('торговли', 7),
#  ('начинается', 7),
#  ('скотину', 7),
#  ('торговых', 7),
#  ('особливо', 7),
#  ('4', 7),
#  ('недельные', 7),
#  ('воскресеньям', 7),
#  ('числе', 7),
#  ('люди', 7),
#  ('именно', 7),
#  ('сей', 7),
#  ('обывателями', 7),
#  ('скупают', 7),
#  ('30', 7),
#  ('парчи', 7),
#  ('пятницы', 7),
#  ('Иногда', 7),
#  ('соседственных', 7),
#  ('собираются', 7),
#  ('станиц', 7),
#  ('Маие', 7),
#  ('деревень', 7),
#  ('Саратовского', 7),
#  ('крамными', 7),
#  ('покупки', 7),
#  ('1781', 7),
#  ('Рогачева', 7),
#  ('раза', 7),
#  ('рукоделия', 7),
#  ('Полтавском', 7),
#  ('вещи', 7),
#  ('стеклянною', 7),
#  ('праздника', 7),
#  ('Пскова', 7),
#  ('сало', 7),
#  ('коей', 7),
#  ('прочею', 6),
#  ('продолжающияся', 6),
#  ('Суздальском', 6),
#  ('19', 6),
#  ('кои', 6),
#  ('Шатском', 6),
#  ('Троицы', 6),
#  ('Смоленского', 6),
#  ('уездными', 6),
#  ('крепость', 6),
#  ('небогатыми', 6),
#  ('Предтечи', 6),
#  ('привозимыми', 6),
#  ('Елецкие', 6),
#  ('1777', 6),
#  ('приезжает', 6),
#  ('Светлого', 6),
#  ('Борисоглебска', 6),
#  ('еженедельной', 6),
#  ('Августе', 6),
#  ('Христова', 6),
#  ('братьи', 6),
#  ('овчины', 6),
#  ('волость', 6),
#  ('парусную', 6),
#  ('близости', 6),
#  ('продолжаются', 6),
#  ('Параскевы', 6),
#  ('Пошехонском', 6),
#  ('великая', 6),
#  ('их', 6),
#  ('Кашинском', 6),
#  ('деревянную', 6),
#  ('Успения', 6),
#  ('мелочью', 6),
#  ('Казанския', 6),
#  ('еженедельно', 6),
#  ('Прилуцком', 6),
#  ('Бежецком', 6),
#  ('Уфимского', 6),
#  ('мягкую', 6),
#  ('Вологодские', 6),
#  ('слободе', 6),
#  ('Выборгского', 6),
#  ('городка', 6),
#  ('Архистратига', 6),
#  ('годовой', 6),
#  ('вещами', 6),
#  ('места', 6),
#  ('Троицын', 6),
#  ('одинадцатой', 6),
#  ('торговля', 6),
#  ('Димитрия', 6),
#  ('всеедной', 6),
#  ('Провинции', 6),
#  ('середам', 6),
#  ('купцами', 6),
#  ('они', 6),
#  ('Сибири', 6),
#  ('Малороссийские', 5),
#  ('котором', 5),
#  ('церкви', 5),
#  ('железные', 5),
#  ('москотильной', 5),
#  ('первую', 5),
#  ('четверток', 5),
#  ('Боровска', 5),
#  ('Валуек', 5),
#  ('Воздвижения', 5),
#  ('вина', 5),
#  ('шелковых', 5),
#  ('Святые', 5),
#  ('всех', 5),
#  ('лен', 5),
#  ('позументы', 5),
#  ('Белева', 5),
#  ('льняной', 5),
#  ('сырейные', 5),
#  ('честного', 5),
#  ('Октябре', 5),
#  ('сих', 5),
#  ('Стародубовском', 5),
#  ('между', 5),
#  ('рухлядью', 5),
#  ('Челябинском', 5),
#  ('среду', 5),
#  ('лавочным', 5),
#  ('токмо', 5),
#  ('дням', 5),
#  ('НИКОЛАЕВСКОЙ', 5),
#  ('коровье', 5),
#  ('Святителя', 5),
#  ('весною', 5),
#  ('собою', 5),
#  ('зимнее', 5),
#  ('2о', 5),
#  ('месяцахъ', 5),
#  ('27', 5),
#  ('днем', 5),
#  ('ежегодно', 5),
#  ('пригород', 5),
#  ('посконной', 5),
#  ('второй', 5),
#  ('бумажных', 5),
#  ('Богослова', 5),
#  ('полотном', 5),
#  ('последних', 5),
#  ('Саранском', 5),
#  ('пригоняют', 5),
#  ('Елецком', 5),
#  ('Воскресения', 5),
#  ('уточную', 5),
#  ('сеном', 5),
#  ('3', 5),
#  ('иностранными', 5),
#  ('вторникам', 5),
#  ('холстами', 5),
#  ('Тобольского', 5),
#  ('Богоматери', 5),
#  ('набойчатыми', 5),
#  ('шестая', 5),
#  ('Гадяцком', 5),
#  ('том', 5),
#  ('Господ', 4),
#  ('Рыбного', 4),
#  ('Белицком', 4),
#  ('крестьянам', 4),
#  ('холстов', 4),
#  ('привозимые', 4),
#  ('Покровская', 4),
#  ('жителями', 4),
#  ('говяжьими', 4),
#  ('Изюмском', 4),
#  ('бываетъ', 4),
#  ('субботам', 4),
#  ('ней', 4),
#  ('поселян', 4),
#  ('Калмыки', 4),
#  ('торговъ', 4),
#  ('мягкою', 4),
#  ('ИВАНОВСКОЕ', 4),
#  ('мелочных', 4),
#  ('отправляются', 4),
#  ('Святых', 4),
#  ('Феврале', 4),
#  ('Петрова', 4),
#  ('субботние', 4),
#  ('шерстью', 4),
#  ('Алексина', 4),
#  ('мелочьми', 4),
#  ('Климовицком', 4),
#  ('Екатеринославском', 4),
#  ('пред', 4),
#  ('рукоделье', 4),
#  ('сию', 4),
#  ('Нежина', 4),
#  ('трех', 4),
#  ('рукоделья', 4),
#  ('все', 4),
#  ('знатные', 4),
#  ('Воскресеньям', 4),
#  ('под', 4),
#  ('торговой', 4),
#  ('Тройцын', 4),
#  ('двух', 4),
#  ('конопляное', 4),
#  ('глиняною', 4),
#  ('тое', 4),
#  ('Вологды', 4),
#  ('Вереи', 4),
#  ('Рогачевском', 4),
#  ('хлебъ', 4),
#  ('Мещовска', 4),
#  ('Яренска', 4),
#  ('Бывают', 4),
#  ('паче', 4),
#  ('Святой', 4),
#  ('торжков', 4),
#  ('воском', 4),
#  ('Великого', 4),
#  ('четырех', 4),
#  ('Можайском', 4),
#  ('привозимою', 4),
#  ('крестьянския', 4),
#  ('произрастения', 4),
#  ('Греки', 4),
#  ('Острова', 4),
#  ('материями', 4),
#  ('вощину', 4),
#  ('Козельском', 4),
#  ('раз', 4),
#  ('ПОКРОВСКОЕ', 4),
#  ('сортов', 4),
#  ('производится', 4),
#  ('перед', 4),
#  ('ряды', 4),
#  ('говяжьи', 4),
#  ('приезжающих', 4),
#  ('расстоянием', 4),
#  ('сермяжные', 4),
#  ('первых', 4),
#  ('шерстяные', 4),
#  ('одинадцатую', 4),
#  ('некоторые', 4),
#  ('тех', 4),
#  ('Вятского', 4),
#  ('небольшой', 4),
#  ('воскресным', 4),
#  ('полотна', 4),
#  ('отчине', 4),
#  ('временем', 4),
#  ('дважды', 4),
#  ('Графа', 4),
#  ('привозит', 4),
#  ('построены', 4),
#  ('Нежинском', 4),
#  ('море', 4),
#  ('Россия', 4),
#  ('посуда', 4),
#  ('Генваре', 4),
#  ('больше', 4),
#  ('количестве', 4),
#  ('скотиною', 4),
#  ('заячьи', 4),
#  ('Олонецкого', 4),
#  ('мелочной', 4),
#  ('прежде', 4),
#  ('начинающаяся', 4),
#  ('осенью', 4),
#  ('той', 4),
#  ('недорогими', 4),
#  ('Живоначальные', 4),
#  ('разную', 4),
#  ('Троицкая', 4),
#  ('Пятидесятницы', 4),
#  ('Рузы', 4),
#  ('Харькова', 4),
#  ('лавок', 4),
#  ('Новосиля', 4),
#  ('торгует', 4),
#  ('ь', 4),
#  ('много', 4),
#  ('Апостол', 4),
#  ('ми', 4),
#  ('1776', 4),
#  ('изделья', 4),
#  ('железо', 4),
#  ('серебро', 4),
#  ('состоит', 4),
#  ('те', 4),
#  ('большем', 3),
#  ('питейными', 3),
#  ('сырые', 3),
#  ('11', 3),
#  ('дворе', 3),
#  ('волчьи', 3),
#  ('ве', 3),
#  ('Великомученицы', 3),
#  ('Яренском', 3),
#  ('назад', 3),
#  ('Донковском', 3),
#  ('Малого', 3),
#  ('товаровъ', 3),
#  ('уезда', 3),
#  ('Мологи', 3),
#  ('Залесного', 3),
#  ('местечка', 3),
#  ('приуготовлениями', 3),
#  ('скота', 3),
#  ('медочными', 3),
#  ('канаты', 3),
#  ('первое', 3),
#  ('Старой', 3),
#  ('разною', 3),
#  ('жителей', 3),
#  ('работы', 3),
#  ('торгах', 3),
#  ('крестьянскою', 3),
#  ('Ивановская', 3),
#  ('Дамиана', 3),
#  ('острог', 3),
#  ('торгъ', 3),
#  ('Шуи', 3),
#  ('О', 3),
#  ('Иркутска', 3),
#  ('медвежьи', 3),
#  ('товару', 3),
#  ('материй', 3),
#  ('окрестные', 3),
#  ('саньми', 3),
#  ('А', 3),
#  ('Новагорода', 3),
#  ('товар', 3),
#  ('реки', 3),
#  ('Болхова', 3),
#  ('крестьянским', 3),
#  ('однажды', 3),
#  ('22', 3),
#  ('Казани', 3),
#  ('Россиан', 3),
#  ('зимою', 3),
#  ('Петровская', 3),
#  ('Можайска', 3),
#  ('продажа', 3),
#  ('чай', 3),
#  ('сахар', 3),
#  ('серебреными', 3),
#  ('Звенигородском', 3),
#  ('иногородные', 3),
#  ('Кесове', 3),
#  ('пушные', 3),
#  ('пятой', 3),
#  ('каждонедельные', 3),
#  ('туда', 3),
#  ('Симеона', 3),
#  ('летним', 3),
#  ('болеежь', 3),
#  ('чулки', 3),
#  ('средине', 3),
#  ('1784', 3),
#  ('Ноябре', 3),
#  ('Московские', 3),
#  ('оттуда', 3),
#  ('седьмой', 3),
#  ('каждонедельных', 3),
#  ('съежаются', 3),
#  ('пятниц', 3),
#  ('пост', 3),
#  ('всяким', 3),
#  ('окольными', 3),
#  ('печеным', 3),
#  ('Светлой', 3),
#  ('пятокъ', 3),
#  ('Прокопия', 3),
#  ('иные', 3),
#  ('находятся', 3),
#  ('ТИХОНОВА', 3),
#  ('1775', 3),
#  ('Архангельского', 3),
#  ('МИХАЙЛОВКА', 3),
#  ('главы', 3),
#  ('числом', 3),
#  ('гостиной', 3),
#  ('льняное', 3),
#  ('Креста', 3),
#  ('мясами', 3),
#  ('рядах', 3),
#  ('шубами', 3),
#  ('отправляет', 3),
#  ('всякого', 3),
#  ('здешние', 3),
#  ('Жители', 3),
#  ('щетиною', 3),
#  ('им', 3),
#  ('Евстафия', 3),
#  ('Р', 3),
#  ('другия', 3),
#  ('Козловском', 3),
#  ('лыками', 3),
#  ('великой', 3),
#  ('Ростова', 3),
#  ('путем', 3),
#  ('Мстиславском', 3),
#  ('разночинцы', 3),
#  ('Для', 3),
#  ('каждом', 3),
#  ('Сумском', 3),
#  ('имеется', 3),
#  ('каждогодно', 3),
#  ('Рузском', 3),
#  ('лавки', 3),
#  ('городок', 3),
#  ('селений', 3),
#  ('13', 3),
#  ('крамщики', 3),
#  ('девять', 3),
#  ('малым', 3),
#  ('вторник', 3),
#  ('купецкие', 3),
#  ('округе', 3),
#  ('привозными', 3),
#  ('торгуютъ', 3),
#  ('где', 3),
#  ('усекновения', 3),
#  ('подобные', 3),
#  ('крестьянское', 3),
#  ('Подле', 3),
#  ('крестьянами', 3),
#  ('нет', 3),
#  ('Алатырьском', 3),
#  ('отсюда', 3),
#  ('мелочми', 3),
#  ('табаком', 3),
#  ('льняным', 3),
#  ('вся', 3),
#  ('Ярославца', 3),
#  ('коем', 3),
#  ('маслом', 3),
#  ('воскресенье', 3),
#  ('КИРИЛОВ', 3),
#  ('виномъ', 3),
#  ('Норской', 3),
#  ('12', 3),
#  ('годовых', 3),
#  ('местечке', 3),
#  ('суровскими', 3),
#  ('производят', 3),
#  ('них', 3),
#  ('озера', 3),
#  ('Сретения', 3),
#  ('четвергам', 3),
#  ('10', 3),
#  ('двор', 3),
#  ('Бежецка', 3),
#  ('собирается', 3),
#  ('девятой', 3),
#  ('Фоминой', 3),
#  ('деревянной', 3),
#  ('Столпника', 3),
#  ('семь', 3),
#  ('каждое', 3),
#  ('Фомину', 3),
#  ('Калмыцких', 3),
#  ('городовъ', 3),
#  ('деревянная', 3),
#  ('соседних', 3),
#  ('Ваий', 3),
#  ('шелк', 3),
#  ('отпускают', 3),
#  ('бумагу', 3),
#  ('мехи', 3),
#  ('Провинций', 2),
#  ('всяких', 2),
#  ('всякое', 2),
#  ('Островском', 2),
#  ('прежния', 2),
#  ('мясо', 2),
#  ('мелкие', 2),
#  ('лисицы', 2),
#  ('Марша', 2),
#  ('рогожи', 2),
#  ('городом', 2),
#  ('сии', 2),
#  ('Олонецком', 2),
#  ('хлебе', 2),
#  ('хлопчатую', 2),
#  ('седмицу', 2),
#  ('СТАРОЙ', 2),
#  ('имеют', 2),
#  ('саломъ', 2),
#  ('БОРИСОВ', 2),
#  ('рублей', 2),
#  ('Васильевская', 2),
#  ('Голландския', 2),
#  ('тот', 2),
#  ('положено', 2),
#  ('шубы', 2),
#  ('Ильинская', 2),
#  ('посуде', 2),
#  ('Дворянства', 2),
#  ('крестьянству', 2),
#  ('Богоявление', 2),
#  ('тутошними', 2),
#  ('рекам', 2),
#  ('тамошних', 2),
#  ('ИВАНОВКА', 2),
#  ('высоки', 2),
#  ('Крымскою', 2),
#  ('нетокмо', 2),
#  ('золотые', 2),
#  ('деготь', 2),
#  ('уфимского', 2),
#  ('посуды', 2),
#  ('рукоделие', 2),
#  ('ЛУЧКА', 2),
#  ('Гороховецком', 2),
#  ('Росссийских', 2),
#  ('Сырную', 2),
#  ('ярмарке', 2),
#  ('Петербургской', 2),
#  ('отдаленных', 2),
#  ('была', 2),
#  ('сандал', 2),
#  ('говяжье', 2),
#  ('слободах', 2),
#  ('НОВОЙ', 2),
#  ('Стратилатовской', 2),
#  ('пятницею', 2),
#  ('Воскресение', 2),
#  ('У', 2),
#  ('Г', 2),
#  ('ИВАНОВО', 2),
#  ('Стратилата', 2),
#  ('происходит', 2),
#  ('СТАРАЯ', 2),
#  ('когда', 2),
#  ('годе', 2),
#  ('иноходью', 2),
#  ('САРАТОВ', 2),
#  ('цветам', 2),
#  ('Немецких', 2),
#  ('москательные', 2),
#  ('небольшем', 2),
#  ('КРАСНОЕ', 2),
#  ('лучшия', 2),
#  ('приезжающие', 2),
#  ('Первая', 2),
#  ('река', 2),
#  ('женъ', 2),
#  ('СОЛЬ', 2),
#  ('мещанам', 2),
#  ('Помещиков', 2),
#  ('юфть', 2),
#  ('года', 2),
#  ...]

# %%
stopwords = ['-',',','.','а','в','и',';','на','В','с','по',':','из'] # "helper" stopwords, to find significant text generally
stopwords.extend(['быва','ярмарк','наместничеств','город','он','год','уезд','зде','ден','сел','перв','проч','втор','а','котор','местечк','годов','недел','одн','дня','три','две','привоз','трет','друг','нем','пятниц','8','слобод','числ','1','такж','август','всяк','десят','для','сем','жител','еженедельн','четыр','же','то','6','четверт','как','съезжа','мест','9','больш','ноябр','месяц','обывател','киевск','29','продаж','монастыр','декабр','губерн','московск']) # words that aren't of interest to this analysis. can be replaced/commented out

# %%
stopped_tokens = [w for w in tok_stems if w not in stopwords]

# %%
stopped_text = nltk.text.Text(stopped_tokens)

# %%
nltk.FreqDist(stopped_text).most_common()
# Out:
# [('товар', 505),
#  ('купц', 355),
#  ('торг', 351),
#  ('разн', 343),
#  ('мелочн', 259),
#  ('приезжа', 252),
#  ('июл', 137),
#  ('шелков', 127),
#  ('хлеб', 118),
#  ('июн', 109),
#  ('сентябр', 108),
#  ('вин', 85),
#  ('крестьян', 83),
#  ('припас', 76),
#  ('скот', 75),
#  ('съестн', 74),
#  ('бумажн', 68),
#  ('ма', 66),
#  ('российск', 65),
#  ('октябр', 58),
#  ('генвар', 56),
#  ('пасх', 56),
#  ('холст', 50),
#  ('горяч', 47),
#  ('посуд', 47),
#  ('деревя', 46),
#  ('богородиц', 44),
#  ('продолжа', 44),
#  ('тог', 44),
#  ('част', 44),
#  ('кож', 43),
#  ('15', 43),
#  ('харьковск', 42),
#  ('от', 42),
#  ('сег', 40),
#  ('торжк', 40),
#  ('дни', 40),
#  ('екатеринославск', 40),
#  ('крестьянск', 40),
#  ('пеньк', 39),
#  ('близ', 39),
#  ('ближн', 39),
#  ('велик', 39),
#  ('прода', 38),
#  ('прочим', 38),
#  ('уездн', 38),
#  ('мед', 38),
#  ('ил', 38),
#  ('лежа', 38),
#  ('рыб', 37),
#  ('съезд', 36),
#  ('свят', 36),
#  ('могилевск', 36),
#  ('красн', 35),
#  ('тульск', 35),
#  ('черниговск', 35),
#  ('окольн', 35),
#  ('рижск', 35),
#  ('сво', 35),
#  ('кажд', 35),
#  ('москотильн', 34),
#  ('не', 34),
#  ('20', 34),
#  ('при', 34),
#  ('воскресен', 33),
#  ('23', 33),
#  ('вологодск', 33),
#  ('тамбовск', 32),
#  ('лошад', 32),
#  ('24', 32),
#  ('пят', 32),
#  ('приезж', 31),
#  ('полотск', 31),
#  ('кром', 31),
#  ('сюд', 31),
#  ('ко', 31),
#  ('мелк', 30),
#  ('два', 29),
#  ('понедельник', 29),
#  ('сверх', 29),
#  ('сукн', 29),
#  ('великороссийск', 28),
#  ('новогородск', 28),
#  ('25', 28),
#  ('да', 28),
#  ('рогат', 28),
#  ('имен', 28),
#  ('ярославск', 28),
#  ('посл', 27),
#  ('сол', 27),
#  ('14', 27),
#  ('овчин', 27),
#  ('окрестн', 27),
#  ('о', 27),
#  (')', 27),
#  ('пост', 27),
#  ('издел', 27),
#  ('тверск', 26),
#  ('лошадьм', 26),
#  ('торгов', 25),
#  ('товаром', 25),
#  ('ярмарок', 25),
#  ('но', 25),
#  ('пивом', 24),
#  ('крестьянств', 24),
#  ('26', 24),
#  ('ярославл', 24),
#  ('воск', 24),
#  ('дворц', 23),
#  ('лавочн', 23),
#  ('мал', 23),
#  ('господн', 23),
#  ('масл', 23),
#  ('2', 23),
#  ('21', 22),
#  ('главн', 22),
#  ('во', 22),
#  ('праздник', 22),
#  ('апрел', 21),
#  ('дух', 21),
#  ('льнян', 21),
#  ('рукодел', 20),
#  ('матер', 20),
#  ('пензенск', 20),
#  ('со', 20),
#  ('март', 20),
#  ('курск', 20),
#  ('сошеств', 20),
#  ('калужск', 20),
#  ('один', 20),
#  ('никол', 19),
#  ('рождеств', 19),
#  ('шерстян', 19),
#  ('псковск', 19),
#  ('купечеств', 19),
#  ('вознесен', 19),
#  ('костромск', 19),
#  ('врем', 19),
#  ('казанск', 19),
#  ('иногд', 18),
#  ('великомученик', 18),
#  ('орловск', 18),
#  ('углич', 18),
#  ('зарайск', 18),
#  ('окол', 18),
#  ('сал', 18),
#  ('девят', 18),
#  ('успен', 18),
#  ('рязанск', 18),
#  ('каждонедельн', 18),
#  ('там', 18),
#  ('чисел', 18),
#  ('называ', 17),
#  ('дне', 17),
#  ('привозим', 17),
#  ('тул', 17),
#  ('св', 17),
#  ('1780', 17),
#  ('у', 17),
#  ('иностра', 17),
#  ('погост', 17),
#  ('синбирск', 17),
#  ('чудотворц', 17),
#  ('петр', 17),
#  ('феврал', 16),
#  ('павл', 16),
#  ('северск', 16),
#  ('родя', 16),
#  ('пяток', 16),
#  ('тож', 16),
#  ('пророк', 16),
#  ('тольк', 16),
#  ('апостол', 16),
#  ('смол', 16),
#  ('пресвят', 15),
#  ('вещ', 15),
#  ('иркутск', 15),
#  ('верст', 15),
#  ('дегт', 15),
#  ('том', 15),
#  ('шест', 14),
#  ('изюм', 14),
#  ('троицк', 14),
#  ('преображен', 14),
#  ('что', 14),
#  ('торговл', 14),
#  ('серпухов', 14),
#  ('ест', 14),
#  ('москв', 14),
#  ('малороссийск', 13),
#  ('желез', 13),
#  ('за', 13),
#  ('небольш', 13),
#  ('нижегородск', 13),
#  ('раз', 13),
#  ('пустын', 13),
#  ('динабург', 13),
#  ('бол', 13),
#  ('воронежск', 13),
#  ('иоан', 13),
#  ('покров', 13),
#  ('миргородск', 13),
#  ('переславл', 12),
#  ('покупа', 12),
#  ('суббот', 12),
#  ('1779', 12),
#  ('владимерск', 12),
#  ('каширск', 12),
#  ('обыкновен', 12),
#  ('мягк', 12),
#  ('крымск', 12),
#  ('лубенск', 12),
#  ('рухляд', 12),
#  ('пив', 12),
#  ('кашир', 12),
#  ('волоколамск', 12),
#  ('преполовен', 12),
#  ('произрастен', 12),
#  ('гарусн', 11),
#  ('елецк', 11),
#  ('венев', 11),
#  ('начина', 11),
#  ('тобольск', 11),
#  ('георг', 11),
#  ('дела', 11),
#  ('одинадцат', 11),
#  ('серед', 11),
#  ('скотин', 11),
#  ('бежецк', 11),
#  ('1778', 11),
#  ('сырн', 11),
#  ('до', 11),
#  ('петровск', 11),
#  ('б', 11),
#  ('рек', 11),
#  ('дню', 11),
#  ('також', 11),
#  ('богоявлен', 11),
#  ('к', 11),
#  ('мелоч', 10),
#  ('особлив', 10),
#  ('отправля', 10),
#  ('вторник', 10),
#  ('динабургск', 10),
#  ('борисоглебск', 10),
#  ('16', 10),
#  ('говяж', 10),
#  ('станиц', 10),
#  ('7', 10),
#  ('собира', 10),
#  ('светл', 10),
#  ('архангельск', 10),
#  ('крестья', 10),
#  ('ряд', 10),
#  ('производ', 10),
#  ('залеск', 10),
#  ('деревн', 10),
#  ('полотн', 10),
#  ('здешн', 9),
#  ('множеств', 9),
#  ('стекля', 9),
#  ('пряж', 9),
#  ('володимерск', 9),
#  ('колес', 9),
#  ('донск', 9),
#  ('нескольк', 9),
#  ('деревенск', 9),
#  ('1782', 9),
#  ('5', 9),
#  ('знатн', 9),
#  ('покупк', 9),
#  ('саратовск', 9),
#  ('николаевск', 9),
#  ('нов', 9),
#  ('недельн', 9),
#  ('серебрен', 9),
#  ('си', 9),
#  ('троицын', 9),
#  ('крест', 8),
#  ('псков', 8),
#  ('так', 8),
#  ('28', 8),
#  ('уфимск', 8),
#  ('пошехонск', 8),
#  ('последн', 8),
#  ('боровск', 8),
#  ('железн', 8),
#  ('некотор', 8),
#  ('честн', 8),
#  ('яренск', 8),
#  ('се', 8),
#  ('шатск', 8),
#  ('небогат', 8),
#  ('провинц', 8),
#  ('бел', 8),
#  ('крамн', 8),
#  ('романов', 8),
#  ('волост', 8),
#  ('чрез', 8),
#  ('мяс', 8),
#  ('рогачев', 8),
#  ('люд', 8),
#  ('зимн', 8),
#  ('парч', 8),
#  ('калуг', 8),
#  ('сен', 8),
#  ('17', 8),
#  ('покровск', 8),
#  ('ещ', 8),
#  ('шанец', 8),
#  ('всеедн', 8),
#  ('можайск', 8),
#  ('пермск', 8),
#  ('хлебом', 8),
#  ('позумент', 7),
#  ('двор', 7),
#  ('сибир', 7),
#  ('соседствен', 7),
#  ('30', 7),
#  ('крепост', 7),
#  ('18', 7),
#  ('летн', 7),
#  ('1781', 7),
#  ('полтавск', 7),
#  ('челябинск', 7),
#  ('тамошн', 7),
#  ('стар', 7),
#  ('смоленск', 7),
#  ('отчин', 7),
#  ('воскресн', 7),
#  ('парусн', 7),
#  ('сибирск', 7),
#  ('скупа', 7),
#  ('ивановск', 7),
#  ('миха', 7),
#  ('лен', 7),
#  ('христов', 7),
#  ('деревен', 7),
#  ('китайск', 7),
#  ('переяславск', 7),
#  ('постро', 7),
#  ('4', 7),
#  ('богородицк', 7),
#  ('устюжск', 7),
#  ('мног', 7),
#  ('', 6),
#  ('высок', 6),
#  ('их', 6),
#  ('коров', 6),
#  ('суздальск', 6),
#  ('ча', 6),
#  ('олонецк', 6),
#  ('купецк', 6),
#  ('петров', 6),
#  ('фомин', 6),
#  ('выборгск', 6),
#  ('весн', 6),
#  ('предтеч', 6),
#  ('брат', 6),
#  ('четверток', 6),
#  ('димитр', 6),
#  ('троиц', 6),
#  ('близост', 6),
#  ('кашинск', 6),
#  ('рыбн', 6),
#  ('руз', 6),
#  ('городк', 6),
#  ('архистратиг', 6),
#  ('19', 6),
#  ('1777', 6),
#  ('прилуцк', 6),
#  ('шерст', 6),
#  ('нужн', 6),
#  ('воздвижен', 6),
#  ('приуготовлен', 6),
#  ('немецк', 6),
#  ('параскев', 6),
#  ('саранск', 6),
#  ('поскон', 6),
#  ('мор', 6),
#  ('щетин', 6),
#  ('пут', 6),
#  ('козельск', 6),
#  ('гостин', 6),
#  ('продолжающ', 6),
#  ('табак', 6),
#  ('валуек', 5),
#  ('остров', 5),
#  ('добр', 5),
#  ('межд', 5),
#  ('нежин', 5),
#  ('грек', 5),
#  ('работ', 5),
#  ('днем', 5),
#  ('сермяжн', 5),
#  ('иногородн', 5),
#  ('новосил', 5),
#  ('стародубовск', 5),
#  ('росс', 5),
#  ('токм', 5),
#  ('мещовск', 5),
#  ('шуб', 5),
#  ('никольск', 5),
#  ('пушн', 5),
#  ('турецк', 5),
#  ('щепетильн', 5),
#  ('богоматер', 5),
#  ('святител', 5),
#  ('дням', 5),
#  ('2о', 5),
#  ('округ', 5),
#  ('городок', 5),
#  ('тройцын', 5),
#  ('сырейн', 5),
#  ('глинян', 5),
#  ('острог', 5),
#  ('азиатск', 5),
#  ('гадяцк', 5),
#  ('27', 5),
#  ('сахар', 5),
#  ('сред', 5),
#  ('пригород', 5),
#  ('ва', 5),
#  ('всех', 5),
#  ('выбойк', 5),
#  ('уточн', 5),
#  ('состо', 5),
#  ('им', 5),
#  ('церкв', 5),
#  ('времен', 5),
#  ('кесов', 5),
#  ('осен', 5),
#  ('чулк', 5),
#  ('коноплян', 5),
#  ('богослов', 5),
#  ('сих', 5),
#  ('месяцах', 5),
#  ('седьм', 5),
#  ('набойчат', 5),
#  ('все', 5),
#  ('3', 5),
#  ('гор', 5),
#  ('белев', 5),
#  ('пригоня', 5),
#  ('лавк', 5),
#  ('белозерск', 5),
#  ('соб', 5),
#  ('шелк', 5),
#  ('сыр', 5),
#  ('субботн', 5),
#  ('ежегодн', 5),
#  ('великолуцк', 4),
#  ('граф', 4),
#  ('рогачевск', 4),
#  ('изюмск', 4),
#  ('солен', 4),
#  ('четверг', 4),
#  ('лес', 4),
#  ('ми', 4),
#  ('четырех', 4),
#  ('селен', 4),
#  ('посад', 4),
#  ('сорт', 4),
#  ('холм', 4),
#  ('городов', 4),
#  ('белицк', 4),
#  ('приход', 4),
#  ('економическ', 4),
#  ('богоявленск', 4),
#  ('сумск', 4),
#  ('сам', 4),
#  ('заяч', 4),
#  ('тихонов', 4),
#  ('медн', 4),
#  ('вощин', 4),
#  ('прежд', 4),
#  ('серебр', 4),
#  ('поселя', 4),
#  ('дважд', 4),
#  ('польск', 4),
#  ('перед', 4),
#  ('борис', 4),
#  ('торгуют', 4),
#  ('бывш', 4),
#  ('род', 4),
#  ('расстоян', 4),
#  ('бывает', 4),
#  ('лык', 4),
#  ('торжок', 4),
#  ('живоначальн', 4),
#  ('волч', 4),
#  ('калмык', 4),
#  ('шу', 4),
#  ('ильинск', 4),
#  ('суровск', 4),
#  ('тех', 4),
#  ('недорог', 4),
#  ('зим', 4),
#  ('вятск', 4),
#  ('господ', 4),
#  ('был', 4),
#  ('сдела', 4),
#  ('осьм', 4),
#  ('козловск', 4),
#  ('нежинск', 4),
#  ('михайловк', 4),
#  ('вологд', 4),
#  ('тутошн', 4),
#  ('благовещенск', 4),
#  ('вер', 4),
#  ('под', 4),
#  ('имеют', 4),
#  ('вольн', 4),
#  ('те', 4),
#  ('ин', 4),
#  ('питейн', 4),
#  ('сукон', 4),
#  ('подобн', 4),
#  ('трех', 4),
#  ('пятидесятниц', 4),
#  ('пач', 4),
#  ('съежа', 4),
#  ('мелочм', 4),
#  ('молог', 4),
#  ('климовицк', 4),
#  ('внутрен', 4),
#  ('иванов', 4),
#  ('продукт', 4),
#  ('пореч', 4),
#  ('пред', 4),
#  ('1776', 4),
#  ('мелочьм', 4),
#  ('половин', 4),
#  ('двух', 4),
#  ('собор', 4),
#  ('лавок', 4),
#  ('уральск', 4),
#  ('алексин', 4),
#  ('бумаг', 4),
#  ('лисиц', 4),
#  ('харьков', 4),
#  ('количеств', 4),
#  ('керенск', 4),
#  ('спас', 4),
#  ('привозн', 3),
#  ('средин', 3),
#  ('успенск', 3),
#  ('лучш', 3),
#  ('вином', 3),
#  ('китайк', 3),
#  ('донковск', 3),
#  ('устюг', 3),
#  ('озер', 3),
#  ('коломн', 3),
#  ('назад', 3),
#  ('алатырьск', 3),
#  ('водян', 3),
#  ('рузск', 3),
#  ('хлопчат', 3),
#  ('ивановк', 3),
#  ('россиа', 3),
#  ('воронеж', 3),
#  ('москательн', 3),
#  ('славн', 3),
#  ('брянск', 3),
#  ('рыбинск', 3),
#  ('великомучениц', 3),
#  ('однажд', 3),
#  ('рогож', 3),
#  ('петербургск', 3),
#  ('кинешм', 3),
#  ('медвеж', 3),
#  ('отпуска', 3),
#  ('саньм', 3),
#  ('каждогодн', 3),
#  ('11', 3),
#  ('оттуд', 3),
#  ('г', 3),
#  ('канат', 3),
#  ('цен', 3),
#  ('калмыцк', 3),
#  ('13', 3),
#  ('кашин', 3),
#  ('происход', 3),
#  ('глав', 3),
#  ('рост', 3),
#  ('отсюд', 3),
#  ('петербург', 3),
#  ('ростов', 3),
#  ('куниц', 3),
#  ('свин', 3),
#  ('хмел', 3),
#  ('соседн', 3),
#  ('казан', 3),
#  ('мех', 3),
#  ('золот', 3),
#  ('краснослободск', 3),
#  ('прокоп', 3),
#  ('белк', 3),
#  ('немал', 3),
#  ('подл', 3),
#  ('катайск', 3),
#  ('имеет', 3),
#  ('макар', 3),
#  ('промышленник', 3),
#  ('полож', 3),
#  ('евстаф', 3),
#  ('завод', 3),
#  ('касимовск', 3),
#  ('наход', 3),
#  ('оловя', 3),
#  ('ладон', 3),
#  ('нет', 3),
#  ('болееж', 3),
#  ('симеон', 3),
#  ('армян', 3),
#  ('любимск', 3),
#  ('болхов', 3),
#  ('дамиа', 3),
#  ('девич', 3),
#  ('камк', 3),
#  ('первоверховн', 3),
#  ('седмиц', 3),
#  ('выдр', 3),
#  ('дмитровск', 3),
#  ('столпник', 3),
#  ('порт', 3),
#  ('александровск', 3),
#  ('медочн', 3),
#  ('торопецк', 3),
#  ('учрежд', 3),
#  ('отвоз', 3),
#  ('товаров', 3),
#  ('22', 3),
#  ('ан', 3),
#  ('туд', 3),
#  ('ве', 3),
#  ('юфт', 3),
#  ('1784', 3),
#  ('девя', 3),
#  ('свинск', 3),
#  ('залесн', 3),
#  ('новагород', 3),
#  ('12', 3),
#  ('арсамазск', 3),
#  ('разночинц', 3),
#  ('волокопинежск', 3),
#  ('муромск', 3),
#  ('ни', 3),
#  ('них', 3),
#  ('сретен', 3),
#  ('коломенск', 3),
#  ('кирил', 3),
#  ('10', 3),
#  ('област', 3),
#  ('дорог', 3),
#  ('вод', 3),
#  ('норск', 3),
#  ('зимов', 3),
#  ('кос', 3),
#  ('усекновен', 3),
#  ('крамщик', 3),
#  ('баран', 3),
#  ('сапог', 3),
#  ('галицк', 3),
#  ('алексеевск', 3),
#  ('нижн', 3),
#  ('уст', 3),
#  ('сторон', 3),
#  ('где', 3),
#  ('цвет', 3),
#  ('верхн', 3),
#  ('р', 3),
#  ('вознесенск', 3),
#  ('ярославц', 3),
#  ('икр', 3),
#  ('печен', 3),
#  ('1775', 3),
#  ('звенигородск', 3),
#  ('суздал', 3),
#  ('деньг', 3),
#  ('вся', 3),
#  ('тут', 3),
#  ('мстиславск', 3),
#  ('кропивн', 3),
#  ('колп', 2),
#  ('иноверц', 2),
#  ('туринск', 2),
#  ('границ', 2),
#  ('белогородск', 2),
#  ('сарбаев', 2),
#  ('ефремов', 2),
#  ('кадом', 2),
#  ('квасц', 2),
#  ('напитк', 2),
#  ('глеб', 2),
#  ('ворва', 2),
#  ('отдален', 2),
#  ('малоросс', 2),
#  ('свирск', 2),
#  ('часовн', 2),
#  ('веревк', 2),
#  ('обод', 2),
#  ('алешн', 2),
#  ('барышевк', 2),
#  ('рубл', 2),
#  ('подобным', 2),
#  ('белокурин', 2),
#  ('сряд', 2),
#  ('колюпановк', 2),
#  ('лет', 2),
#  ('прежн', 2),
#  ('ямпол', 2),
#  ('лучк', 2),
#  ('николин', 2),
#  ('молодов', 2),
#  ('салом', 2),
#  ('единожд', 2),
#  ('дегот', 2),
#  ('конск', 2),
#  ('град', 2),
#  ('одиножд', 2),
#  ('деркул', 2),
#  ('тот', 2),
#  ('тотемск', 2),
#  ('гвозд', 2),
#  ('вразсужден', 2),
#  ('дубровк', 2),
#  ('грезет', 2),
#  ('ординарн', 2),
#  ('свержин', 2),
#  ('куд', 2),
#  ('прилук', 2),
#  ('кле', 2),
#  ('васильевск', 2),
#  ('иван', 2),
#  ('крестител', 2),
#  ('уклад', 2),
#  ('мещан', 2),
#  ('языков', 2),
#  ('корабл', 2),
#  ('ветк', 2),
#  ('чуж', 2),
#  ('кубенск', 2),
#  ('замк', 2),
#  ('упадк', 2),
#  ('ным', 2),
#  ('рог', 2),
#  ('ям', 2),
#  ('купеческ', 2),
#  ('брусков', 2),
#  ('башкирц', 2),
#  ('беркунов', 2),
#  ('оренбург', 2),
#  ('пятницк', 2),
#  ('шведск', 2),
#  ('щепетин', 2),
#  ('волхов', 2),
#  ('крапивн', 2),
#  ('ском', 2),
#  ('десн', 2),
#  ('образ', 2),
#  ('персидск', 2),
#  ('вещм', 2),
#  ('ярмарочн', 2),
#  ('коф', 2),
#  ('достопамятн', 2),
#  ('хрящ', 2),
#  ('щепет', 2),
#  ('хот', 2),
#  ('хован', 2),
#  ('различн', 2),
#  ('кра', 2),
#  ('дерпт', 2),
#  ('уразов', 2),
#  ('речк', 2),
#  ('производят', 2),
#  ('темниковск', 2),
#  ('иноход', 2),
#  ('липецк', 2),
#  ('ливенск', 2),
#  ('арзамаск', 2),
#  ('ром', 2),
#  ('спаск', 2),
#  ('епифан', 2),
#  ('краснопол', 2),
#  ('построен', 2),
#  ('сторожевск', 2),
#  ('зубцов', 2),
#  ('лошадин', 2),
#  ('екатеринбург', 2),
#  ('произрастан', 2),
#  ('нын', 2),
#  ('сватов', 2),
#  ('короченск', 2),
#  ('камен', 2),
#  ('храмов', 2),
#  ('уф', 2),
#  ('пятидесят', 2),
#  ('доск', 2),
#  ('сетк', 2),
#  ('богородск', 2),
#  ('васил', 2),
#  ('марк', 2),
#  ('цар', 2),
#  ('тюмен', 2),
#  ('орл', 2),
#  ('михайловск', 2),
#  ('краск', 2),
#  ('яр', 2),
#  ('алатырск', 2),
#  ('сасов', 2),
#  ('пол', 2),
#  ('богомол', 2),
#  ('починк', 2),
#  ('конотоп', 2),
#  ('козак', 2),
#  ('новгородск', 2),
#  ('сарат', 2),
#  ('когд', 2),
#  ('черлянков', 2),
#  ('вь', 2),
#  ('савин', 2),
#  ('лежнев', 2),
#  ('настоя', 2),
#  ('ежедневн', 2),
#  ('семик', 2),
#  ('крашен', 2),
#  ('костром', 2),
#  ('стратилат', 2),
#  ('получа', 2),
#  ('повсягодн', 2),
#  ('сте', 2),
#  ('парск', 2),
#  ('сельц', 2),
#  ('переяславл', 2),
#  ('свеж', 2),
#  ('1783', 2),
#  ('потребн', 2),
#  ('сергиевск', 2),
#  ('шипин', 2),
#  ('гороховецк', 2),
#  ('гремяч', 2),
#  ('домашн', 2),
#  ('хрящев', 2),
#  ('цел', 2),
#  ('вычегодск', 2),
#  ('ближайш', 2),
#  ('самар', 2),
#  ('средн', 2),
#  ('живущ', 2),
#  ('промысл', 2),
#  ('помещик', 2),
#  ('екатерин', 2),
#  ('впроч', 2),
#  ('состоя', 2),
#  ('вар', 2),
#  ('яблунев', 2),
#  ('курмышск', 2),
#  ('нетокм', 2),
#  ('нагольн', 2),
#  ('карачев', 2),
#  ('мен', 2),
#  ('иосиф', 2),
#  ('лужк', 2),
#  ('городищ', 2),
#  ('сух', 2),
#  ('платк', 2),
#  ('базар', 2),
#  ('вытегр', 2),
#  ('л', 2),
#  ('оршанск', 2),
#  ('нич', 2),
#  ('бобр', 2),
#  ('аврам', 2),
#  ('тафт', 2),
#  ('слывет', 2),
#  ('карпов', 2),
#  ('дел', 2),
#  ('домов', 2),
#  ('лебедин', 2),
#  ('юрьев', 2),
#  ('чег', 2),
#  ('княз', 2),
#  ('пятницам', 2),
#  ('воскресенск', 2),
#  ('важн', 2),
#  ('европейск', 2),
#  ('донков', 2),
#  ('киренск', 2),
#  ('мясоед', 2),
#  ('галантерейн', 2),
#  ('енисейск', 2),
#  ('учрежден', 2),
#  ('погромц', 2),
#  ('кошеч', 2),
#  ('городн', 2),
#  ('санда', 2),
#  ('марш', 2),
#  ('полушелков', 2),
#  ('овц', 2),
#  ('прост', 2),
#  ('тихвинск', 2),
#  ('смежн', 2),
#  ('бы', 2),
#  ('стратилатовск', 2),
#  ('свиажск', 2),
#  ('след', 2),
#  ('аргамач', 2),
#  ('варвар', 2),
#  ('тюртен', 2),
#  ('заморск', 2),
#  ('одеван', 2),
#  ('подворгальск', 2),
#  ('похвальн', 2),
#  ('намерен', 2),
#  ('принадлежа', 2),
#  ('екатеринбургск', 2),
#  ('стран', 2),
#  ('жен', 2),
#  ('симеоновск', 2),
#  ('шапк', 2),
#  ('дал', 2),
#  ('лебедян', 2),
#  ('белевск', 2),
#  ('пупк', 2),
#  ('муриков', 2),
#  ('рыльск', 2),
#  ('ахтырк', 2),
#  ('довольн', 2),
#  ('михайл', 2),
#  ('привозят', 2),
#  ('ту', 2),
#  ('риг', 2),
#  ('горшк', 2),
#  ('поводнев', 2),
#  ('глинск', 2),
#  ('ревел', 2),
#  ('вышгород', 2),
#  ('пятничн', 2),
#  ('ком', 2),
#  ('веневск', 2),
#  ('60', 2),
#  ('черн', 2),
#  ('островск', 2),
#  ('отъезжа', 2),
#  ('поселян', 2),
#  ('игл', 2),
#  ('п', 2),
#  ('косм', 2),
#  ('бык', 2),
#  ('дворянств', 2),
#  ('вает', 2),
#  ('чухлом', 2),
#  ('кавказск', 2),
#  ('кумач', 2),
#  ('борзн', 2),
#  ('алексинск', 2),
#  ('миргород', 2),
#  ('приморск', 2),
#  ('бронниц', 2),
#  ('произведен', 2),
#  ('рук', 2),
#  ('отпуск', 2),
#  ('дров', 2),
#  ('оклад', 2),
#  ('мезенск', 2),
#  ('кушак', 2),
#  ('ичн', 2),
#  ('ош', 2),
#  ('оскол', 2),
#  ('поташ', 2),
#  ('новогородскаг', 2),
#  ('миропол', 2),
#  ('форпост', 2),
#  ('опочек', 2),
#  ('росссийск', 2),
#  ('возвраща', 2),
#  ('голландск', 2),
#  ('сызран', 2),
#  ('ярополч', 2),
#  ('звенигород', 2),
#  ('петропавловск', 2),
#  ('рамен', 2),
#  ('феодор', 2),
#  ('ход', 2),
#  ('рязан', 2),
#  ('руск', 2),
#  ('мглин', 2),
#  ('звер', 2),
#  ('штоф', 2),
#  ('введен', 2),
#  ('вял', 2),
#  ('холстом', 2),
#  ('дмитровк', 1),
#  ('народ', 1),
#  ('сход', 1),
#  ('незнатн', 1),
#  ('салтов', 1),
#  ('юрьевц', 1),
#  ...]

# %%
top50 = [p[0] for p in nltk.FreqDist(stopped_text).most_common()][:50]

# %%
nltk.FreqDist(stopped_text).plot(25,cumulative=True)

# %%
top50
# Out:
# ['товар',
#  'купц',
#  'торг',
#  'разн',
#  'мелочн',
#  'приезжа',
#  'июл',
#  'шелков',
#  'хлеб',
#  'июн',
#  'сентябр',
#  'вин',
#  'крестьян',
#  'припас',
#  'скот',
#  'съестн',
#  'бумажн',
#  'ма',
#  'российск',
#  'октябр',
#  'генвар',
#  'пасх',
#  'холст',
#  'горяч',
#  'посуд',
#  'деревя',
#  'богородиц',
#  'продолжа',
#  'тог',
#  'част',
#  'кож',
#  '15',
#  'харьковск',
#  'от',
#  'сег',
#  'торжк',
#  'дни',
#  'екатеринославск',
#  'крестьянск',
#  'пеньк',
#  'близ',
#  'ближн',
#  'велик',
#  'прода',
#  'прочим',
#  'уездн',
#  'мед',
#  'ил',
#  'лежа',
#  'рыб']

# %%
[reverse_stem[w][0] for w in top50]
# Out:
# ['товары',
#  'купцам',
#  'торгующих',
#  'разными',
#  'мелочного',
#  'Приезжают',
#  'Июле',
#  'шелковых',
#  'хлебе',
#  'Июня',
#  'Сентябре',
#  'вина',
#  'крестьянам',
#  'припасы',
#  'скот',
#  'съестным',
#  'бумажную',
#  'Маия',
#  'Российские',
#  'Октябре',
#  'Генваря',
#  'Пасхе',
#  'холстов',
#  'горячие',
#  'посуде',
#  'деревянном',
#  'Богородицы',
#  'продолжав',
#  'того',
#  'Часть',
#  'кожами',
#  '15',
#  'Харьковского',
#  'от',
#  'сего',
#  'торжков',
#  'дни',
#  'Екатеринославском',
#  'крестьянское',
#  'Пенькою',
#  'близ',
#  'ближних',
#  'Великой',
#  'проданные',
#  'прочимъ',
#  'уездных',
#  'мед',
#  'или',
#  'лежащем',
#  'рыбою']

# %%
with open("../resources/reverse_stem.json","w",encoding='utf-8') as fp:
    json.dump(reverse_stem,fp)

# %%
ru_stemmer.stem('смол')
# Out:
# 'смол'

# %%
reverse_stem["красн"]
# Out:
# ['красным', 'красными', 'КРАСНОЕ', 'красной', 'красную', 'КРАСНОЙ', 'красные']

# %%
text.concordance("крамными",lines=1000,width=135)
# Out:
# Displaying 7 of 7 matches:
# . Купцы приезжают на оные из близ лежащих городов с красными , крамными и прочими товарами , с стеклянною и деревянною посудою , с мел
# Михаила . Купцы приезжают из близ лежащих городов с красными , крамными и прочими товарами , стеклянною и деревянною посудою , съестны
# я . Купцы приезжают на оные из близ лежащих городов с красными крамными и прочими товарами , с стеклянною и деревянною посудою , с мел
# 6 . Купцы приезжают на оные из близ лежащих городов с красными крамными и прочими товарами , стеклянною и деревянною посудою и мелкою
# в . Купцы приезжают на оные из близ лежащих городов с красными крамными и прочими товарами , с стеклянною и деревянною посудою , с мел
# невные съезды отправляются привозными из окольных мест мелкими крамными вещами , хлебом , глиняною посудою , кожами , колесами к други
# новская ; купцы приезжают из близ лежащих городов с красными , крамными , суконными и прочими товарами ; а жители тех мест продают рог

# %%
text.concordance("привозят",lines=1000,width=135)
# Out:
# Displaying 103 of 103 matches:
# сы и лошадей . Для покупки сего приезжают Российские купцы , и привозят с собою всякие мелочные товары , а уездные обыватели торгуют х
# тва . Здесь бывает ярмарка о десятой пятнице , Июля 8 ; товары привозят на оную из разных городов и уездов купцы , шелк , бумагу красн
# ничества . В сем городе бывает ярмарка Августа 16 , на которую привозят из разных городов купцы мелочные и прочие товары ; торг продол
# монастырем в Троицын день и в десятую пятницу ; товары на оные привозят из уезду холсты льняные разные , да из городов Ярославля , Пер
#  торг только весною во время полой воды , на которой крестьяне привозят разные припасы и рукоделья своего вещи . СЕРДОБОЛЬ , с 1784 го
# ели в девятую , в десятую и во вторуюнадесять пятницы ; товары привозят из иных городов и из уездов крестьянские , съестные и прочие ,
# Петра и Павла , и в день Покрова Пресвятые Богородицы ; товары привозят купцы из Новагорода и из Торопца всякие москотильные , и сенок
# ком уезде . Здесь бывает в год один торжок , на которой товары привозят из уезду , холсты льняные разные , да из городов Ярославля , П
# о два дни ; приезжают на оные купцы из соседственных городов ; привозят шелковые бумажные и прочие товары небольшим числомъ . СУЗДАЛЬ
# е ярмарки съезжаются разных городов Российские купцы и Греки ; привозят хорошия сукна , шелковые материи , парчи , разную посуду , сах
# в Генваре и Феврале месяцах ; приезжают разных городов купцы , привозят хлеб , шелковые и бумажные товары , шерстяные материи , сукна
# и Орловской Провинций , из Болхова и Белева и других городов ; привозят товары москотильные , несколько бумажных , шелковых и других с
# аздника Успения Пресвятые Богородицы дней за пять , на которую привозят холст и прочие мелочные Российские товары , также и шелковые .
#  еженедельной торг по вторникам , на которой уездные обыватели привозят всякой хлеб и прочие сырейные и съестные товары . ХОМУТЦЫ , ме
# ря 26 чисел , но токмо знатных товаров в продаже не бывает , и привозят по близости из других городов по малому числу мелочные товары
#  ярмарка на 14 число Сентября , на которую из уездов обыватели привозят всякой хлеб и прочие сырейные и съестные товары . ШИШАКИ , мес
# ры чрез море на кораблях из чужих краев к Архангельскому порту привозят ; а Российские в те места отпускают всякие привозимые чрез вер
# ва . Сюда приезжают крестьяне в понедельник и четверток товары привозят хлеб и съестные припасы , и с разным лесом , сеном и горшками
# ют рогатой скот лошадей , хлеб , смолу , горячее вино и проч . Привозят также сюда для продажи жителям Крымскую соль . ЯГОТИН , местеч
#  рогатой скот , лошадей , хлеб , смолу , горячее вино и проч . Привозят также сюда для продажи жителям Крымскую соль . ЯДРИН , с 1781
#  уезде . Здесь бывает ярмарка в последних числах Июля месяца ; привозят купцы разные мелочные шелковые товары . АТКАРСК , город Сарато
# етвертая Октября 28 дня ; купцы приезжают из раз ных городов , привозят парчи , шелковые материи и серебро в деле ; торгуют также скот
#  в зимнее время и по воскресеньям торги , на которые крестьяне привозят более хлеб , съестные припасы и разные для жителей потребности
#  скот , лошадей , хлеб , смолу , горячее вино и прочее ; также привозят сюда для продажи жителям Крымскую соль . БАТРАК , село Синбирс
# 9 Июня по 12 Июля бывает годовая ярмарка , на которую особливо привозят много уральской рыбы и икры . БАТУРИН , местечко Новогородског
# естве и уезде . Здесь бывает ярмарка в последних числах Июля ; привозят на оную купцы разные мелочные шелковые товары . БЕРЕЗОВ , горо
# здесь базар , куда съезжаются жители всех около лежащих мест ; привозят на торжище все свои домашния рукоделия , коими они избыточеств
#  Ноября Купцы приезжают на оные из разных Российских городов ; привозят шелковые товары , парчи , позументы золотые и серебро в деле ;
# одов Тулы , Епифани , Кропивны , Дедилова , Ефремова и Донкова привозят мелочные красные товары , а оных городов из уездов крестьяне к
# ая Маия 9 , вторая Декабря 6 , на которые той округи крестьяне привозят разные съестные припасы , а купцы мелочные товары . БОГОЯВЛЕНС
# ущие в близости оной слободы крестьяне и прочие разночинцы , и привозят на продажу хлеб , столовые запасы и деланную ими деревянную и
# риезжают купцы из Тулы , Калуги , Серпухова и прочих городов ; привозят . шелковые и прочие товары , а по большей части крестьяне съез
# ество из Калуги , Мещовска , Болхова , Белева и других городов привозят товары москотильные ; но есть несколько бумажных , шелковых и
# овых и других материй ; а по большей части и уездные крестьяне привозят разные уездные товары , всякой хлебе , пеньку , масло , мед ,
#  скот , лошадей , хлеб , смолу , горячее вино и прочее . Также привозят сюда для продажи жителям Крымскую соль . БЕЖЕЦК , город Тверск
# родолжающаяся до 5 Июля ; приезжают купцы из смежных городов ; привозят товары шелковые и прочие москотильные мелочные и железные . Зд
# ых торгует крестьянство разными их домовными издельями , также привозят мя сено и хлебъ . БЕЛОЗЕРСКОЙ КИРИЛОВ монастырь , того же Наме
# и , Серпухова , Можайска , Боровска и прочих ближних городов ; привозят шелковые , бумажные , москотильные и прочие товары небольшим ч
# ранском уезде . Здесь бывает ярмарка в последних числах Июля ; привозят купцы разные мелочные шелковые товары . ВОЗНЕСЕНСКОЙ , погост
# жи крестьянам и для покупки у них деревенских товаров , на что привозят с собою деньги . ВОЛСК , город Саратовского Наместничества . В
# едельный съезд для торговли ; приезжают сюда купцы , но только привозят мелочные товары . ВОСКРЕСЕНСК , город Московской Губернии . В
#  : первая Августа 24 вторая Сентября 21 , на которыя крестьяне привозят по большей части рогатой скот , лошадей и съестные припасы . В
# ском уезде . В оном бывает ярмарка Сентября 8 дня , на которую привозят из уезду холсты льняные разные , да из городов Ярославля , Пер
# гатой скот , лошадей , хлебе , смолу , горячее вино и прочее ; привозят также сюда для продажи жителям Крымскую соль . ГЛИНСК , слобод
# ства . В нем каждонедельно бывает по середам торг , на которой привозят крестьяне хлеб и пеньку . ГОРИЦЫ , село Тверского Наместничест
# В оном торжки бывают по вся недели по воскресным дням ; товары привозят из уезду холсты льняные разные , да из городов Ярославля , Пер
#  здника успения Пресвятые Богородицы дней за пять , на которую привозят холст и прочие мелочные Российские товары . ГОРОШИН , местечко
# зде . Здесь бывает ярмарка Апреля 23 дня , на кокоторую товары привозят из Каширы , из Тулы , Серпухова , Венева и Зарайска по малому
# ийских городов с шелковыми , бумажными и шерстяными товарами , привозят также с собою и другие лавочные . ДЕЙМАНОВКА , село Черниговск
# 9 Июня , то есть в день Св . Апостолов Петра и Павла ; на оную привозят соленую и сушеную рыбу с Чудского озера Российские рыбаки ; та
# ссийские рыбаки ; также иногда и из ближних Российских городов привозят купцы всякие железные товары и горшки глиняные ; третия бывает
# жаются не более как по одному , или по два Дни . Купцы на оные привозят мелочные товары . ДОМНИЦКОЙ , монастырь Черниговского Наместни
# ранском уезде . Здесь бывает ярмарка в последних числах Июля ; привозят купцы разные мелочные шелковые товары . ДУБРОВНА , местечко Мо
# тва . Здесь бывают каждонедельно в субботу торжки , на которые привозят съестные припасы и мелочные товары сторонние люди и Елатомские
# огатой скот , лошадей , хлеб , смолу , горячее вино и прочее ; привозят также сюда для лродажи жителям Крымскую соль . ЗОЛОЧЕВ , город
#  в Саранском уезде . Здесь бывает годовая ярмарка Июля 8 Дня ; привозят купцы разные мелочные шелковые товары . ИВАНОВКА , слобода Хар
# ь бывают торжки каждонедельно в пятничные дни ; товары на оные привозят из уезда холсты льняные разные , да из городов Ярославля , Пер
# го торгу ; бывает ярмарка Августа 1 дня , купцы на оную товары привозят шелковые и прочие мелочные . ИСЕТСКАЯ , слобода уфимского Наме
# ателей ; вторая после Святой недели в десятую пятницу . Товары привозят на оные из уезду холсты льняные разные , да из города Ярославл
# уезде . Здесь бывает по вся недели торг в понедельник ; товары привозят из уезду холсты льняные разные , да из городов Ярославля , Пер
# упцы из Москвы , Ярославля , Костромы , Нижнего Новагорода , и привозят на продажу сукна , разные шелковые материи , серебреную и олов
#  бывает каждую неделю по вторникам торг , на которой крестьяне привозят всякие съестные припасы , также дрова и деготь . КОБЫЗЧА , мес
#  лавочными мелочными товарами из Нежина и местечка Барышевки ; привозят сукна , такожь торгуют горячим вином , дегтем , рыбою , солью
# е , Романовские и Вологодские купцы бывают , из коих некоторые привозят шелковые , гарусные , бумажные , москотильные и прочие товары
# Кашинском уезде . Здесь бывает ярмарка Августа 15 дня ; товары привозят из уезду холсты льняные разные , да из городов Ярославля , Пер
# кое множество всяких Российских , Немецких и Азиатских товаров привозят ; также и лошадьми великой торг производится . КОРОВАЙ , село
# году одна ярмарка Июля 8 числа , в день Казанския Богородицы ; привозят на оную малое число шелковых и бумажных товаров , а более крес
# ду и пяток ; приезжает на оные по большей части крестьянство ; привозят из окрестных мест холст , пряжу , хлеб и прочие крестьянские т
# ая Сентября 8 . Купцы приезжают из разных Российских городов , привозят парчи , шелковые товары , позументы , сетки , серебро в посуде
# огатой скот , дашадей , хлеб , смолу , горячее вино и прочее ; привозят также сюда для продажи жителям Крымскую соль . КРАСНОБОРСК , г
# ря 21 ; приезжают на оные купцы из разных Российских городов ; привозят шелковые и прочие товары , позументы , серебро в посуде и проч
# бывает годовая Никольская ярмарка Декабря в 5 день ; крестьяне привозят и продают свиное сало , масло коровье , гусей , кожи сырые и о
# огатой скот , лошадей , хлеб , смолу , горячее вино и прочее ; привозят также сюда для продажи жителям Крымскую соль . КРЮКОВ , слобод
#  в Зарайском уезде . Здесь бывает годовая ярмарка Июля 8 Дня ; привозят на оную купцы разные мелочные шелковые товары . ЛАДИНСКОЙ , де
# 8 , третия Марта 25 , четвертая Июня в первых числах ; на оные привозят устюжские купцы разные мелочные товары ; а крестьянство сукна
# подня , Живоначальные Троицы и Покрова Богородицы , на которые привозят товары из разных городов , Российские купцы сукна , шелковые и
#  бывает торг одиножды в неделе по воскресным дням , на которые привозят разных уездов и деревень крестьяне разные товары домовой своей
# а и по три дни , на которые Курские , Севские и Рыльские купцы привозят сукна , шелковые разные материи и мелкия вещи ; также довольно
# главную часть сего торгу составляют окрестные жители , которые привозят съестные припасы и деревенския изделья . МАЛЫКОВА , местечко П
# а оные приезжают купцы из ближних Великороссийских городов , и привозят всякие внутренние мелкие товары , торгуют также скотом и лошад
# ства в Каширском уезде . В оном бывает ярмарка Июля 20 . Купцы привозят товары на продажу из Каширы , Гуды , Серпухова , Венева и Зара
# цу по Пасхе бывает ярмарка , на которую пригоняют скот , также привозят вялую рыбу , холст , шелковые материи , сукна , деготь и горяч
# жедневные отправляются торги , на которые в немалом количестве привозят всякого рода хлебъ . МОСАЛЬСК , город Калужского Наместничеств
# луги и Мещовска , также из Болхова , Белева и других городов ; привозят товары мэскотильные , то есть несколько бумажных шелковых и др
# и других сортов материи , а по большей части уездные крестьяне привозят разные уездные товары , всякой хлеб , пеньку , масло , мед , в
# динадцатой пятниц бывают ярмарки , на которые товары в продажу привозят из Каширы , Тулы , Серпухова , Венева и Зарайска по малому чис
#  и Июля 24 чисел ; да сверх того в каждой неделе в понедельник привозят холст , пряжу льняную , китайку , кумачи , выбойки и прочие ме
# ая Декабря б чисел ; на оные большею частию деревенские жители привозят хлеб , конопляное масло и тому подобное . ОБРУБ , село Тверско
# марка во время десятой и одинадцатой пятниц ; товары в продажу привозят из Каширы , Тулы , Серпухова , Венева , и Зарайска по малому ч
# 6 . Приезжают на оные Российские и иностранные купцы и Греки ; привозят парчи и прочия шелковые материи , сукна , серебреную и фарфоро
# а Октября 26 дня , на которую приезжающие разных городов купцы привозят сукна , шелк и всякие для поселян нужные товары , а жители про
# ярмарка сверх обыкновенных торгов в десятую пятницу по Пасхе ; привозят на продажу хдеб , пеньку , хмель и прочее . ПЕРЕСЛАВЛЬ ЗАЛЕСКО
# , так и приезжими из разных городов купцами . Московские купцы привозят разные мелкие серебреные товары , как - то оклады на образа и
# товары , как - то оклады на образа и прочее ; болеежь крестяне привозят разный хлеб на продажу ; а в уезде сего города в трех селах то
# ают ярмарки Петровская и Покровская в год по единожды ; товары привозят москотильные и прочие мелочные . ПЛОСКОЕ , село Тульского Наме
# тво из Калуги , Мещовска , Волхова , Белева и других городов ; привозят товары москотильные , несколько бумажных , шелковых и других с
# ки бывают еженедельные торжки , на которые из уездов обыватели привозят всякой хлеб и прочие сырейные и съестные товары . ПОТОК , мест
# аранском уезде . Бывает здесь ярмарка в последних числах юля ; привозят купцы разные мелочные шелковые товары . ПОЧИНКИ , город Нижего
# икого поста в неделю православия , другая Июня 29 дня ; товары привозят разные москотильные , шелковые , позументы золотые и серебрены
#  и торгуют в деревянном особливом гостином дворе ; а крестьяне привозят произрастания и рукоделия свои . РЫЖКОВО , село Калужского Нам
# Калуги , Мещовска , Орла , Волхова , Белева и других городов ; привозят товары москательные , бумажные , шелковые и другия материи ; а
# лковые и другия материи ; а по большей части уездные крестьяне привозят разные товары , всякой хлеб , пеньку , масло , мед , воск , во
# е , как по одному дню . Купцы приезжают из ближних городов , и привозят шелковые , бумажные , москательные и прочие товары не по больш

# %%
re.findall("\s+[с]\s+(?:[А-Яа-я,]+\s+)+товарами",fulltext)
# Out:
# [' с мелочными товарами',
#  ' с шелковыми и бумажными товарами',
#  ' с шелковыми, бумажными, гарусными и прочими товарами',
#  ' с шелковыми , бумажными, шерстяными и прочими товарами',
#  ' с шелковыми , бумажными , гарусными и прочими товарами',
#  ' с мелочными всякими небогатыми товарами',
#  ' с шелковыми, бумажными, шерстяными и прочими товарами',
#  ' с красныни и другими мелочными товарами',
#  ' с разными мелочными товарами',
#  ' с разными шелковыми мелочными товарами',
#  ' с такимижь товарами',
#  ' с красными товарами',
#  ' с разными товарами',
#  ' с разными мелочными товарами',
#  ' с разными москотильными товарами',
#  ' с разными товарами',
#  ' с разными мелочными товарами',
#  ' с мелочными всякими небогатыми товарами',
#  ' с мелочными товарами',
#  ' с хлебом, с рогатою и мелкою скотиною , съестными припасами и прочими мелочными товарами',
#  ' с шелковыми , бумажными, шерстяными и прочими товарами',
#  ' с шелковыми , бумажными и другими разными мелочными товарами',
#  ' с мелочными товарами',
#  ' с мелочными шелковыми и прочими товарами',
#  ' с уездными обывателями разными мелочными товарами',
#  ' с мелочными товарами',
#  ' с шелковыми и другими мелкими товарами',
#  ' с разными мелочными товарами',
#  ' с уездными обывателями всякими разными мелочными товарами',
#  ' с шелковыми, бумажными, москотильными и прочими товарами',
#  ' с сукнами и разными шелковыми и мелочными товарами',
#  '\r\n\r\n \r\n\r\n\r\n\r\nс шелковыми , бумажными и другими медочными товарами',
#  ' с шелковыми , бумажными , гарусными и прочими товарами',
#  ' с уездными обывателями всякими разными мелочными товарами',
#  ' с лавочными товарами',
#  ' с шелковыми , бумажными , москотильными и прочими товарами',
#  ' с Цареградскими Греками и другими торгуют Европейскими и Азиатскими товарами',
#  ' с красными товарами',
#  ' с медочными товарами',
#  ' с разными мелочными товарами',
#  ' с шелковыми , бумажными , гарусными и прочими товарами',
#  ' с недорогими товарами',
#  ' с разными мелочными товарами',
#  ' с недорогими товарами',
#  ' с мелочными товарами',
#  ' с разными товарами',
#  ' с мелкими товарами',
#  ' с шелковыми , щепетинными , серебряными и прочими товарами',
#  ' с шелковыми, бумажными, гарусными и прочими товарами',
#  ' с мелочными товарами',
#  ' с красными , крамными и прочими товарами',
#  ' с красными, крамными и прочими товарами',
#  ' с шелковыми и прочими товарами',
#  ' с недорогими товарами',
#  ' с Персианами, Армянами, Индейцами и прочими, разными Европейскими и Азиатскими товарами',
#  ' с шелковыми , бумажными, гарусными и прочими товарами',
#  ' с мелочными лавочными шелковыми , бумажными и прочими товарами',
#  ' с шелковыми, шерстяными и прочими товарами',
#  ' с холстами и прочими крестьянскими товарами',
#  ' с шелковыми, бумажными и другими товарами',
#  ' с различными товарами',
#  ' с разными мелочными товарами',
#  ' с мелочными лавочными товарами',
#  ' с разными товарами',
#  ' с щепетильными мелкими товарами',
#  ' с суровскими товарами',
#  ' с два, на которую и иностранные купцы приезжают с товарами',
#  ' с разными крестьянскими и щепетильными мелкими товарами',
#  ' с разными мелочными товарами',
#  ' с мелрчными купецкими товарами',
#  ' с красными крамными и прочими товарами',
#  ' с разными мелочными товарами',
#  ' с мелкими на продажу крестьянам товарами',
#  ' с разными мелочньми товарами',
#  ' с мелочными всякими небогатыми товарами',
#  ' с красными товарами',
#  ' с лавочными товарами',
#  ' с разными мелочными для крестьянства товарами',
#  ' с шелковыми , бумажными и шерстяными товарами',
#  ' с разными товарами',
#  ' с шелковыми и прочими товарами',
#  ' с разными товарами',
#  ' с разными мелочными товарами',
#  ' с разными товарами',
#  ' с разными мелочными товарами',
#  ' с шелковыми и бумажными товарами',
#  ' с мелочными товарами',
#  ' с разными товарами',
#  ' с мелочными для крестьянства товарами',
#  ' с разными товарами',
#  ' с разными мелочными товарами',
#  ' с разными товарами',
#  ' с разными не в знатном числе товарами',
#  ' с мелочными на продажу крестьянам товарами',
#  ' с разными товарами',
#  ' с шелковыми, бумажными и москотильными товарами',
#  ' с разными мелочными товарами',
#  ' с шелковыми , шерстяными , бумажными и прочими товарами',
#  ' с красными крамными и прочими товарами',
#  ' с разными мелочными товарами',
#  ' с разными товарами',
#  ' с шелковыми , бумажными , шерстяными и прочими товарами',
#  ' с мелочными всякими небогатыми товарами',
#  ' с недорогими товарами',
#  ' с шелковыми , бумажными и црочими мелочными товарами',
#  ' с разными мелочными товарами',
#  ' с шелковыми , бумажными , шерстяными товарами',
#  ' с разными мелочными товарами',
#  ' с мелочными всякими небогатыми товарами',
#  ' с разными мелочными товарами',
#  ' с мелочными товарами',
#  ' с Российскими и иностранными товарами',
#  ' \r\n\r\n \r\n\r\n\r\n\r\nс мелочными шелковыми и бумажными товарами',
#  ' с мелочными товарами',
#  ' с лавочными мелочными товарами',
#  ' с разными товарами',
#  ' с мелкими для крестьян товарами',
#  ' с мелочными всякими небогатыми товарами',
#  ' с разными мелочными товарами',
#  ' с красными крамными и прочими товарами',
#  ' с мълочными товарами',
#  ' с шелковыми товарами',
#  ' с мелочными товарами',
#  ' с шелковыми, бумажными , москотильными и прочими разными в небольшем числе товарами',
#  ' с какими товарами',
#  ' с шелковыми , бумажными , шерстяными и прочими товарами',
#  ' с разными мелкими шелковыми товарами',
#  ' с лавочными товарами',
#  ' с разными товарами',
#  ' с шелковыми и про чими мелочными товарами',
#  ' с шелковыми, бумажными , шерстяными и прочими товарами',
#  ' с шелковыми , бумажными , шерстяными и прочими товарами',
#  ' с разными мелочными товарами',
#  ' с мелочными товарами',
#  ' с шелковыми, бумажными и прочими мелочными товарами',
#  ' с шелковыми и бумажными платками , китайками , выбойками, чаем, сахаром, кофием и разными москотильными товарами',
#  ' с мелочными товарами',
#  ' с шелковыми, бумажными, шерстяными и прочими товарами',
#  ' с шелковыми, бумажными и москотильными ниских цен товарами',
#  ' с мелочными товарами',
#  ' с лавочными товарами',
#  ' с разными товарами',
#  ' с разными товарами',
#  ' с разными мелочными товарами',
#  ' с разными шелковыми и прочими мелочными товарами',
#  ' с мелочными товарами',
#  ' с мелочными товарами',
#  ' с разными мелочными товарами',
#  ' с разными мелочными москотильными и красными товарами',
#  ' с мелочными шелковыми , бумажными и прочими разными товарами',
#  ' с шелковыми , бумажными , шерстяными и прочими товарами',
#  ' с их товарами',
#  ' с бумажными , шелковыми и прочими в небольшем числе товарами',
#  ' с мелочными товарами',
#  ' с мелочными товарами',
#  ' с лавочными мелочмыми товарами',
#  ' с красными, крамными, суконными и прочими товарами',
#  ' с уездными обывателями всякими разными мелочными товарами',
#  ' с разными шелковыми мелочными и прочими товарами',
#  ' с шелковыми, бумажными , гарусными и прочими товарами',
#  ' с шелковыми и другими мелочными товарами',
#  ' с разными товарами',
#  ' с мелочными шелковыми товарами',
#  ' с разными товарами',
#  ' с лавочными товарами',
#  ' с мелочными товарами',
#  ' с шелковыми , бумажными , гарусными и прочими товарами',
#  ' с разными товарами',
#  ' с какими товарами',
#  ' с мелочными товарами',
#  ' с шелковыми, бумажными , гарусными , серебреными , медными , оловянными, галантерейными и прочими товарами',
#  ' с красными и другими мелочными товарами',
#  ' с разными Российскими и Немецкими товарами, мягкою рухлядью и прочим из Ярославля, из Переяславля Залеского, Москвы и из Вологды с разными суровски ми шелковыми товарами, а из Ярославля и с серебреными да из города Кинешмы с об розами, из слобод Макарья и Пуреха с деревянною посудою , из Муромского и Касимовского уездов с ободами, из Пошехонского и устюжского уездов с дельным железом , то есть с котлами, сковородами, гвоздями, замками, укладом и с другими железными товарами',
#  ' с разными товарами',
#  ' с мелкими товарами']

# %%
re.findall("[А-Яа-я,]+\s+(?:приезжают|привозят)\s+[А-Яа-я,]+",fulltext)
# Out:
# ['которую приезжают купцы',
#  'сюда приезжают из',
#  'оные приезжают купцы',
#  'сего приезжают Российские',
#  'и привозят с',
#  'товары привозят на',
#  'которую привозят из',
#  'ярмарку приезжают со',
#  'торгу приезжают купцы',
#  'оные привозят из',
#  'Углича приезжают купцы',
#  'крестьяне привозят разные',
#  'купцы приезжают на',
#  'товары привозят из',
#  'Купцы приезжают на',
#  'а приезжают в',
#  'иногда приезжают и',
#  'съезды приезжают окольные',
#  'которую приезжают купцы',
#  'товары привозят купцы',
#  'купцы приезжают из',
#  'оные приезжают с',
#  'оные приезжают из',
#  'которую приезжают купцы',
#  'которые приезжают купцы',
#  'ярмарку приезжают со',
#  'оную приезжают купцы',
#  'товары привозят из',
#  'Углича приезжают купцы',
#  'купцы приезжают из',
#  'ярмарку приезжают со',
#  'которую приезжают купцы',
#  'оную приезжают купцы',
#  'числе приезжают и',
#  'Купцы приезжают из',
#  'оные приезжают купцы',
#  'оные приезжают купцы',
#  'которую приезжают из',
#  'Иногда приезжают и',
#  'оные приезжают купцы',
#  'купцы, привозят хлеб,',
#  'которую приезжают купцы',
#  'оные приезжают из',
#  'ярмарку приезжают со',
#  'Иногда приезжают и',
#  'которую приезжают купцы',
#  'купцы приезжают из',
#  'которую привозят холст',
#  'обыватели привозят всякой',
#  'Иногда приезжают и',
#  'Иногда приезжают и',
#  'купцы приезжают с',
#  'купцы приезжают на',
#  'купцы приезжают из',
#  'Купцы приезжают из',
#  'купцы приезжают из',
#  'купцы приезжают из',
#  'Сюда приезжают купцы',
#  'оную приезжают купцы',
#  'и привозят по',
#  'которую приезжают со',
#  'оные приезжают купцы',
#  'Купцы приезжают на',
#  'обыватели привозят всякой',
#  'Иногда приезжают и',
#  'кои приезжают купцы',
#  'купцы приезжают с',
#  'Сюда приезжают крестьяне',
#  'товары привозят хлеб',
#  'Купцы приезжают на',
#  'Купцы приезжают из',
#  'ярмарку приезжают со',
#  'купцы приезжают на',
#  'оную приезжают купцы',
#  'которой приезжают купцы',
#  'иногда приезжают и',
#  'Сюда приезжают купцы',
#  'купцы приезжают из',
#  'городов, привозят парчи',
#  'которые приезжают купцы',
#  'крестьяне привозят более',
#  'также привозят сюда',
#  'особливо привозят много',
#  'Сюда приезжают Тобольские',
#  'купцы приезжают на',
#  'Иногда приезжают и',
#  'Купцы приезжают на',
#  'Донкова привозят мелочные',
#  'крестьяне привозят разные',
#  'Купцы приезжают из',
#  'и привозят на',
#  'кои приезжают купцы',
#  'оные приезжают купцы',
#  'оные приезжают купцы',
#  'городов привозят товары',
#  'крестьяне привозят разные',
#  'торгов приезжают из',
#  'оные приезжают купцы',
#  'Также привозят сюда',
#  'торги приезжают из',
#  'также привозят мя',
#  'сюда приезжают из',
#  'иногда приезжают и',
#  'оные приезжают купцы',
#  'которую приезжают с',
#  'оную приезжают купцы',
#  'купцы приезжают с',
#  'которую приезжают из',
#  'ярмарку приезжают Архангельские',
#  'что привозят с',
#  'Купцы приезжают на',
#  'только привозят мелочные',
#  'которую приезжают из',
#  'оные приезжают Торопецкие',
#  'крестьяне привозят по',
#  'которую привозят из',
#  'оные приезжают купцы',
#  'Купцы приезжают на',
#  'оные приезжают из',
#  'купцы приезжают для',
#  'люди приезжают из',
#  'купцы приезжают из',
#  'оные приезжают купцы',
#  'иногда приезжают и',
#  'которой привозят крестьяне',
#  'товары привозят из',
#  'Углича приезжают купцы',
#  'иногда приезжают и',
#  'торжки приезжают окольные',
#  'также приезжают из',
#  'которую привозят холст',
#  'оные приезжают купцы',
#  'товары привозят из',
#  'оную приезжают купцы',
#  'Купцы приезжают на',
#  ', привозят также',
#  'которую приезжают множество',
#  'оную привозят соленую',
#  'городов привозят купцы',
#  'товарами приезжают из',
#  'купцы приезжают с',
#  'оные привозят мелочные',
#  'купцы приезжают из',
#  'куда приезжают купцы',
#  'Сюда приезжают купцы',
#  'купцы приезжают из',
#  'которую приезжают жители',
#  'оные приезжают с',
#  'которые привозят съестные',
#  'оную приезжают из',
#  'купцы приезжают из',
#  'Купцы приезжают из',
#  'люди приезжают из',
#  'которую приезжают из',
#  'обыватели приезжают с',
#  'Каширы приезжают купцы',
#  'купцы приезжают из',
#  'оные приезжают разных',
#  'Купцы приезжают на',
#  'Купцы приезжают на',
#  'купцы приезжают из',
#  'купцы приезжают с',
#  'купцы приезжают из',
#  'оные привозят из',
#  'Углича приезжают купцы',
#  'которую приезжают купцы',
#  'товары привозят шелковые',
#  'которую приезжают купцы',
#  'купцы приезжают из',
#  'Товары привозят на',
#  'купцы приезжают с',
#  'оные приезжают \r\n\r\n \r\n\r\n\r\n\r\nКадомонские',
#  'обыватели приезжают сюда',
#  'товары привозят из',
#  'ярмарку приезжают купцы',
#  'и привозят на',
#  'которые приезжают из',
#  'Сюда приезжают разных',
#  'оную приезжают из',
#  'которую приезжают со',
#  'крестьяне привозят всякие',
#  'Сюда приезжают иногородные',
#  'которую приезжают купцы',
#  'некоторые привозят шелковые,',
#  'товары привозят из',
#  'купцы приезжают с',
#  'ярмарки приезжают Великороссийские',
#  'Купцы приезжают из',
#  ', привозят парчи,',
#  'Купцы приезжают на',
#  'Сюда приезжают окрестных',
#  'Купцы приезжают из',
#  'частию приезжают крестьяне',
#  'крестьяне привозят и',
#  'купцы приезжают из',
#  'купцы приезжают с',
#  'оные привозят устюжские',
#  'оную приезжают Нейшлотского',
#  'оные приезжают из',
#  'которые привозят товары',
#  'Купцы приезжают на',
#  'которые привозят разных',
#  'купцы приезжают на',
#  'которой приезжают крестьяне',
#  'купцы привозят сукна',
#  'оную приезжают окрестные',
#  'сюда приезжают по',
#  'купцы приезжают из',
#  'которые приезжают купцы',
#  'которые привозят съестные',
#  'купцы приезжают из',
#  'оную приезжают купцы',
#  'Купцы приезжают на',
#  'купцы приезжают из',
#  'которую приезжают купцы',
#  'оную приезжают из',
#  'Купцы приезжают из',
#  'иногда приезжают и',
#  'оные приезжают купцы',
#  'и привозят всякие',
#  'Купцы привозят товары',
#  'также привозят вялую',
#  'оные приезжают из',
#  'купцы приезжают с',
#  'городов приезжают купцы',
#  'купцы приезжают из',
#  'оную приезжают из',
#  'которые приезжают \r\n\r\n \r\n\r\n\r\n\r\nкупцы',
#  'количестве привозят всякого',
#  'крестьяне привозят разные',
#  'которые приезжают для',
#  'продажу привозят из',
#  'Кунцы приезжают на',
#  'понедельник привозят холст',
#  'оные приезжают купцы',
#  'жители привозят хлеб,',
#  'оную приезжают купцы',
#  'продажу привозят из',
#  'оные приезжают из',
#  'иногда приезжают и',
#  'иногда приезжают и',
#  'купцы приезжают из',
#  'купцы привозят сукна,',
#  'оные приезжают купцы',
#  'Купцы приезжают на',
#  'купцы привозят разные',
#  'крестяне привозят разный',
#  'купцы приезжают из',
#  'Сюда приезжают купцы',
#  'Купцы приезжают на',
#  'Купцы приезжают на',
#  'Купцы приезжают на',
#  'товары привозят москотильные',
#  'оные приезжают Великороссийские',
#  'купцы приезжают из',
#  'обыватели привозят всякой',
#  'Иногда приезжают и',
#  'вторую приезжают из',
#  'которые приезжают купцы',
#  'также приезжают из',
#  'которой приезжают купцы',
#  'которую приезжают купцы',
#  'оные приезжают из',
#  'кои приезжают из',
#  'товары привозят разные',
#  'купцы приезжают из',
#  'Сюда приезжают купцы',
#  'люди приезжают на',
#  'крестьяне привозят произрастания',
#  'крестьяне привозят разные',
#  'Купцы приезжают из',
#  'и привозят шелковые']

# %%
re.findall(r"из\s+[А-Яа-я,]+\s+[А-Яа-я,]+",fulltext)
# Out:
# ['из ближних городов',
#  'из достопамятных и',
#  'из разных Российских',
#  'из разных городов',
#  'из разных городов',
#  'из ближних селений',
#  'из Москвы и',
#  'из других городов',
#  'из разных Российских',
#  'из отдаленных местъ',
#  'из разных Российских',
#  'из уезду холсты',
#  'из городов Ярославля,',
#  'из разных Российских',
#  'из окольных мест',
#  'из Пскова с',
#  'из иных городов',
#  'из уездов крестьянские,',
#  'из окрестных городов,',
#  'из разных мест',
#  'из Новагорода и',
#  'из Старой Рузы',
#  'из уездов разных',
#  'из разных городов',
#  'из уезду жители',
#  'из Великороссийских городов',
#  'из ближних городов',
#  'из Новагорода и',
#  'из Торопца всякие',
#  'из ближних городов,',
#  'из близ лежащих',
#  'из ближайших городов',
#  'из ближних городовъ',
#  'из других соседственных',
#  'из близ лежащих',
#  'из Москвы и',
#  'из других городов',
#  'из близ лежащих',
#  'из уезду, холсты',
#  'из городов Ярославля,',
#  'из соседственных городов',
#  'из окрестных к',
#  'из Москвы, Ярославля,',
#  'из окрестных городов',
#  'из ближних селений',
#  'из Москвы и',
#  'из других городов',
#  'из разных Российских',
#  'из отдаленных местъ',
#  'из ближних городов',
#  'из разных городов',
#  'из окрестных ближних',
#  'из Калуги и',
#  'из Ирбитской ярмарки,',
#  'из окрестных городов',
#  'из ближних деревень',
#  'из разных Великороссийских',
#  'из Тамбова и',
#  'из разных Российских',
#  'из ближних городов',
#  'из уездных жителей',
#  'из Ярославля, Кашина',
#  'из уезду съезжается',
#  'из Углича, Кашина',
#  'из Воронежа, Ельца',
#  'из слободы Яропольца',
#  'из разных Росссийских',
#  'из Москвы и',
#  'из других городов',
#  'из Россия барок,',
#  'из за моря',
#  'из уезду жители',
#  'из уездов Устюжского,',
#  'из разных Российских',
#  'из Болхова и',
#  'из ближних городов',
#  'из уезду жители',
#  'из уезду жители',
#  'из разных Российских',
#  'из близ лежащих',
#  'из Пскова с',
#  'из Великой Бухарии,',
#  'из близ лежащих',
#  'из Старой Рузы',
#  'из разных Российских',
#  'из ближних городов',
#  'из Великороссийских и',
#  'из других городов',
#  'из уездов товарами,',
#  'из Москвы и',
#  'из других городов',
#  'из близ лежащих',
#  'из разных Российских',
#  'из уездов обыватели',
#  'из уезду жители',
#  'из разных мест',
#  'из чужих краев',
#  'из гумми разных',
#  'из близ лежащих',
#  'из Донских станиц',
#  'из близ лежащих',
#  'из Москвы и',
#  'из других городов',
#  'из разных городов',
#  'из разных городов',
#  'из близ лежащих',
#  'из уезду, воском,',
#  'из Устюга Великого,',
#  'из уездов жители',
#  'из Низовых же',
#  'из раз ных',
#  'из разных городов',
#  'из Донских станиц',
#  'из Донских станиц',
#  'из ближних мест',
#  'из окольных мест',
#  'из окрестных городов',
#  'из Каширы, а',
#  'из Тулы ,',
#  'из всех торговых',
#  'из соседних Провинций',
#  'из Каширы ,',
#  'из Тулы, Серпухова,',
#  'из уезду жители',
#  'из разных Российских',
#  'из городов Тулы',
#  'из уездов крестьяне',
#  'из разных городов',
#  'из окрестных ближних',
#  'из Вереи ,',
#  'из ближних городов',
#  'из разных окольных',
#  'из окольных тамошних',
#  'из других городов',
#  'из Тулы, Калуги,',
#  'из разных Российских',
#  'из Калуги ,',
#  'из города Свинская,',
#  'из окрестных городов',
#  'из близ лежащих',
#  'из Донских станиц',
#  'из смежных городов',
#  'из прочих городов',
#  'из близ лежащих',
#  'из разных Российских',
#  'из уезду жители',
#  'из окрестных городов',
#  'из Ярославля ,',
#  'из Переславля Залеского',
#  'из Тулы ,',
#  'из ближних сел',
#  'из Москвы ,',
#  'из разных привозимых',
#  'из Иркутска и',
#  'из разных мест',
#  'из разных городов',
#  'из рубежа Кеврольского',
#  'из соседственных городов',
#  'из лежащих городов',
#  'из окольных мест',
#  'из разных мест',
#  'из уезду холсты',
#  'из городов Ярославля',
#  'из городов Вереи,',
#  'из разных городов',
#  'из близ лежащих',
#  'из Донских станице',
#  'из близ лежащих',
#  'из Ярославля, Романова,',
#  'из Пскова с',
#  'из окольных городов',
#  'из уезду жители',
#  'из уезду холсты',
#  'из городов Ярославля,',
#  'из уездов жители',
#  'из городов и',
#  'из ближних городов',
#  'из Каширы, а',
#  'из Каширы ,',
#  'из Тулы, Серпухова,',
#  'из близ лежащих',
#  'из разных Российских',
#  'из близ лежащих',
#  'из Риги и',
#  'из уезда много',
#  'из ближних Российских',
#  'из разных ближиих',
#  'из Москвы \r\n\r\n \r\n\r\n\r\n\r\nиз',
#  'из Катина и',
#  'из смежных мест',
#  'из ближних город',
#  'из Пскова с',
#  'из лежащих городов',
#  'из окрестных городов',
#  'из разных городов',
#  'из близ лежащих',
#  'из ближних городов',
#  'из которых в',
#  'из Коломны разной',
#  'из разных деревень',
#  'из Пскова с',
#  'из близ лежащих',
#  'из Тобольска и',
#  'из Иркутска, из',
#  'из окрестных городов',
#  'из Ярославля, Романова,',
#  'из Борисоглебска, из',
#  'из разных сел',
#  'из окрестных городов',
#  'из окольных городов',
#  'из Тулы, Венева',
#  'из ближних городов',
#  'из разных месте',
#  'из разных Российских',
#  'из близ лежащих',
#  'из Донских станиц',
#  'из Нежина, Борзны',
#  'из Каширы, Тулы,',
#  'из Зарайска по',
#  'из Каширы, и',
#  'из Тулы, Серпухова,',
#  'из Зарайска по',
#  'из города Малого',
#  'из Малого Ярославца',
#  'из Боровскаа, торгуют',
#  'из ближних \r\n\r\n \r\n\r\n\r\n\r\nгородов,',
#  'из Каширы, Тулы',
#  'из Зарайска по',
#  'из разных городов',
#  'из уезда холсты',
#  'из городов Ярославля,',
#  'из близ лежащих',
#  'из досок ,',
#  'из ближних городов',
#  'из разных Российских',
#  'из окольных мест',
#  'из Сибири и',
#  'из Россия ,',
#  'из Казани чрез',
#  'из Казани в',
#  'из уезду холсты',
#  'из города Ярославля',
#  'из прочих городов',
#  'из уезду холсты',
#  'из городов Ярославля',
#  'из Москвы, Ярославля,',
#  'из ближайших городов',
#  'из других уездов,',
#  'из некоторых окрестных',
#  'из Москвы и',
#  'из других городов',
#  'из близ лежащих',
#  'из разных городов',
#  'из ближних Малороссийских',
#  'из Нежина и',
#  'из приезжих купцов',
#  'из Каширы, Тулы,',
#  'из здешнего и',
#  'из Алексина с',
#  'из коих некоторые',
#  'из Вологодского, Галицкого,',
#  'из окольных разных',
#  'из уезду холсты',
#  'из городов Ярославля,',
#  'из разных Росссийских',
#  'из окрестных мест',
#  'из разных Российских',
#  'из близ лежащих',
#  'из Донских станиц',
#  'из разных Российских',
#  'из разных Российских',
#  'из близ лежащих',
#  'из ближних городов',
#  'из них бывает',
#  'из Донских станиц',
#  'из Сибири купцы',
#  'из разных городов',
#  'из кирок Чухны',
#  'из близ лежащих',
#  'из разных городов,',
#  'из разных городов',
#  'из окрестных городов',
#  'из разных Российских',
#  'из ближних городов',
#  'из Российских и',
#  'из Великороссийских и',
#  'из уездов товарами',
#  'из окольных мест',
#  'из ближних городов',
#  'из окрестных селений',
#  'из блИз лежащих',
#  'из всех стран',
#  'из Боровска, Вереи',
#  'из ближних городов',
#  'из разных Российских',
#  'из соседственных мест',
#  'из разных Российских',
#  'из разных городов',
#  'из городов купцы',
#  'из разных городов',
#  'из окрестных городов',
#  'из уезду жители',
#  'из ближних Великороссийских',
#  'из Каширы ,',
#  'из ближних городов',
#  'из близ лежащих',
#  'из Пскова с',
#  'из ближних к',
#  'из Тулы ,',
#  'из Калуги и',
#  'из Болхова, Белева',
#  'из других городов',
#  'из ближних городов,',
#  'из Ярославля, Ростова',
#  'из Каширы ,',
#  'из близ лежащих',
#  'из окрестных городов',
#  'из Великороссийских и',
#  'из соседственных городов',
#  'из окрестных ближних',
#  'из Каширы, Тулы,',
#  'из разных городов',
#  'из уезду жители',
#  'из окрестных городов,',
#  'из уезду жители',
#  'из Пскова с',
#  'из близ лежащих',
#  'из разных городов',
#  'из близ лежащих',
#  'из уездов обыватели',
#  'из разных городов',
#  'из близ лежащих',
#  'из близ лежащих',
#  'из соседственных городов',
#  'из разных городов',
#  'из Великороссийских \r\n\r\n \r\n\r\n\r\n\r\nгородов',
#  'из близ лежащих',
#  'из Калуги, Мещовска,',
#  'из Польши ,',
#  'из всей Турецкой',
#  'из ближних городов',
#  'из близ лежащих',
#  'из уездов обыватели',
#  'из уезду жители',
#  'из ближних городов',
#  'из прикосновенных городов',
#  'из Великороссийских и',
#  'из соседних городов',
#  'из разных Российских',
#  'из разных городов',
#  'из ближних городов',
#  'из уездов крестьяне',
#  'из уездов товара',
#  'из Германии и',
#  'из соседственных стран',
#  'из которого те',
#  'из окрестных городов',
#  'из Ярославля с',
#  'из окольных мест',
#  'из Ярославля, из',
#  'из Вологды с',
#  'из Ярославля и',
#  'из города Кинешмы',
#  'из слобод Макарья',
#  'из Муромского и',
#  'из Пошехонского и',
#  'из близъ\r\n\r\n \r\n\r\n\r\n\r\nлежащих',
#  'из Ярославля, Романова,',
#  'из сел с',
#  'из разных городовъ',
#  'из окрестных городов',
#  'из окольных мест',
#  'из ближних городов,']

# %%
re.findall(r"из\s+((?:(?!из)[А-Яа-я,]+\s+)*)купцы",fulltext)
# Out:
# ['разных городов и уездов  ',
#  'разных городов ',
#  'других городов ',
#  'городов Ярославля, Переславля Залеского, Углича приезжают ',
#  'окольных мест ',
#  'Старой Рузы ',
#  'Великороссийских городов ',
#  'других городов ',
#  'городов Ярославля, Переславля Залеского , Углича приезжают ',
#  'других городов ',
#  'разных Великороссийских городов ',
#  'Углича, Кашина и Бежецка ',
#  'других городов ',
#  'Великороссийских и Малороссийских городов ',
#  'других городов ',
#  'разных мест сбираются ',
#  'других городов ',
#  'разных городов наплывают  сверху Лены реки со всякими товарами ',
#  'окрестных городов ',
#  'разных городов ',
#  'ближних городов ',
#  'разных окольных городов ',
#  'разных Российских городов ',
#  'разных городов ',
#  'городов Ярославля, Переславля Залеского и Углича приезжают ',
#  'близ лежащих мест ',
#  'ближних Российских городов привозят ',
#  'окольных городов ',
#  'Тулы, Венева и Каширы приезжают ',
#  'городов Ярославля, Переславля Залесного и Углича приезжают ',
#  'города Ярославля , Переславля Залеского и Углича ',
#  'других городов ',
#  'городов Ярославля, Переславля Залеского и Углича ',
#  'разных Росссийских городов ',
#  'Сибири ',
#  'разных городов, Российские ',
#  'разных городов ',
#  'ближних городов ',
#  'ближних городов ',
#  'соседственных мест ',
#  'городов ',
#  'разных городов ',
#  'соседственных городов ',
#  'всей Турецкой области ',
#  'ближних городов ',
#  'ближних городов ',
#  'Великороссийских и Малороссийских городов ',
#  'ближних городов ',
#  'окольных мест ']

# %%
trade_areas = list(set(re.findall(r"([А-Яа-я]+ские)",fulltext)))
trade_areas.sort()

# %%
re.findall(r"((?:[А-Яа-я]+[цс]кие\s*,\s*)*(?:[А-Яа-я]+[цс]кие)*(?:\s*и\s*)?(?:[А-Яа-я]+[цс]кие)) купцы",fulltext)\
# Out:
# ['Вологодские',
#  'Российские',
#  'Руские',
#  'Российские',
#  'Курские и Старооскольские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Московские, Устюжские и Тотемские',
#  'Российские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Российские',
#  'Тобольские',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Архангельские и Холмогорские',
#  'Торопецкие',
#  ' и Великороссийские',
#  ' и Великороссийские',
#  'Российские',
#  'Российские',
#  'Московские, Ярославские , Костромские , Любимские, Романовские и Вологодские',
#  'Великороссийские и Малороссийские',
#  'Великолуцкие, Торопецкие и Псковские',
#  'устюжские',
#  'Российские',
#  'Вологодские',
#  'Вологодские',
#  'Курские, Севские и Рыльские',
#  ' и Великороссийские',
#  'Муромские',
#  'Великороссийские и Малороссийские',
#  ' и Великороссийские',
#  'Азиатские',
#  ' и Великороссийские',
#  'Зарайские',
#  'Московские',
#  'Елецкие',
#  ' и Великороссийские']

# %%
re.findall(r"[А-Яа-я]+ские\s*,\s*",fulltext)
# Out:
# ['крестьянские, ',
#  'Российские, ',
#  'Вологодские, ',
#  'Московские, ',
#  'Российские, ',
#  'Китайские, ',
#  'Персидские, ',
#  'Кадомонские , ',
#  'Московские, ',
#  'Ярославские , ',
#  'Костромские , ',
#  'Любимские, ',
#  'Российские, ',
#  'Курские, ',
#  'Вологодские, ',
#  'Великороссийские , ',
#  'Великороссийские , ']

# %%
text.concordance("Алексина")
# Out:
# Displaying 4 of 4 matches:
# кого Наместничества в уезде города Алексина . В оном бывают яр марки Июля 8 ,
# кого Наместничества в 7 верстах от Алексина . Здесь бывает ярмарка Июля 8 числ
# ла , на которую приезжают купцы из Алексина с мелкими для крестьян товарами .
# кого Наместничества в уезде города Алексина . Здесь бывает ярмарка Маия 2 и Ию

# %%
re.findall(r"купцы из\s+(?:[а-яА-Я,]+\s+)*(?:городов|мест)",fulltext)
# Out:
# ['купцы из разных Российских городов',
#  'купцы из разных Российских городов',
#  'купцы из разных Российских городов',
#  'купцы из разных Российских городов',
#  'купцы из разных городов',
#  'купцы из ближних городов',
#  'купцы из ближних городов',
#  'купцы из близ лежащих городов',
#  'купцы из соседственных городов',
#  'купцы из Москвы, Ярославля, Суздаля, Шуи и других ближних мест',
#  'купцы из разных Российских городов',
#  'купцы из ближних городов',
#  'купцы из разных городов',
#  'купцы из окрестных ближних городов',
#  'купцы из разных Российских городов',
#  'купцы из разных Российских городов',
#  'купцы из разных Российских городов',
#  'купцы из ближних городов',
#  'купцы из близ лежащих городов',
#  'купцы из близ лежащих городов',
#  'купцы из разных городов',
#  'купцы из Тулы, Калуги, Серпухова и прочих городов',
#  'купцы из разных Российских городов',
#  'купцы из близ лежащих городов',
#  'купцы из смежных городов',
#  'купцы из окрестных городов',
#  'купцы из Москвы , Тулы , Калуги, Серпухова , Можайска , Боровска и прочих ближних городов',
#  'купцы из городов',
#  'купцы из окольных городов',
#  'купцы из ближних городов',
#  'купцы из близ лежащих Сибирских городов',
#  'купцы из окрестных городов',
#  'купцы из разных городов',
#  'купцы из ближних \r\n\r\n \r\n\r\n\r\n\r\nгородов',
#  'купцы из близ лежащих городов',
#  'купцы из некоторых окрестных городов',
#  'купцы из разных городов',
#  'купцы из разных Российских городов',
#  'купцы из разных Российских городов',
#  'купцы из близ лежащих городов',
#  'купцы из окрестных городов',
#  'купцы из Российских и Малороссийских городов',
#  'купцы из разных городов',
#  'купцы из ближних Великороссийских городов',
#  'купцы из ближних городов',
#  'купцы из ближних городов',
#  'купцы из Великороссийских и Малороссийских городов',
#  'купцы из окрестных ближних городов',
#  'купцы из окрестных городов',
#  'купцы из близ лежащих городов',
#  'купцы из разных городов',
#  'купцы из соседственных городов',
#  'купцы из прикосновенных городов',
#  'купцы из соседних городов',
#  'купцы из разных Российских городов',
#  'купцы из окрестных городов']

# %%
test = re.findall(r"купцы\s+из\s+((?:[а-яА-Я,]+\s+)*?)(?:с|;) ",fulltext)

# %%
test = [t.strip() for t in test]

# %%
test = [t for t in test if len(re.findall(r"(?:городов|части)$",t))==0]

# %%
len(test)
# Out:
# 7

# %%
test
# Out:
# ['Тамбова и Зарайска',
#  'Воронежа, Ельца и Липецка',
#  'Ярославля , Юрьева и из Переславля Залеского',
#  'городов Вереи, Можайска и Боровска , и множество сходится крестьянства',
#  'Алексина',
#  'Боровска, Вереи и Серпухова',
#  'прикосновенных городов , Ярославля , Романова , Углича и Вологды']

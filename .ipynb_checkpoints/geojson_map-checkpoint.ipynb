# %%
import pandas as pd
import numpy as np
import json

# %%
test_set = pd.DataFrame.from_csv("hgr_test_set.csv",index_col=None)

# %%
mydict = {}
def dictify(k,v):
    mydict.update({k:v})
    return {k:v}
np.vectorize(dictify)(test_set.uniq_id,test_set.partof_id)
# Out:
# array([{1: nan}, {2: nan}, {3: nan}, {4: nan}, {5: nan}, {6: nan},
#        {7: nan}, {8: nan}, {9: nan}, {10: nan}, {11: nan}, {12: nan},
#        {13: nan}, {14: nan}, {15: nan}, {16: nan}, {17: nan}, {18: nan},
#        {19: nan}, {20: nan}, {21: nan}, {22: nan}, {23: nan}, {24: nan},
#        {25: nan}, {26: nan}, {27: nan}, {28: nan}, {29: nan}, {30: nan},
#        {31: nan}, {32: nan}, {33: nan}, {34: nan}, {35: nan}, {36: nan},
#        {37: nan}, {38: nan}, {39: nan}, {40: 30.0}, {41: 35.0}, {42: 17.0},
#        {43: 37.0}, {44: 16.0}, {45: 33.0}, {46: 35.0}, {47: 16.0},
#        {48: 15.0}, {49: 18.0}, {50: 5.0}, {51: 25.0}, {52: 35.0},
#        {53: 1.0}, {54: 9.0}, {55: 4.0}, {56: 1.0}, {57: 6.0}, {58: 38.0},
#        {59: 3.0}, {60: 24.0}, {61: 1.0}, {62: 28.0}, {63: 8.0}, {64: 21.0},
#        {65: 35.0}, {66: 28.0}, {67: 1.0}, {68: 33.0}, {69: 37.0},
#        {71: 28.0}, {72: 33.0}, {73: 35.0}, {74: 22.0}, {75: 14.0},
#        {76: 9.0}, {77: 13.0}, {78: 16.0}, {79: 12.0}, {80: 32.0},
#        {81: 1.0}, {82: 15.0}, {83: 14.0}, {84: 22.0}, {85: 15.0},
#        {86: 32.0}, {87: 21.0}, {88: 13.0}, {89: 39.0}, {90: 2.0},
#        {91: 13.0}, {92: 37.0}, {93: 1.0}, {94: 16.0}, {95: 22.0},
#        {96: 22.0}, {98: 18.0}, {99: 19.0}, {100: 35.0}, {101: 38.0},
#        {102: 19.0}, {103: 16.0}, {104: 25.0}, {105: 13.0}, {106: 39.0},
#        {107: 38.0}, {108: 8.0}, {109: 24.0}, {110: 39.0}, {111: 38.0},
#        {112: 25.0}, {113: 16.0}, {114: 39.0}, {115: 1.0}, {116: 28.0},
#        {117: 22.0}, {118: 29.0}, {119: 11.0}, {120: 30.0}, {121: 19.0},
#        {122: 16.0}, {123: 19.0}, {124: 3.0}, {125: 33.0}, {126: 32.0},
#        {127: 35.0}, {128: 37.0}, {129: 36.0}, {130: 16.0}, {131: 38.0},
#        {132: 14.0}, {133: 32.0}, {134: 14.0}, {135: 4.0}, {136: 39.0},
#        {140: 35.0}, {141: 32.0}, {142: 2.0}, {143: 10.0}, {144: 117.0},
#        {145: 29.0}, {146: 37.0}, {147: 105.0}, {148: 102.0}, {149: 118.0},
#        {150: 11.0}, {151: 60.0}, {152: 77.0}, {153: 37.0}, {154: 1.0},
#        {155: 38.0}, {156: 32.0}, {157: 105.0}, {158: 8.0}, {159: 12.0},
#        {160: 1.0}, {161: 21.0}, {162: 65.0}, {163: nan}, {164: 56.0},
#        {165: 18.0}, {166: 37.0}, {167: 5.0}, {168: 111.0}, {169: 90.0},
#        {170: 50.0}, {171: 24.0}, {172: 27.0}, {173: 33.0}, {174: 27.0},
#        {175: 5.0}, {176: 102.0}, {177: 105.0}, {178: 25.0}, {179: 6.0},
#        {180: 20.0}, {181: 3.0}, {182: 38.0}, {183: 25.0}, {184: 8.0},
#        {185: 77.0}, {186: 13.0}, {187: 17.0}, {188: 3.0}, {189: 88.0},
#        {190: 46.0}, {191: 73.0}, {192: 41.0}, {193: 4.0}, {194: 60.0},
#        {195: 69.0}, {196: 111.0}, {197: 27.0}, {198: 1.0}, {199: 5.0},
#        {200: 123.0}, {201: 81.0}, {202: 32.0}, {203: 31.0}, {204: 35.0},
#        {205: 35.0}, {206: 9.0}, {207: 12.0}, {208: 100.0}, {209: 4.0},
#        {210: 28.0}, {211: 9.0}, {212: 1.0}, {213: 5.0}, {214: 121.0},
#        {215: 13.0}, {216: 33.0}, {217: 37.0}, {218: 29.0}, {219: 8.0},
#        {220: 32.0}, {221: 91.0}, {222: 33.0}, {223: 22.0}, {224: 125.0},
#        {225: 72.0}, {226: 14.0}, {227: 9.0}, {228: 123.0}, {229: 3.0},
#        {230: 13.0}, {231: 12.0}, {232: 1.0}, {233: 5.0}, {234: 30.0},
#        {235: 14.0}, {236: 43.0}, {237: 7.0}, {238: 95.0}, {239: 35.0},
#        {240: 105.0}, {241: 4.0}, {242: 37.0}, {243: 92.0}, {244: 22.0},
#        {245: 21.0}, {246: 8.0}, {247: 55.0}, {248: 29.0}, {249: 88.0},
#        {251: 78.0}, {252: 11.0}, {253: 4.0}, {254: 21.0}, {255: 32.0},
#        {256: 12.0}, {257: 38.0}, {258: 14.0}, {259: 38.0}, {260: 39.0},
#        {261: 58.0}, {262: 17.0}], dtype=object)

# %%
def sep_val(partof_id):
    if not np.isnan(partof_id):
        temp = mydict[partof_id]
        if np.isnan(temp):
            return partof_id,temp
        else:
            return temp,partof_id
    else:
        return partof_id,partof_id

# %%
test_set['partof_prov'], test_set['partof_uezd'] = zip(*test_set.partof_id.map(sep_val))

# %%
test_set.to_csv('hgr_test_set_2.csv')

# %%
geojson = {"type":"FeatureCollection","features":[]}

# %%
test_set.head()
# Out:
#    uniq_id    ru_old_orth alt_name  partof_id    x_coord    y_coord  \
# 0        1     Московская      NaN        NaN  37.617778  55.751667
# 1        2  Архангельское      NaN        NaN  40.533333  64.533333
# 2        3   Владимерское      NaN        NaN  40.416667  56.133333
# 3        4    Вологодское      NaN        NaN  39.883333  59.200000
# 4        5    Воронежское      NaN        NaN  39.210556  51.671667
#
#    ru_featuretype SOURCE description    ru_new_orth      ...        \
# 0        Губернія    NaN         NaN     Московская      ...
# 1  Намѣстничество    NaN         NaN  Архангельское      ...
# 2  Намѣстничество    NaN         NaN   Владимерское      ...
# 3  Намѣстничество    NaN         NaN    Вологодское      ...
# 4  Намѣстничество    NaN         NaN    Воронежское      ...
#
#   pres_country country_code beg_yr end_yr  lc_featuretype  id_featuretype  \
# 0       Russia           RU    NaN    NaN             NaN             NaN
# 1       Russia           RU    NaN    NaN             NaN             NaN
# 2       Russia           RU    NaN    NaN             NaN             NaN
# 3       Russia           RU    NaN    NaN             NaN             NaN
# 4       Russia           RU    NaN    NaN             NaN             NaN
#
#    en_featuretype  xy_type  partof_prov partof_uezd
# 0             NaN    POINT          NaN         NaN
# 1             NaN    POINT          NaN         NaN
# 2             NaN    POINT          NaN         NaN
# 3             NaN    POINT          NaN         NaN
# 4             NaN    POINT          NaN         NaN
#
# [5 rows x 22 columns]

# %%
def mapmaker(name,desc,lat,lng,featuretype,partof_namest):
    if featuretype in ['Губернія','Намѣстничество']:
        markerSize = 'large'
    elif featuretype in ['уезд']:
        markerSize = 'medium'
    else:
        markerSize = 'small'
    if featuretype in ['Губернія','Намѣстничество']:
        markerSymbol = 'star'
    elif featuretype in ['уезд']:
        markerSymbol = 'square'
    else:
        markerSymbol = 'circle'
    colorlist = ["#D73E29","#73E444","#6469D3","#323E21","#7ACEDB","#DC3E96","#E4BF39","#4D234D","#D78583","#CDDF8F","#D247D6","#D7B7D8","#632923","#406F6F","#E18029","#6597DA","#6FE08C","#629B6E","#9B375D","#853B8B","#6DDCBA","#C7CEBF","#C9E042","#776228","#D1B183","#AE5834","#8D647E","#59AD3E","#99A53F","#416C26","#414D82","#D779B1","#D24158","#887B69","#373039","#A988D0","#7490AD","#C69344","#C170DD"]
    if np.isnan(partof_namest):
        markerColor = markerColor = colorlist[int(partof_namest-1)]
    if str(desc)=='nan':
        desc = ""
    outdict = {"type":"Feature","geometry":{"type":"Point","coordinates":[lng,lat]},"properties":{"title":name,"description":desc,"marker-size":markerSize,"marker-symbol":markerSymbol,"marker-color":markerColor}}
    return outdict

# %%
geojson['features'] = np.vectorize(mapmaker)(test_set.ru_old_orth,test_set.description+" "+test_set.SOURCE,test_set.y_coord,test_set.x_coord,test_set.ru_featuretype,test_set.partof_prov).tolist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-d41af3e066ec> in <module>()
# ----> 1 geojson['features'] = np.vectorize(mapmaker)(test_set.ru_old_orth,test_set.description+" "+test_set.SOURCE,test_set.y_coord,test_set.x_coord,test_set.ru_featuretype,test_set.partof_prov).tolist()
#
# /home/jeremy/anaconda3/lib/python3.4/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    1571             vargs.extend([kwargs[_n] for _n in names])
#    1572
# -> 1573         return self._vectorize_call(func=func, args=vargs)
#    1574
#    1575     def _get_ufunc_and_otypes(self, func, args):
#
# /home/jeremy/anaconda3/lib/python3.4/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    1631             _res = func()
#    1632         else:
# -> 1633             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    1634
#    1635             # Convert args to object arrays first
#
# /home/jeremy/anaconda3/lib/python3.4/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    1595             # arrays (the input values are not checked to ensure this)
#    1596             inputs = [asarray(_a).flat[0] for _a in args]
# -> 1597             outputs = func(*inputs)
#    1598
#    1599             # Performance note: profiling indicates that -- for simple functions
#
# <ipython-input-57-a7d11647a220> in mapmaker(name, desc, lat, lng, featuretype, partof_namest)
#      13         markerSymbol = 'circle'
#      14     colorlist = ["#D73E29","#73E444","#6469D3","#323E21","#7ACEDB","#DC3E96","#E4BF39","#4D234D","#D78583","#CDDF8F","#D247D6","#D7B7D8","#632923","#406F6F","#E18029","#6597DA","#6FE08C","#629B6E","#9B375D","#853B8B","#6DDCBA","#C7CEBF","#C9E042","#776228","#D1B183","#AE5834","#8D647E","#59AD3E","#99A53F","#416C26","#414D82","#D779B1","#D24158","#887B69","#373039","#A988D0","#7490AD","#C69344","#C170DD"]
# ---> 15     markerColor = colorlist[int(partof_namest-1)]
#      16     if str(desc)=='nan':
#      17         desc = ""
#
# ValueError: cannot convert float NaN to integer

# %%
with open("hgr_map_test.geojson","w") as fp:
    json.dump(geojson,fp)

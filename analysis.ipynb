# %%
import pandas as pd

# %%
market_towns = pd.DataFrame.from_csv('market_towns.csv')

# %%
cyrillic_translit={u'\u0410': 'A', u'\u0430': 'a',u'\u0411': 'B', u'\u0431': 'b',u'\u0412': 'V', u'\u0432': 'v',u'\u0413': 'G', u'\u0433': 'g',u'\u0414': 'D', u'\u0434': 'd',u'\u0415': 'E', u'\u0435': 'e',u'\u0416': 'Zh', u'\u0436': 'zh',u'\u0417': 'Z', u'\u0437': 'z',u'\u0418': 'I', u'\u0438': 'i',u'\u0419': 'I', u'\u0439': 'i',u'\u041a': 'K', u'\u043a': 'k',u'\u041b': 'L', u'\u043b': 'l',u'\u041c': 'M', u'\u043c': 'm',u'\u041d': 'N', u'\u043d': 'n',u'\u041e': 'O', u'\u043e': 'o',u'\u041f': 'P', u'\u043f': 'p',u'\u0420': 'R', u'\u0440': 'r',u'\u0421': 'S', u'\u0441': 's',u'\u0422': 'T', u'\u0442': 't',u'\u0423': 'U', u'\u0443': 'u',u'\u0424': 'F', u'\u0444': 'f',u'\u0425': 'Kh', u'\u0445': 'kh',u'\u0426': 'Ts', u'\u0446': 'ts',u'\u0427': 'Ch', u'\u0447': 'ch',u'\u0428': 'Sh', u'\u0448': 'sh',u'\u0429': 'Shch', u'\u0449': 'shch',u'\u042a': '"', u'\u044a': '"',u'\u042b': 'Y', u'\u044b': 'y',u'\u042c': "'", u'\u044c': "'",u'\u042d': 'E', u'\u044d': 'e',u'\u042e': 'Iu', u'\u044e': 'iu',u'\u042f': 'Ia', u'\u044f': 'ia', u'\u0462': 'IE', u'\u0463': 'ie', u'\u0406': 'I', u'\u0456': 'i'}
def transliterate(word, translit_table):
    """
    Transliterates 'word' based on the key/value pairs in 'translit_table'
    """
    converted_word = ''
    for char in word:
        transchar = ''
        if char in translit_table:
            transchar = translit_table[char]
        else:
            transchar = char
        converted_word += transchar
    return converted_word

# %%
market_towns.name = market_towns.name.apply(str.capitalize)
market_towns['lc_trans'] = market_towns.name.apply(transliterate,args=(cyrillic_translit,))

# %%
market_towns.columns = ['lc_trans', 'name', '_type', 'text', 'geo_lat', 'geo_lng', 'geo_placename', 'google_reconcile', 'google_lat', 'google_lng', 'google_url', 'geo_id', 'geo_url']

# %%
cols = ['lc_trans', 'name', '_type', 'text', 'geo_lat', 'geo_lng', 'geo_placename', 'google_reconcile', 'google_lat', 'google_lng', 'google_url', 'geo_id', 'geo_url']
market_towns = market_towns[cols]

# %%
market_towns.columns = ['lc_trans', 'ru_old_orth', 'ru_featuretype', 'description', 'x_coord', 'y_coord', 'pres_loc', 'google_reconcile', 'google_lat', 'google_lng', 'google_url', 'geo_id', 'geo_url']

# %%
market_towns.head()
# Out:
#                 lc_trans ru_old_orth ru_featuretype  \
# ІОСИФОВЪ        Iosifov"    Іосифовъ      монастырь
# АБЗАЛЬ           Abzal'      Абзаль          городъ
# АВДУЛОВО        Avdulovo    Авдулово           село
# АВЖЕНСКАЯ   Avzhenskaia   Авженская         волость
# АДОВАТОВО      Adovatovo   Адоватово           село
#
#                                                   description    x_coord  \
# ІОСИФОВЪ     </span><span class="font0" style="font-style:...  not_found
# АБЗАЛЬ       </span><span class="font0" style="font-style:...   31.51667
# АВДУЛОВО     ИВАНОВСКОЕ тожь, </span><span class="font0" s...   53.29975
# АВЖЕНСКАЯ    </span><span class="font0" style="font-style:...  not_found
# АДОВАТОВО    </span><span class="font0" style="font-style:...  not_found
#
#               y_coord           pres_loc  \
# ІОСИФОВЪ    not_found          not_found
# АБЗАЛЬ       53.83333  Mazra‘eh-ye Ābzal
# АВДУЛОВО      38.6293           Avdulovo
# АВЖЕНСКАЯ   not_found          not_found
# АДОВАТОВО   not_found          not_found
#
#                                              google_reconcile  google_lat  \
# ІОСИФОВЪ                                            not_found   not_found
# АБЗАЛЬ      Abzal Bus Stop, Bukhar-Zhyrau Avenue, Karagand...  49.8042101
# АВДУЛОВО             Avdulovo, Lipetsk Oblast, Russia, 399837   53.300006
# АВЖЕНСКАЯ                                           not_found   not_found
# АДОВАТОВО                                           not_found   not_found
#
#             google_lng                                         google_url  \
# ІОСИФОВЪ     not_found  https://maps.googleapis.com/maps/api/geocode/j...
# АБЗАЛЬ      73.0872345  https://maps.googleapis.com/maps/api/geocode/j...
# АВДУЛОВО    38.6298386  https://maps.googleapis.com/maps/api/geocode/j...
# АВЖЕНСКАЯ    not_found  https://maps.googleapis.com/maps/api/geocode/j...
# АДОВАТОВО    not_found  https://maps.googleapis.com/maps/api/geocode/j...
#
#                geo_id                                            geo_url
# ІОСИФОВЪ    not_found  http://api.geonames.org/search?username=jaguil...
# АБЗАЛЬ         124470  http://api.geonames.org/search?username=jaguil...
# АВДУЛОВО       580282  http://api.geonames.org/search?username=jaguil...
# АВЖЕНСКАЯ   not_found  http://api.geonames.org/search?username=jaguil...
# АДОВАТОВО   not_found  http://api.geonames.org/search?username=jaguil...

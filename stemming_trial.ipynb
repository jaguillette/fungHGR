# %%
import nltk

# %%
russ_stemmer = nltk.stem.SnowballStemmer('russian')

# %%
russ_stemmer.stem("Рязанского")
# Out:
# 'рязанск'

# %%
for w in "Рязанского Наместничества Вологодского Наместничества Нижегородского Наместничества Тамбовского Наместничества Синбирского Наместничества Ярославского Наместничества Пензенского Наместничества Тульского Наместничества в Воронежском Наместничества Екатеринославского Наместничества Курского Наместничества Тамбовского Наместничества Харьковского Наместничества Могилевского Наместничества Синбирского Наместничества Орловского Наместничества Нижегородского Наместничества Харьковского Наместничества Архангельск Наместничества Рязанского Наместничества Тульского Наместничества Кавказского Наместничества Пензенского Наместничества Саратовского Наместничества Харьковского Наместничества".split(' '):
    print(russ_stemmer.stem(w))
# Out:
# рязанск
# наместничеств
# вологодск
# наместничеств
# нижегородск
# наместничеств
# тамбовск
# наместничеств
# синбирск
# наместничеств
# ярославск
# наместничеств
# пензенск
# наместничеств
# тульск
# наместничеств
# в
# воронежск
# наместничеств
# екатеринославск
# наместничеств
# курск
# наместничеств
# тамбовск
# наместничеств
# харьковск
# наместничеств
# могилевск
# наместничеств
# синбирск
# наместничеств
# орловск
# наместничеств
# нижегородск
# наместничеств
# харьковск
# наместничеств
# архангельск
# наместничеств
# рязанск
# наместничеств
# тульск
# наместничеств
# кавказск
# наместничеств
# пензенск
# наместничеств
# саратовск
# наместничеств
# харьковск
# наместничеств

span class=\"font0\">кожи медвежьи, кошечьи и волчьи; полотна гладкія и салфеточныя широкія и узкія и брань уѣздной работы, Фламскія парусныя и равендукЪ холстЪ , хрящЪ, посуда деревянная, свѣчи сальныя, языки говяжьи копченые, губа лиственная , клей Сибирской, кожи подошевныя и ворванныя, сукна сермяжныя и чирковыя туфли, чаи жуланЪ и простой, бадьянЪ, масло коровье льняное и конопляное, медЪ сырецЪ, рога оленьи , мясо говяжье соленое , семга соленая , пряники медовые.</span></p>"

# %%
test_text = html.fromstring(test_text).text_content()

# %%
text_list = test_text.split(sep=' ')
text_list
# Out:
# ['АРХАНГЕЛЬСКЪ,',
#  'главный',
#  'городъ',
#  'Намѣстничества',
#  'сего',
#  'имени.',
#  'ВЪ',
#  'немЪ',
#  'бываетъ',
#  'каждой',
#  'годЪ',
#  'ярмарка',
#  ',',
#  'которая',
#  'начинается',
#  'вЪ',
#  'Маіѣ',
#  'мѣсяцѣ',
#  'сЪ',
#  'приходомъ',
#  'изЪ',
#  'Россіи',
#  'барокЪ,',
#  'а',
#  'изЪ',
#  'за',
#  'моря',
#  'кораблей;',
#  'прямая',
#  'же,',
#  'или',
#  'валовая',
#  'начинается',
#  'всегда',
#  'вЪ',
#  'Іюнѣ,',
#  'а',
#  'оканчивается',
#  'вЪ',
#  'первыхъ',
#  'числахъ',
#  'Октября',
#  ';',
#  'на',
#  'ней',
#  'бываетъ',
#  'торговля',
#  'ме-жду',
#  'иностранными',
#  'и',
#  'Россійскими',
#  'купцами',
#  'Россійскими',
#  'и',
#  'иностранными',
#  'товарами',
#  ',',
#  'продолжающаяся',
#  'во',
#  'время',
#  'мореплаванія,',
#  'на',
#  'которую',
#  'ярмарку',
#  'иностранные',
#  'купцы',
#  'всякіе',
#  'иностранные',
#  'товары',
#  'чрезЪ',
#  'море',
#  'на',
#  'корабляхъ',
#  'изЪ',
#  'чужихЪ',
#  'краевЪ',
#  'кЪ',
# ...

# %%
def word_lookup(word, lookup_dict):
    """
    Towards creating a dictionary to automatically update Russian orthography using http://www.dorev.ru/ru-index.html
    Looks up `word`, finds a modern equivalent and adds it to lookup dict, or doesn't and adds exact conversion to lookup dict.
    """
    url = "http://www.dorev.ru/ru-index.html?s={}".format(word)
    R = requests.get(url)
    parsed = html.fromstring(R.text)
    updated = parsed.xpath('//tr/td[2][@class="uu"]')
    old = parsed.xpath('//tr/td[4][@class="uu"]')
    for x in range(0,len(old)+1):
        if word in old[x].text_content:
            dict[word] = updated[x].text_content
            return updatec[x].text_content
        else:
            return 0

# %%
lookup_dict = {}

# %%
word_lookup('АРХАНГЕЛЬСКЪ',lookup_dict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-8155ade14b15> in <module>()
# ----> 1 word_lookup('АРХАНГЕЛЬСКЪ',lookup_dict)
#
# <ipython-input-13-6544684eba63> in word_lookup(word, lookup_dict)
#      10     old = parsed.xpath('//tr/td[4][@class="uu"]')
#      11     for x in range(0,len(old)+1):
# ---> 12         if word in old[x].text_content:
#      13             dict[word] = updated[x].text_content
#      14             return updatec[x].text_content
#
# IndexError: list index out of range

# %%
url = "http://www.dorev.ru/ru-index.html?s={}&q=on".format(urllib.parse.quote_plus('АРХАНГЕЛЬСКЪ'))
R = requests.get(url)
parsed = html.fromstring(R.text)
updated = parsed.xpath('//tr/td[2][@class="uu"]')
old = parsed.xpath('//tr/td[4][@class="uu"]')

# %%
url
# Out:
# 'http://www.dorev.ru/ru-index.html?s=%D0%90%D0%A0%D0%A5%D0%90%D0%9D%D0%93%D0%95%D0%9B%D0%AC%D0%A1%D0%9A%D0%AA&q=on'

# %%
'http://www.dorev.ru/ru-index.html?s=%C0%D0%D5%C0%CD%C3%C5%CB%DC%D1%CA%DA&q=on'
'http://www.dorev.ru/ru-index.html?s=%D0%90%D0%A0%D0%A5%D0%90%D0%9D%D0%93%D0%95%D0%9B%D0%AC%D0%A1%D0%9A%D0%AA&q=on'

# %%
updated[1].text_content()
# Out:
# 'Слово не найдено.Предположеніе: рррррррррррръ (скорѣе всего, такъ и пишется).\xa0Къ сожалѣнію, нашъ поискъ значительно уступаетъ Яндексу...Поискъ ведётся по первой колонкѣ (современная орѳографія).Словоформы не обрабатываются, «е» и «ё» считаются за одну букву.Попробуйте искать по наиболѣе значимой части слова,включивъ флажокъ «въ любомъ мѣстѣ слова».Напримѣръ:«не\xa0известный» (вмѣсто «неизвестный»),«Победоносец» (вмѣсто «Победоносец»),«употребляешь» (вмѣсто «употребляешь»).\xa0Алфавитъ.По названіямъ буквъ изъ словаря.'

# %%
import json

# %%
import re
from lxml import html

lookup_dict = {}
with open("special_cases.json",'r') as fp:
    lookup_dict = json.load(fp)

def ortho_rules(text,lookup_dict):
    """
    Takes a text string and a lookup dict as input
    Removes any lingering html tags
    Breaks the string down into component words with split
    Uses replacements to modernize orthography
    Returns re-assembled text with modern orthography
    """
    text = html.fromstring(text).text_content()
    textlist = text.split(' ')
    out_list = []
    for word in textlist:
        if word in [',','.',';',':']:
            out_list.append(word)
        word = word.strip(',.;:')
        if word in lookup_dict:
            word = lookup_dict[word]
            out_list.append(word)
        else:
            word = re.sub("[Ъъ]$",'',word)
            word = re.sub("^([че]{0,2}[ч]?[вбнр]?[веоаи])з([ПФКТШСЧпфктшсч])","\1с\2",word,re.IGNORECASE)
            word = re.sub("аго$","ого",word,re.IGNORECASE)
            word = re.sub("яго$","его",word,re.IGNORECASE)
            word = re.sub("ыя$","ые",word,re.IGNORECASE)
            word = re.sub("iя$","ие",word,re.IGNORECASE)
            word = word.replace('і','и')
            word = word.replace('I','И')
            word = word.replace('Ѣ','Е')
            word = word.replace('ѣ','е')
            out_list.append(word)
    out_str = ' '.join(out_list)
    return out_str

# %%
